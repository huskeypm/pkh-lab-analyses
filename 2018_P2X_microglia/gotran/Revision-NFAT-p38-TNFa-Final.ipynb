# %%
# %matplotlib inline

import matplotlib.pylab as plt 


# routlines for analyzing odes
import sys
import pickle as pk
import numpy as np
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/P2X-project/pkh-code/fitting')
import analyzeGotran as ao

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_0mMATP_cat.pickle") #
data2 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_01mMATP_cat.pickle") #
data3 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_1mMATP_cat.pickle") #
data4 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_2mMATP_cat.pickle") #
data5 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_3mMATP_cat.pickle") #
data6 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_5mMATP_cat.pickle") #

stateLabel = "NFATNn"
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)
subData4 = ao.GetData(data4,stateLabel)
subData5 = ao.GetData(data5,stateLabel)
subData6 = ao.GetData(data6,stateLabel)

NFAT1 = subData1.valsIdx[-1] 
NFAT2 = subData2.valsIdx[-1]
NFAT3 = subData3.valsIdx[-1]
NFAT4 = subData4.valsIdx[-1]
NFAT5 = subData5.valsIdx[-1]
NFAT6 = subData6.valsIdx[-1]
## Calculating the absolute difference by setting the NFAT concentration to zero at 0 ATP
NFAT = np.array([NFAT1,NFAT2,NFAT3,NFAT4,NFAT5,NFAT6])-NFAT1 

maxN = max(NFAT)
NFATr = NFAT/maxN

#ATPmM = np.array([0,0.1,0.25,0.5,0.75,1,3,5]) 
ATPmM = np.array([0,0.1,1,2,3,5])
ATPmM2 = np.array([0,0.1,0.5,1,3,5]) 
LitNFATr = np.array([0,0.05,0.1,0.5,1,0.3])

plt.figure(figsize=(10,5),dpi=200)
plt.tick_params(labelsize=12)
plt.subplot(1,2,1)
plt.plot(ATPmM,NFATr,'b-s',label="Model for 15 min")
plt.plot(ATPmM2,LitNFATr,'r--s',label="Ferrari et. al., for 15 min")

plt.xlim(-0.1,5.1)
plt.ylim(-0.05,1.05)

plt.legend(loc=0,fontsize=12)
plt.xlabel("ATP conc. (mM)",fontsize=15)
plt.ylabel("Dephosphorylated NFAT conc. (fraction of max)",fontsize=15)

stateLabel = "NFATNn"
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)
subData4 = ao.GetData(data4,stateLabel)
subData5 = ao.GetData(data5,stateLabel)
subData6 = ao.GetData(data6,stateLabel)


plt.subplot(1,2,2)
plt.tick_params(labelsize=12)
plt.plot(subData1.t/60,subData1.valsIdx,label="0")
plt.plot(subData2.t/60,subData2.valsIdx,label="0.1")
plt.plot(subData3.t/60,subData3.valsIdx,label="1")
plt.plot(subData4.t/60,subData4.valsIdx,label="2")
plt.plot(subData5.t/60,subData5.valsIdx,label="3")
plt.plot(subData6.t/60,subData6.valsIdx,label="5")
plt.legend(loc=0)
#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/nfatvsATPconc15min.png")
# Out:
# Reading /home/AD/bch265/Data_storage/15min_MG_0mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_2mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_3mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_5mMATP_cat.pickle

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_0mMATP_cat.pickle") #
data2 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_01mMATP_cat.pickle") #
data3 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_1mMATP_cat.pickle") #
data4 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_2mMATP_cat.pickle") #
data5 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_3mMATP_cat.pickle") #
data6 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_5mMATP_cat.pickle") #

stateLabel = "NFATNn"
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)
subData4 = ao.GetData(data4,stateLabel)
subData5 = ao.GetData(data5,stateLabel)
subData6 = ao.GetData(data6,stateLabel)

NFAT1 = subData1.valsIdx[-1] 
NFAT2 = subData2.valsIdx[-1]
NFAT3 = subData3.valsIdx[-1]
NFAT4 = subData4.valsIdx[-1]
NFAT5 = subData5.valsIdx[-1]
NFAT6 = subData6.valsIdx[-1]

NFAT = np.array([NFAT1,NFAT2,NFAT3,NFAT4,NFAT5,NFAT6])-NFAT1 

maxN = max(NFAT)
NFATr = NFAT/maxN

#ATPmM = np.array([0,0.1,0.25,0.5,0.75,1,3,5]) 
ATPmM = np.array([0,0.1,1,2,3,5])
ATPmM2 = np.array([0,0.1,0.5,1,3,5]) 
LitNFATr = np.array([0,0.05,0.1,0.5,1,0.3])

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(ATPmM,NFATr,'b-s',label="Model for 15 min")
plt.plot(ATPmM2,LitNFATr,'r--s',label="Ferrari et. al., for 15 min")

plt.xlim(-0.1,5.1)
plt.ylim(-0.05,1.05)

plt.legend(loc=0,fontsize=10)
plt.xlabel("ATP conc. (mM)",fontsize=12)
plt.ylabel("Dephosphorylated NFAT conc. (fraction of max)",fontsize=12)

stateLabel = "NFATNn"
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)
subData4 = ao.GetData(data4,stateLabel)
subData5 = ao.GetData(data5,stateLabel)
subData6 = ao.GetData(data6,stateLabel)
# Out:
# Reading /home/AD/bch265/Data_storage/15min_MG_0mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_2mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_3mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_5mMATP_cat.pickle

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_0mMATP_cat.pickle") #
data2 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_01mMATP_cat.pickle") #
data3 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_1mMATP_cat.pickle") #
data4 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_2mMATP_cat.pickle") #
data5 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_3mMATP_cat.pickle") #
data6 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_5mMATP_cat.pickle") #

stateLabel = "NFATNn"
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)
subData4 = ao.GetData(data4,stateLabel)
subData5 = ao.GetData(data5,stateLabel)
subData6 = ao.GetData(data6,stateLabel)

NFAT1 = subData1.valsIdx[-1] 
NFAT2 = subData2.valsIdx[-1]
NFAT3 = subData3.valsIdx[-1]
NFAT4 = subData4.valsIdx[-1]
NFAT5 = subData5.valsIdx[-1]
NFAT6 = subData6.valsIdx[-1]

NFAT = np.array([NFAT1,NFAT2,NFAT3,NFAT4,NFAT5])-NFAT1 

maxN = max(NFAT)
NFATr = NFAT/maxN

#ATPmM = np.array([0,0.1,0.25,0.5,0.75,1,3,5]) 
ATPmM = np.array([0,0.1,1,2,3])
ATPmM2 = np.array([0,0.1,0.5,1,3,5]) 
LitNFATr = np.array([0,0.05,0.1,0.5,1,0.3])

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(ATPmM,NFATr,'b-s',label="Model for 15 min")
plt.plot(ATPmM2,LitNFATr,'r--s',label="Ferrari et. al., for 15 min")

plt.xlim(-0.1,5.1)
plt.ylim(-0.05,1.05)

plt.legend(loc=0,fontsize=10)
plt.xlabel("ATP conc. (mM)",fontsize=12)
plt.ylabel("Dephosphorylated NFAT conc. (fraction of max)",fontsize=12)

stateLabel = "NFATNn"
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)
subData4 = ao.GetData(data4,stateLabel)
subData5 = ao.GetData(data5,stateLabel)
subData6 = ao.GetData(data6,stateLabel)
# Out:
# Reading /home/AD/bch265/Data_storage/15min_MG_0mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_2mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_3mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/15min_MG_5mMATP_cat.pickle

# %%
data8 = ao.readPickle("/home/AD/bch265/Data_storage/60min_MG_3mMATP_cat.pickle") #

stateLabel = "NFATNn"
subData0 = ao.GetData(data8,stateLabel)

NFAT0 = subData0.valsIdx[1] #+ subData1a.valsIdx[1]
NFAT1 = subData0.valsIdx[60] #+ subData1a.valsIdx[60]
NFAT2 = subData0.valsIdx[5*60] #+ subData1a.valsIdx[5*60]
NFAT3 = subData0.valsIdx[10*60] #+ subData1a.valsIdx[10*60]
NFAT4 = subData0.valsIdx[15*60] #+ subData1a.valsIdx[15*60]
NFAT5 = subData0.valsIdx[30*60] #+ subData1a.valsIdx[30*60]
NFAT6 = subData0.valsIdx[60*60] #+ subData1a.valsIdx[60*60]

## Calculating the absolute difference by setting the NFAT concentration 0 at time = 0
NFAT = np.array([NFAT0,NFAT1,NFAT2,NFAT3,NFAT4,NFAT5,NFAT6]) - NFAT0
maxN = max(NFAT)
NFATr = NFAT/maxN

dura = np.array([0,1,5,10,15,30,60]) # in min
## Ferrari et al.
LitNFATr = np.array([0,0.26,0.95,1,0.95]) # in fraction
Littime = np.array([0,1,15,30,60]) # in min

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(dura,NFATr,'b-s',label="Model at 3 mM [ATP]")
plt.plot(Littime,LitNFATr,'r--s',label="Ferrari et al., at 3 mM [ATP]")

plt.xlim(-2,62)
plt.ylim(-0.05,1.05)

plt.legend(loc=0,fontsize=10)
plt.xlabel("ATP exposure time (min)",fontsize=12)
plt.ylabel("Dephosphorylated NFAT conc. (fraction of max)",fontsize=12)
plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/60min_MG_3mMATP_cat.pickle

# %%
data8 = ao.readPickle("/home/AD/bch265/Data_storage/60min_MG_3mMATP_cat.pickle") #

stateLabel = "NFATNn"
subData0 = ao.GetData(data8,stateLabel)

NFAT0 = subData0.valsIdx[1] #+ subData1a.valsIdx[1]
NFAT1 = subData0.valsIdx[60] #+ subData1a.valsIdx[60]
NFAT2 = subData0.valsIdx[5*60] #+ subData1a.valsIdx[5*60]
NFAT3 = subData0.valsIdx[10*60] #+ subData1a.valsIdx[10*60]
NFAT4 = subData0.valsIdx[15*60] #+ subData1a.valsIdx[15*60]
NFAT5 = subData0.valsIdx[30*60] #+ subData1a.valsIdx[30*60]
NFAT6 = subData0.valsIdx[60*60] #+ subData1a.valsIdx[60*60]

## Calculating the absolute difference by setting the NFAT concentration 0 at time = 0
NFAT = np.array([NFAT0,NFAT1,NFAT2,NFAT3,NFAT4,NFAT5]) - NFAT0
maxN = max(NFAT)
NFATr = NFAT/maxN

dura = np.array([0,1,5,10,15,30]) # in min
## Ferrari et al.
LitNFATr = np.array([0,0.26,0.95,1,0.95]) # in fraction
Littime = np.array([0,1,15,30,60]) # in min

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(dura,NFATr,'b-s',label="Model at 3 mM [ATP]")
plt.plot(Littime,LitNFATr,'r--s',label="Ferrari et al., at 3 mM [ATP]")

plt.xlim(-2,62)
plt.ylim(-0.05,1.05)

plt.legend(loc=0,fontsize=10)
plt.xlabel("ATP exposure time (min)",fontsize=12)
plt.ylabel("Dephosphorylated NFAT conc. (fraction of max)",fontsize=12)
plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/60min_MG_3mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_1mMATP_cat.pickle")

stateLabel = "pp38"
subData0 = ao.GetData(data0,stateLabel)

pp38= np.array([subData0.valsIdx[0], subData0.valsIdx[60], subData0.valsIdx[60*5], subData0.valsIdx[600]])
pp38r = pp38/max(pp38)

Expt = np.array([0,1,5,15,30,60])
Expt2 = np.array([0,1,5,10])
Litr2 = np.array([0.7,0.8,0.95,1])# Hide

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(Expt2,pp38r,'b-s',label="Model at 1 mM ATP")
plt.plot(Expt2,Litr2,'r--s',label="Hide et al., 1 mM ATP")
plt.legend(loc=0,fontsize=10)
plt.ylim(0.6,1.05)
plt.xlim(-1,11)
plt.tight_layout()
plt.xlabel("ATP exposure time (min)",fontsize=12)
plt.ylabel("Relative pp38 amount (Fraction of max)",fontsize=12)
# Out:
# Reading /home/AD/bch265/Data_storage/15min_MG_1mMATP_cat.pickle

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_001mMATP_cat.pickle") #
data2 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_01mMATP_cat.pickle") #
data3 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_1mMATP_cat.pickle")

stateLabel = "TNFa"

subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

tnfa = np.array([subData1.valsIdx[-1],
                 subData2.valsIdx[-1],
                 subData3.valsIdx[-1]]
                 ) - subData1.valsIdx[0]

tnfar = tnfa/max(tnfa)

ATP = np.array([0.01,0.1,0.2,1])
ATP2 = np.array([0.01,0.1,1])
Hide = np.array([0.04,0.26,0.35,1])

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.semilogx(ATP2,tnfar,'b-s',label="Model - 3 hr")
plt.semilogx(ATP,Hide,'r--s',label="Hide et al. - 3 hr")

plt.xlim(0.009,1.2)
plt.ylim(0,1.05)

plt.legend(loc=0,fontsize=10)
plt.xlabel("log[ATP] (log(mM))",fontsize=12)
plt.ylabel("Synthesized TNFa (fraction of max)",fontsize=12)
plt.tight_layout()
print (subData1.valsIdx[0],subData1.valsIdx[-1])
# Out:
# Reading /home/AD/bch265/Data_storage/180min_MG_001mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/180min_MG_01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/180min_MG_1mMATP_cat.pickle
# (0.42450389403, 0.43285334779352291)

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/MG_0mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_001mMATP_cat.pickle") #
data2 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_01mMATP_cat.pickle") #
data3 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_1mMATP_cat.pickle")

stateLabel = "TNFa"
ta0 = ao.GetData(data0,stateLabel)
ta1 = ao.GetData(data1,stateLabel)
ta2 = ao.GetData(data2,stateLabel)
ta3 = ao.GetData(data3,stateLabel)

tnfa = np.array([ta0.valsIdx[-1],ta1.valsIdx[-1],ta2.valsIdx[-1],ta3.valsIdx[-1]]) - ta0.valsIdx[0]
tnfar = tnfa/max(tnfa)
ATP1 = np.array([0.01,0.1,0.2,1])
ATP2 = np.array([0,0.01,0.1,1])
Hide = np.array([0.04,0.26,0.35,1])

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(ATP2,tnfar,'b-s',label="Model - 3 hr")
plt.plot(ATP1,Hide,'r--s',label="Hide et al. - 3 hr")

plt.xlim(-0.1,1.1)
plt.ylim(-0.02,1.02)

plt.legend(loc=0,fontsize=10)
plt.xlabel("[ATP] (mM)",fontsize=12)
plt.ylabel("Synthesized TNFa (fraction of max)",fontsize=12)
plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/MG_0mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/180min_MG_001mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/180min_MG_01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/180min_MG_1mMATP_cat.pickle

# %%
data = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_3mMATP_cat.pickle") #

stateLabel = "TNFa"
subData1 = ao.GetData(data,stateLabel)

tnfa = np.array([subData1.valsIdx[0],
                 subData1.valsIdx[3600],
                 subData1.valsIdx[3600*2],
                 subData1.valsIdx[3600*3]]) - subData1.valsIdx[0]
tnfar = tnfa/max(tnfa)

hrs = np.array([0,1,2,3])
Hide = np.array([0,0.054,0.54,1])

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(hrs,tnfar,'b-s',label="Model- 3 mM ATP")
plt.plot(hrs,Hide,'r--s',label="Hide et al. - 3 mM ATP")

plt.xlim(-0.2,3.2)
plt.ylim(-0.05,1.05)

plt.legend(loc=0,fontsize=10)
plt.xlabel("time (hr)",fontsize=12)
plt.ylabel("Synthesized TNFa (fraction of max)",fontsize=12)
plt.tight_layout()
#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/tnfvstime3mMATP.png")
# Out:
# Reading /home/AD/bch265/Data_storage/180min_MG_3mMATP_cat.pickle
