# %% [markdown]
# ### This is testing high frequency beyond 0.5
# - Stim time is 0.1 second

# %%
# routlines for analyzing odes
# %matplotlib inline
import matplotlib.pylab as plto 
import sys
import pickle as pk
import numpy as np
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/P2X-project/pkh-code/fitting')
import analyzeGotran as ao

import matplotlib
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
data61 = ao.readPickle("/home/AD/bch265/Data_storage/0.5HzMG_0.01mMATPnew_cat.pickle")
data62 = ao.readPickle("/home/AD/bch265/Data_storage/0.5HzMG_0.1mMATPnew_cat.pickle")
data63 = ao.readPickle("/home/AD/bch265/Data_storage/0.5HzMG_1mMATPnew_cat.pickle")
data64 = ao.readPickle("/home/AD/bch265/Data_storage/0.5HzMG_2mMATPnew_cat.pickle")

data71 = ao.readPickle("/home/AD/bch265/Data_storage/1HzMG_0.01mMATPnew_cat.pickle")
data72 = ao.readPickle("/home/AD/bch265/Data_storage/1HzMG_0.1mMATPnew_cat.pickle")
data73 = ao.readPickle("/home/AD/bch265/Data_storage/1HzMG_1mMATPnew_cat.pickle")
data74 = ao.readPickle("/home/AD/bch265/Data_storage/1HzMG_2mMATPnew_cat.pickle")

data81 = ao.readPickle("/home/AD/bch265/Data_storage/2HzMG_0.01mMATPnew_cat.pickle")
data82 = ao.readPickle("/home/AD/bch265/Data_storage/2HzMG_0.1mMATPnew_cat.pickle")
data83 = ao.readPickle("/home/AD/bch265/Data_storage/2HzMG_1mMATPnew_cat.pickle")
data84 = ao.readPickle("/home/AD/bch265/Data_storage/2HzMG_2mMATPnew_cat.pickle")

data91 = ao.readPickle("/home/AD/bch265/Data_storage/4HzMG_0.01mMATPnew_cat.pickle")
data92 = ao.readPickle("/home/AD/bch265/Data_storage/4HzMG_0.1mMATPnew_cat.pickle")
data93 = ao.readPickle("/home/AD/bch265/Data_storage/4HzMG_1mMATPnew_cat.pickle")
data94 = ao.readPickle("/home/AD/bch265/Data_storage/4HzMG_2mMATPnew_cat.pickle")

data01 = ao.readPickle("/home/AD/bch265/Data_storage/5HzMG_0.01mMATPnew_cat.pickle")
data02 = ao.readPickle("/home/AD/bch265/Data_storage/5HzMG_0.1mMATPnew_cat.pickle")
data03 = ao.readPickle("/home/AD/bch265/Data_storage/5HzMG_1mMATPnew_cat.pickle")
data04 = ao.readPickle("/home/AD/bch265/Data_storage/5HzMG_2mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/0.5HzMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/0.5HzMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/0.5HzMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/0.5HzMG_2mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1HzMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1HzMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1HzMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1HzMG_2mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/2HzMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/2HzMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/2HzMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/2HzMG_2mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/4HzMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/4HzMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/4HzMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/4HzMG_2mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5HzMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5HzMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5HzMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5HzMG_2mMATPnew_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/MG_0mMATP_cat.pickle")
#stateLabel = "TNFa_release"
#subData0 = ao.GetData(data0,stateLabel)

#plt.plot(subData0.t/60,subData0.valsIdx)
# Out:
# Reading /home/AD/bch265/Data_storage/MG_0mMATP_cat.pickle

# %%
stateLabel = "Cai"
subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)

subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)

subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)

subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)

subData0 = ao.GetData(data0,stateLabel)

D0 = np.mean(subData0.valsIdx[10:20]) 

D61 = np.mean(subData61.valsIdx[10000:20000]) 
D62 = np.mean(subData62.valsIdx[10000:20000]) 
D63 = np.mean(subData63.valsIdx[10000:20000]) 
D64 = np.mean(subData64.valsIdx[10000:20000]) 

D71 = np.mean(subData71.valsIdx[10000:20000]) 
D72 = np.mean(subData72.valsIdx[10000:20000]) 
D73 = np.mean(subData73.valsIdx[10000:20000]) 
D74 = np.mean(subData74.valsIdx[10000:20000]) 

D81 = np.mean(subData81.valsIdx[10000:20000]) 
D82 = np.mean(subData82.valsIdx[10000:20000]) 
D83 = np.mean(subData83.valsIdx[10000:20000]) 
D84 = np.mean(subData84.valsIdx[10000:20000]) 

D91 = np.mean(subData91.valsIdx[10000:20000]) 
D92 = np.mean(subData92.valsIdx[10000:20000]) 
D93 = np.mean(subData93.valsIdx[10000:20000]) 
D94 = np.mean(subData94.valsIdx[10000:20000]) 

D01 = np.mean(subData01.valsIdx[10000:20000]) 
D02 = np.mean(subData02.valsIdx[10000:20000]) 
D03 = np.mean(subData03.valsIdx[10000:20000]) 
D04 = np.mean(subData04.valsIdx[10000:20000]) 



print np.array([[D0, D61, D62, D63, D64], 
                [D0, D71, D72, D73, D74], 
                [D0, D81, D82, D83, D84],
                [D0, D91, D92, D93, D94],
                [D0, D01, D02, D03, D04]])
                

print np.array([D0, D61, D62, D63, D64, 
                D0, D71, D72, D73, D74, 
                D0, D81, D82, D83, D84, 
                D0, D91, D92, D93, D94, 
                D0, D01, D02, D03, D04])
# Out:
# [[ 0.10003805  0.10015645  0.10089604  0.10161495  0.10245972]
#  [ 0.10003805  0.10021328  0.10163987  0.10262356  0.10425218]
#  [ 0.10003805  0.10032443  0.10452228  0.10541397  0.10932511]
#  [ 0.10003805  0.10065164  0.11404071  0.11457998  0.12539467]
#  [ 0.10003805  0.10081747  0.11775971  0.11837237  0.13183332]]
# [ 0.10003805  0.10015645  0.10089604  0.10161495  0.10245972  0.10003805
#   0.10021328  0.10163987  0.10262356  0.10425218  0.10003805  0.10032443
#   0.10452228  0.10541397  0.10932511  0.10003805  0.10065164  0.11404071
#   0.11457998  0.12539467  0.10003805  0.10081747  0.11775971  0.11837237
#   0.13183332]

# %%
stateLabel = "TNFa"
subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)

subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)

subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)

subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)

subData0 = ao.GetData(data0,stateLabel)

D0 = (subData0.valsIdx[20]-subData0.valsIdx[10])/(0.167)

D61 = (subData61.valsIdx[20000]-subData61.valsIdx[10000])/(0.167)
D62 = (subData62.valsIdx[20000]-subData62.valsIdx[10000])/(0.167)
D63 = (subData63.valsIdx[20000]-subData63.valsIdx[10000])/(0.167)
D64 = (subData64.valsIdx[20000]-subData64.valsIdx[10000])/(0.167)

D71 = (subData71.valsIdx[20000]-subData71.valsIdx[10000])/(0.167)
D72 = (subData72.valsIdx[20000]-subData72.valsIdx[10000])/(0.167)
D73 = (subData73.valsIdx[20000]-subData73.valsIdx[10000])/(0.167)
D74 = (subData74.valsIdx[20000]-subData74.valsIdx[10000])/(0.167)

D81 = (subData81.valsIdx[20000]-subData81.valsIdx[10000])/(0.167)
D82 = (subData82.valsIdx[20000]-subData82.valsIdx[10000])/(0.167)
D83 = (subData83.valsIdx[20000]-subData83.valsIdx[10000])/(0.167)
D84 = (subData84.valsIdx[20000]-subData84.valsIdx[10000])/(0.167)

D91 = (subData91.valsIdx[20000]-subData91.valsIdx[10000])/(0.167)
D92 = (subData92.valsIdx[20000]-subData92.valsIdx[10000])/(0.167)
D93 = (subData93.valsIdx[20000]-subData93.valsIdx[10000])/(0.167)
D94 = (subData94.valsIdx[20000]-subData94.valsIdx[10000])/(0.167)

D01 = (subData01.valsIdx[20000]-subData01.valsIdx[10000])/(0.167)
D02 = (subData02.valsIdx[20000]-subData02.valsIdx[10000])/(0.167)
D03 = (subData03.valsIdx[20000]-subData03.valsIdx[10000])/(0.167)
D04 = (subData04.valsIdx[20000]-subData04.valsIdx[10000])/(0.167)

print np.array([[D0, D01, D02, D03, D04], 
                [D0, D91, D92, D93, D94], 
                [D0, D81, D82, D83, D84],
                [D0, D71, D72, D73, D74],
                [D0, D61, D62, D63, D64]])
# Out:
# [[ -1.94219591e-09   1.17343767e-06   1.20744165e-05   2.14186224e-05
#     4.43126899e-05]
#  [ -1.94219591e-09   9.01699437e-07   9.17638675e-06   1.64073274e-05
#     3.38456827e-05]
#  [ -1.94219591e-09   3.79861447e-07   3.21585598e-06   5.74007775e-06
#     1.02530919e-05]
#  [ -1.94219591e-09   1.70334285e-07   1.45080762e-06   2.48777467e-06
#     3.94212639e-06]
#  [ -1.94219591e-09   8.56214570e-08   8.63033197e-07   1.38827896e-06
#     1.99094812e-06]]

# %%
A = np.array([D0, D61, D62, D63, D64, 
                D71, D72, D73, D74, 
                D81, D82, D83, D84, 
                D91, D92, D93, D94, 
                D01, D02, D03, D04])

maxTNFa = max(A)
st1 = np.array([D0, D61, D62, D63, D64])/maxTNFa
st2 = np.array([D0, D71, D72, D73, D74])/maxTNFa
st3 = np.array([D0, D81, D82, D83, D84])/maxTNFa
st4 = np.array([D0, D91, D92, D93, D94])/maxTNFa
st5 = np.array([D0, D01, D02, D03, D04])/maxTNFa

print st1
print st2
print st3
print st4
print st5
# Out:
# [ -4.38293389e-05   1.93221078e-03   1.94759830e-02   3.13291512e-02
#    4.49295253e-02]
# [ -4.38293389e-05   3.84391662e-03   3.27402290e-02   5.61413599e-02
#    8.89615682e-02]
# [ -4.38293389e-05   8.57229493e-03   7.25718973e-02   1.29535755e-01
#    2.31380491e-01]
# [ -4.38293389e-05   2.03485602e-02   2.07082593e-01   3.70262502e-01
#    7.63792105e-01]
# [ -4.38293389e-05   2.64808494e-02   2.72482137e-01   4.83351889e-01
#    1.00000000e+00]

# %%
stateLabel = "Cai"

subData62 = ao.GetData(data62,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)
subData0 = ao.GetData(data0,stateLabel)


plt.figure(figsize=(7,7),dpi=200)
#plt.plot(subData0.t,subData0.valsIdx)
plt.plot(subData02.t[0:20000],subData02.valsIdx[0:20000],label="0.5")
#plt.plot(subData74.t,subData74.valsIdx,label="1")
#plt.plot(subData84.t,subData84.valsIdx,label="2")
#plt.plot(subData94.t,subData94.valsIdx,label="4")
#plt.plot(subData04.t,subData04.valsIdx,label="5")
#plt.xlim(-1,1)
#plt.ylim(0.3867,0.3869)
plt.legend(loc=0)
#plt.xlim(0,2)

print (np.mean(subData02.valsIdx[10000:20000]))
# Out:
# 0.117759707655

# %%
stateLabel = "Cai"

subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)

subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)

subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)

subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)


xmin = 0
xmax = 20
ymin = 0.095
ymax = 0.175
ytick = 0.01
ind = np.arange(1, 6)

rcParams['figure.figsize'] = 20,18
rcParams['figure.dpi']=200

#plt.figure(num=None, figsize=(30, 16), dpi=100, facecolor='w', edgecolor='k')
ax = plt.subplot(5,5,1)
ax.tick_params(labelsize=12)
ax.set_title("10 uM ATP",fontsize=15)
ax.plot((subData61.t) ,subData61.valsIdx,'b-',label="ST20/RS20")
ax.set_ylabel("0.5 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,2)
ax.tick_params(labelsize=12)
ax.set_title("100 uM ATP",fontsize=15)
ax.plot((subData62.t) ,subData62.valsIdx,'b-',label="ST20/RS20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,3)
ax.tick_params(labelsize=12)
ax.set_title("1 mM ATP",fontsize=15)
ax.plot((subData63.t) ,subData63.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,4)
ax.tick_params(labelsize=12)
ax.set_title("2 mM ATP",fontsize=15)
ax.plot((subData64.t) ,subData64.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,5)
ax.tick_params(labelsize=12)
ax.set_title("Amt. of Synthesized TNFa",fontsize=15)
ba,bb,bc,bd,be = ax.bar(ind, st1, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,6)
ax.tick_params(labelsize=12)
ax.plot((subData71.t) ,subData71.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("1 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,7)
ax.tick_params(labelsize=12)
ax.plot((subData72.t) ,subData72.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,8)
ax.tick_params(labelsize=12)
ax.plot((subData73.t) ,subData73.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,9)
ax.tick_params(labelsize=12)
ax.plot((subData74.t) ,subData74.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,10)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st2, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,11)
ax.tick_params(labelsize=12)
ax.plot((subData81.t) ,subData81.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("2 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,12)
ax.tick_params(labelsize=12)
ax.plot((subData82.t) ,subData82.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,13)
ax.tick_params(labelsize=12)
ax.plot((subData83.t) ,subData83.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,14)
ax.tick_params(labelsize=12)
ax.plot((subData84.t) ,subData84.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,15)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st3, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,16)
ax.tick_params(labelsize=12)
ax.plot((subData91.t) ,subData91.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("4 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,17)
ax.tick_params(labelsize=12)
ax.plot((subData92.t) ,subData92.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,18)
ax.tick_params(labelsize=12)
ax.plot((subData93.t) ,subData93.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,19)
ax.tick_params(labelsize=12)
ax.plot((subData94.t) ,subData94.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,20)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st4, align='center')
ba.set_facecolor('g')
bb.set_facecolor('g')
bc.set_facecolor('g')
bd.set_facecolor('g')
be.set_facecolor('g')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,21)
ax.tick_params(labelsize=12)
ax.plot((subData01.t) ,subData01.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("5 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

ax = plt.subplot(5,5,22)
ax.tick_params(labelsize=12)
ax.plot((subData02.t) ,subData02.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,23)
ax.tick_params(labelsize=12)
ax.plot((subData03.t) ,subData03.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,24)
ax.tick_params(labelsize=12)
ax.plot((subData04.t) ,subData04.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,25)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st5, align='center')
ba.set_facecolor('m')
bb.set_facecolor('m')
bc.set_facecolor('m')
bd.set_facecolor('m')
be.set_facecolor('m')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0','0.01','0.1','1','2'])
ax.set_xlabel('[ATP] (mM)',fontsize=15)
plt.tight_layout()

# %%
stateLabel = "NFATNn"

subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)

subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)

subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)

subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)


xmin = 0
xmax = 20
ymin = 0.21
ymax = 0.40
ytick = 0.05
ind = np.arange(1, 6)

rcParams['figure.figsize'] = 20,18
rcParams['figure.dpi']=100

ax = plt.subplot(5,5,1)
ax.tick_params(labelsize=12)
ax.set_title("10 uM ATP",fontsize=15)
ax.plot((subData61.t) ,subData61.valsIdx,'b-',label="ST20/RS20")
ax.set_ylabel("0.5 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,2)
ax.tick_params(labelsize=12)
ax.set_title("100 uM ATP",fontsize=15)
ax.plot((subData62.t) ,subData62.valsIdx,'b-',label="ST20/RS20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,3)
ax.tick_params(labelsize=12)
ax.set_title("1 mM ATP",fontsize=15)
ax.plot((subData63.t) ,subData63.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,4)
ax.tick_params(labelsize=12)
ax.set_title("2 mM ATP",fontsize=15)
ax.plot((subData64.t) ,subData64.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,5)
ax.tick_params(labelsize=12)
ax.set_title("Amt. of Synthesized TNFa",fontsize=15)
ba,bb,bc,bd,be = ax.bar(ind, st1, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,6)
ax.tick_params(labelsize=12)
ax.plot((subData71.t) ,subData71.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("1 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,7)
ax.tick_params(labelsize=12)
ax.plot((subData72.t) ,subData72.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,8)
ax.tick_params(labelsize=12)
ax.plot((subData73.t) ,subData73.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,9)
ax.tick_params(labelsize=12)
ax.plot((subData74.t) ,subData74.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,10)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st2, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,11)
ax.tick_params(labelsize=12)
ax.plot((subData81.t) ,subData81.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("2 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,12)
ax.tick_params(labelsize=12)
ax.plot((subData82.t) ,subData82.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,13)
ax.tick_params(labelsize=12)
ax.plot((subData83.t) ,subData83.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,14)
ax.tick_params(labelsize=12)
ax.plot((subData84.t) ,subData84.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,15)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st3, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,16)
ax.tick_params(labelsize=12)
ax.plot((subData91.t) ,subData91.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("4 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,17)
ax.tick_params(labelsize=12)
ax.plot((subData92.t) ,subData92.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,18)
ax.tick_params(labelsize=12)
ax.plot((subData93.t) ,subData93.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,19)
ax.tick_params(labelsize=12)
ax.plot((subData94.t) ,subData94.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,20)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st4, align='center')
ba.set_facecolor('g')
bb.set_facecolor('g')
bc.set_facecolor('g')
bd.set_facecolor('g')
be.set_facecolor('g')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,21)
ax.tick_params(labelsize=12)
ax.plot((subData01.t) ,subData01.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("5 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

ax = plt.subplot(5,5,22)
ax.tick_params(labelsize=12)
ax.plot((subData02.t) ,subData02.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,23)
ax.tick_params(labelsize=12)
ax.plot((subData03.t) ,subData03.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,24)
ax.tick_params(labelsize=12)
ax.plot((subData04.t) ,subData04.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,25)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st5, align='center')
ba.set_facecolor('m')
bb.set_facecolor('m')
bc.set_facecolor('m')
bd.set_facecolor('m')
be.set_facecolor('m')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0','0.01','0.1','1','2'])
ax.set_xlabel('[ATP] (mM)',fontsize=15)
plt.tight_layout()

# %%
stateLabel = "pp38"

subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)

subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)

subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)

subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)

xmin = 0
xmax = 20
ymin = 50
ymax = 65
ytick = 5
ind = np.arange(1, 6)

rcParams['figure.figsize'] = 20,18
rcParams['figure.dpi']=100

ax = plt.subplot(5,5,1)
ax.tick_params(labelsize=12)
ax.set_title("10 uM ATP",fontsize=15)
ax.plot((subData61.t) ,subData61.valsIdx,'b-',label="ST20/RS20")
ax.set_ylabel("0.5 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,2)
ax.tick_params(labelsize=12)
ax.set_title("100 uM ATP",fontsize=15)
ax.plot((subData62.t) ,subData62.valsIdx,'b-',label="ST20/RS20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,3)
ax.tick_params(labelsize=12)
ax.set_title("1 mM ATP",fontsize=15)
ax.plot((subData63.t) ,subData63.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,4)
ax.tick_params(labelsize=12)
ax.set_title("2 mM ATP",fontsize=15)
ax.plot((subData64.t) ,subData64.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,5)
ax.tick_params(labelsize=12)
ax.set_title("Amt. of Synthesized TNFa",fontsize=15)
ba,bb,bc,bd,be = ax.bar(ind, st1, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,6)
ax.tick_params(labelsize=12)
ax.plot((subData71.t) ,subData71.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("1 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,7)
ax.tick_params(labelsize=12)
ax.plot((subData72.t) ,subData72.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,8)
ax.tick_params(labelsize=12)
ax.plot((subData73.t) ,subData73.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,9)
ax.tick_params(labelsize=12)
ax.plot((subData74.t) ,subData74.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,10)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st2, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,11)
ax.tick_params(labelsize=12)
ax.plot((subData81.t) ,subData81.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("2 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,12)
ax.tick_params(labelsize=12)
ax.plot((subData82.t) ,subData82.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,13)
ax.tick_params(labelsize=12)
ax.plot((subData83.t) ,subData83.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,14)
ax.tick_params(labelsize=12)
ax.plot((subData84.t) ,subData84.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,15)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st3, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,16)
ax.tick_params(labelsize=12)
ax.plot((subData91.t) ,subData91.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("4 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,17)
ax.tick_params(labelsize=12)
ax.plot((subData92.t) ,subData92.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,18)
ax.tick_params(labelsize=12)
ax.plot((subData93.t) ,subData93.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,19)
ax.tick_params(labelsize=12)
ax.plot((subData94.t) ,subData94.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,20)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st4, align='center')
ba.set_facecolor('g')
bb.set_facecolor('g')
bc.set_facecolor('g')
bd.set_facecolor('g')
be.set_facecolor('g')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,21)
ax.tick_params(labelsize=12)
ax.plot((subData01.t) ,subData01.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("5 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

ax = plt.subplot(5,5,22)
ax.tick_params(labelsize=12)
ax.plot((subData02.t) ,subData02.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,23)
ax.tick_params(labelsize=12)
ax.plot((subData03.t) ,subData03.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,24)
ax.tick_params(labelsize=12)
ax.plot((subData04.t) ,subData04.valsIdx,'m-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,25)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st5, align='center')
ba.set_facecolor('m')
bb.set_facecolor('m')
bc.set_facecolor('m')
bd.set_facecolor('m')
be.set_facecolor('m')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0','0.01','0.1','1','2'])
ax.set_xlabel('[ATP] (mM)',fontsize=15)
plt.tight_layout()
