# %%
# %matplotlib inline

import matplotlib.pylab as plt 


# routlines for analyzing odes
import sys

import pickle as pk
import numpy as np
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/P2X-project/pkh-code/fitting')
import analyzeGotran as ao

# %% [markdown]
# reads pickles generated by the following line:
#
# <code> python daisychain.py -t 0.1 -jit -odeName p2x4_MG.ode -var CNt_NFAT 0.15 -var stim_amplitude 100 -T 10000 -iters 1 -name atp100_NFAT0p15.pickle </code>

# %%
# Toulme P2X4 MG ATP st 30s 100 uM
t19 = np.array([0,0.2040816327,1.734693878,4.693877551,8.571428571,13.7755102,24.08163265,34.69387755])+300
y19 = 0.001*np.array([0,-366.8965517,-270.3448276,-171.0344828,-107.5862069,-57.93103448,-22.06896552,2.75862069])

# Yan P2X7 HEK ATP st 120s 100 uM
t11 = np.array([0,6.41221374,30.6870229,53.12977099,95.26717557,119.5419847,123.6641221,127.7862595])
y11 = np.array([0,-0.006428571429,-0.01303571429,-0.01428571429,-0.01345238095,-0.01255952381,-0.0008333333333,-0.000119047619])

# Yan P2X7 HEK ATP st 120s 320 uM
t12 = np.array([0,1.832061069,11.45038168,16.48854962,67.78625954,119.0839695,122.7480916,127.7862595])
y12 = np.array([0,-0.03928571429,-0.05142857143,-0.05142857143,-0.04464285714,-0.04107142857,-0.002321428571,-0.00125])

# Yan P2X7 HEK ATP st 120s 1000 uM
t13 = np.array([0,0,7.328244275,25.64885496,32.97709924,53.58778626,79.23664122,94.80916031,107.1755725,118.6259542,120.9160305,122.2900763])
y13 = np.array([0,-0.0505952381,-0.06845238095,-0.08035714286,-0.09523809524,-0.2083333333,-0.5863095238,-0.8392857143,-0.8988095238,-0.9077380952,0.03273809524,0.002976190476])

# %%
data1a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_10uMATP_total_full_cat.pickle")
data2a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_total_full_cat.pickle")
data3a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_1000uMATP_total_full_cat.pickle")

stateLabel = "I_ptxf"
subData1a = ao.GetData(data1a,stateLabel)
subData2a = ao.GetData(data2a,stateLabel)
subData3a = ao.GetData(data3a,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(t19+1.2-300,y19*1000,'c--s',linewidth=1,markersize=10,label="Toulme et al. - 100 uM ATP")
plt.plot(subData1a.t,subData1a.valsIdx*(1e6)*1000,'b-',linewidth=2,label="Model - 10 uM ATP",alpha=1)
plt.plot(subData2a.t,subData2a.valsIdx*(1e6)*1000,'r-',linewidth=2,label="Model - 100 uM ATP",alpha=1)
plt.plot(subData3a.t,subData3a.valsIdx*(1e6)*1000,'g--',linewidth=2,label="Model - 1.0 mM ATP",alpha=1)

plt.plot([1.5,30+1.5],[0.3,0.3],'k',lw=7,label="ATP - Toulme")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)
#plt.ylim(-13.5,1)
#plt.yticks(np.arange(-400/30, 1, 100/30))
plt.xlim(0,40)
plt.tight_layout()
plt.legend(loc=0,fontsize=9)
# Out:
# Reading /home/AD/bch265/Data_storage/p2x4_Toulme30st_10uMATP_total_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_total_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x4_Toulme30st_1000uMATP_total_full_cat.pickle

# %%
data1a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_10uMATP_total_full_cat.pickle")
data2a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_total_full_cat.pickle")
data3a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_1000uMATP_total_full_cat.pickle")

stateLabel = "I_ptxf"
subData1a = ao.GetData(data1a,stateLabel)
subData2a = ao.GetData(data2a,stateLabel)
subData3a = ao.GetData(data3a,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(t19+1.2-300,y19*1000,'c--s',linewidth=1,markersize=10,label="Toulme et al. - 100 uM ATP")
plt.plot(subData1a.t,subData1a.valsIdx*(1e6)*1000,'b-',linewidth=2,label="Model - 10 uM ATP",alpha=1)
plt.plot(subData2a.t,subData2a.valsIdx*(1e6)*1000,'r-',linewidth=2,label="Model - 100 uM ATP",alpha=1)
plt.plot(subData3a.t,subData3a.valsIdx*(1e6)*1000,'g--',linewidth=2,label="Model - 1.0 mM ATP",alpha=1)

plt.plot([1.5,30+1.5],[0.3,0.3],'k',lw=7,label="ATP - Toulme")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)
#plt.ylim(-13.5,1)
#plt.yticks(np.arange(-400/30, 1, 100/30))
plt.xlim(0,40)
plt.tight_layout()
plt.legend(loc=0,fontsize=9)
# Out:
# Reading /home/AD/bch265/Data_storage/p2x4_Toulme30st_10uMATP_total_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_total_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x4_Toulme30st_1000uMATP_total_full_cat.pickle

# %%
#data1a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_10uMATP_CaT_cat.pickle")

data2a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_CaT_cat.pickle")
#data3a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_1000uMATP_CaT_cat.pickle")

stateLabel = "Cai"
subData1a = ao.GetData(data1a,stateLabel)
subData2a = ao.GetData(data2a,stateLabel)
subData3a = ao.GetData(data3a,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
#plt.plot(t19+1.2-300,y19*1000,'c--s',linewidth=1,markersize=10,label="Toulme et al. - 100 uM ATP")
#plt.plot(subData1a.t,(subData1a.valsIdx*(1e0)+0.04)-0.1,'b-',linewidth=2,label="Model - 10 uM ATP",alpha=1)
plt.plot(subData2a.t,1000*(subData2a.valsIdx*(1e0)-subData2a.valsIdx[400]),'r-',linewidth=2,label="Activated - 100 uM ATP - 1055 nM at peak",alpha=1)
plt.plot(subData2a.t,1000*(subData2a.valsIdx*(1e0)-subData2a.valsIdx[400])/30,'b-',linewidth=2,label="Rest - 100 uM ATP - 35 nM at peak",alpha=1)
plt.plot([1.5,30+1.5],[-50,-50],'k',lw=7,label="ATP - Toulme")

#plt.plot(subData3a.t,(subData3a.valsIdx*(1e0)+0.04)-0.1,'g--',linewidth=2,label="Model - 1.0 mM ATP",alpha=1)

#plt.plot([1.5,30+1.5],[0.3,0.3],'k',lw=7,label="ATP - Toulme")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("dCa (nM)",fontsize=12)
#plt.ylim(0.09,0.11)
#plt.yticks(np.arange(-400/30, 1, 100/30))
plt.xlim(0.1,35)
plt.tight_layout()
plt.legend(loc=0,fontsize=12)

print(max(1000*(subData2a.valsIdx*(1e0)-subData2a.valsIdx[400])), max(1000*(subData2a.valsIdx*(1e0)-subData2a.valsIdx[400])/30))
# Out:
# Reading /home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_CaT_cat.pickle
# (1055.8148132024751, 35.193827106749168)

# %%
data2a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_total_full_cat.pickle")

stateLabel = "I_4"
subData1 = ao.GetData(data2a,stateLabel)
stateLabel = "I_ptxf"
subData2 = ao.GetData(data2a,stateLabel)


plt.figure(figsize=(7,7),dpi=200)
plt.subplot(2,1,1)
plt.tick_params(labelsize=12)
plt.plot(t19+1.2-300,y19*1000,'b--s',linewidth=1,markersize=10,label="Toulme et al. - 100 uM ATP")
plt.plot(subData1.t,subData1.valsIdx*(1e6)*1000*30,'r-',linewidth=2,label="Full - 100 uM ATP",alpha=1)
plt.plot(subData2.t,subData2.valsIdx*(1e6)*1000*30,'g--x',linewidth=2,label="Lumped - 100 uM ATP",alpha=1)

plt.plot([1.5,30+1.5],[20,20],'k',lw=5,label="ATP - Toulme")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)
#plt.ylim(-13.5,1)
#plt.yticks(np.arange(-400/30, 1, 100/30))
plt.xlim(0,40)
plt.tight_layout()
plt.legend(loc=0,fontsize=9)

plt.subplot(2,1,2)
plt.tick_params(labelsize=12)
plt.plot(subData1.t,subData1.valsIdx*(1e6)*1000*30,'r-',linewidth=4,label="Full - 100 uM ATP",alpha=1)
plt.plot(subData2.t,subData2.valsIdx*(1e6)*1000*30,'k--',linewidth=2,label="Lumped - 100 uM ATP",alpha=1)

#plt.plot([1.5,30+1.5],[20,20],'k',lw=5,label="ATP - Toulme")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)
#plt.ylim(-13.5,1)
#plt.yticks(np.arange(-400/30, 1, 100/30))
plt.xlim(-5,350)
plt.tight_layout()
plt.legend(loc=0,fontsize=9)
# Out:
# Reading /home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_total_full_cat.pickle

# %%
data2a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_total_full_cat.pickle")

stateLabel = "I_4"
subData1 = ao.GetData(data2a,stateLabel)
stateLabel = "I_ptxf"
subData2 = ao.GetData(data2a,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(t19+1.2-300,y19*1000,'b--s',linewidth=1,markersize=10,label="Toulme et al. - 100 uM ATP")
plt.plot(subData1.t,subData1.valsIdx*(1e6)*1000*30,'r-',linewidth=2,label="Full - 100 uM ATP",alpha=1)

T0 = np.linspace(0,40,50)  # point at t=0 was pretty bad
V0 = np.interp(T0,subData2.t-300,subData2.valsIdx*(1e6)*1000*30)

plt.plot(T0,V0,'go',linewidth=2,label="Lumped - 100 uM ATP",alpha=1)

plt.plot([1.5,30+1.5],[20,20],'k',lw=5,label="ATP - Toulme")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)
#plt.ylim(-13.5,1)
#plt.yticks(np.arange(-400/30, 1, 100/30))
plt.xlim(0,40)
plt.tight_layout()
plt.legend(loc=0,fontsize=9)

#plt.plot([1.5,30+1.5],[20,20],'k',lw=5,label="ATP - Toulme")
# Out:
# Reading /home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_total_full_cat.pickle

# %%
data2a = ao.readPickle("/home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_total_full_cat.pickle")

stateLabel = "I_4"
subData1 = ao.GetData(data2a,stateLabel)
stateLabel = "I_ptxf"
subData2 = ao.GetData(data2a,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
#plt.plot(t19+1.2-300,y19*1000,'b--s',linewidth=1,markersize=10,label="Toulme et al. - 100 uM ATP")
plt.plot(subData1.t,subData1.valsIdx*(1e6)*1000*30,'r-',linewidth=8,label="Full - 100 uM ATP",alpha=1)

T0 = np.linspace(0,40,150)  # point at t=0 was pretty bad
V0 = np.interp(T0,subData2.t-300,subData2.valsIdx*(1e6)*1000*30)

plt.plot(T0,V0,'go',linewidth=2,label="Lumped - 100 uM ATP",alpha=1)

#plt.plot([1.5,30+1.5],[20,20],'k',lw=5,label="ATP - Toulme")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)
#plt.ylim(-13.5,1)
#plt.yticks(np.arange(-400/30, 1, 100/30))
plt.xlim(0,40)
plt.tight_layout()
plt.legend(loc=0,fontsize=9)

#plt.plot([1.5,30+1.5],[20,20],'k',lw=5,label="ATP - Toulme")
# Out:
# Reading /home/AD/bch265/Data_storage/p2x4_Toulme30st_100uMATP_total_full_cat.pickle

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_100uMATP_full_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_1000uMATP_full_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_3000uMATP_full_cat.pickle")

stateLabel2 = "I_pxsC"
subData1a = ao.GetData(data1,stateLabel2)
subData2a = ao.GetData(data2,stateLabel2)
subData3a = ao.GetData(data3,stateLabel2)

# Chessel P2X7 HEK ATP st 3s 30-100 uM
t1 = np.array([0,0.88,1.63,2.65,3.15])
y1 = np.array([0,-4.67,-18.7,-21.0,4.67])/2
# Chessel non saturated 1mM
t2 = np.array([0, 0.33,0.71,1.07,1.19,1.34,1.72,2.77])
y2 = np.array([0,-5.21,-26.0,-458.3,-218.75,-114.58,-57.29,-10.42])
# Chessel non saturated 3mM
t3 = np.array([0,0.38,0.64,0.91,1.16,1.27,1.44,1.77,2.41,3.21])
y3 = np.array([0,-15.625,-177.08,-473.96,-875,-447.92,-296.875,-177.08,-72.92,-31.25])

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(subData1a.t,subData1a.valsIdx*(10**9),'b-',linewidth=1,label="Model - 0.1 mM ATP")
plt.plot(subData2a.t,subData2a.valsIdx*(10**9),'r-',linewidth=1,label="Model - 1.0 mM ATP")
plt.plot(subData3a.t,subData3a.valsIdx*(10**9),'g-',linewidth=1,label="Model - 3.0 mM ATP")
plt.plot(t1+1,y1,'b--x',label="Chessel et al.- 0.1 mM ATP")
plt.plot(t2+1.35,y2,'r--x',label="Chessel-1.0 mM ATP")
plt.plot(t3+1.35,y3,'g--x',label="Chessel-3.0 mM ATP")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)
plt.plot([1.5,2.5],[30,30],'k',lw=5,label="ATP")
plt.xlim(0,5)
plt.ylim(-900,300)
plt.legend(loc=0,fontsize=10) 
plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_100uMATP_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_1000uMATP_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_3000uMATP_full_cat.pickle

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_100uMATP_full_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_1000uMATP_full_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_3000uMATP_full_cat.pickle")

stateLabel2 = "I_pxsC"
subData1a = ao.GetData(data1,stateLabel2)
subData2a = ao.GetData(data2,stateLabel2)
subData3a = ao.GetData(data3,stateLabel2)

# Chessel P2X7 HEK ATP st 3s 30-100 uM
t1 = np.array([0,0.88,1.63,2.65,3.15])
y1 = np.array([0,-4.67,-18.7,-21.0,4.67])/2
# Chessel non saturated 1mM
t2 = np.array([0, 0.33,0.71,1.07,1.19,1.34,1.72,2.77])
y2 = np.array([0,-5.21,-26.0,-458.3,-218.75,-114.58,-57.29,-10.42])
# Chessel non saturated 3mM
t3 = np.array([0,0.38,0.64,0.91,1.16,1.27,1.44,1.77,2.41,3.21])
y3 = np.array([0,-15.625,-177.08,-473.96,-875,-447.92,-296.875,-177.08,-72.92,-31.25])

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(subData1a.t,subData1a.valsIdx*(10**9),'b-',linewidth=1,label="Model - 0.1 mM ATP")
plt.plot(subData2a.t,subData2a.valsIdx*(10**9),'r-',linewidth=1,label="Model - 1.0 mM ATP")
plt.plot(subData3a.t,subData3a.valsIdx*(10**9),'g-',linewidth=1,label="Model - 3.0 mM ATP")
plt.plot(t1+1,y1,'b--x',label="Chessel et al.- 0.1 mM ATP")
plt.plot(t2+1.35,y2,'r--x',label="Chessel-1.0 mM ATP")
plt.plot(t3+1.35,y3,'g--x',label="Chessel-3.0 mM ATP")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)
plt.plot([1.5,2.5],[30,30],'k',lw=5,label="ATP")
plt.xlim(0,5)
plt.ylim(-900,300)
plt.legend(loc=0,fontsize=10) 
plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_100uMATP_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_1000uMATP_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_3000uMATP_full_cat.pickle

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_100uMATP_full_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_1000uMATP_full_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_3000uMATP_full_cat.pickle")

stateLabel2 = "I_pxsC"
subData1a = ao.GetData(data1,stateLabel2)
subData2a = ao.GetData(data2,stateLabel2)
subData3a = ao.GetData(data3,stateLabel2)


stateLabel2 = "I_pxsL"
subData1b = ao.GetData(data1,stateLabel2)
subData2b = ao.GetData(data2,stateLabel2)
subData3b = ao.GetData(data3,stateLabel2)


plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(subData1a.t,subData1a.valsIdx*(10**9),'b-',linewidth=1,label="Full - 100 uM ATP")
plt.plot(subData2a.t,subData2a.valsIdx*(10**9),'r-',linewidth=1,label="Full - 1000 uM ATP")
plt.plot(subData3a.t,subData3a.valsIdx*(10**9),'g-',linewidth=1,label="Full - 3000 uM ATP")
plt.plot(subData1b.t,subData1b.valsIdx*(10**9),'b--',linewidth=2.5,label="Lumped - 100 uM ATP")
plt.plot(subData2b.t,subData2b.valsIdx*(10**9),'r--',linewidth=2.5,label="Lumped - 1000 uM ATP")
plt.plot(subData3b.t,subData3b.valsIdx*(10**9),'g--',linewidth=2.5,label="Lumped - 3000 uM ATP")
plt.plot(t1+1,y1,'b--x',label="Chessel et al.- 100 uM ATP")
plt.plot(t2+1.35,y2,'r--x',label="Chessel-1000 uM ATP")
plt.plot(t3+1.35,y3,'g--x',label="Chessel-3000 uM ATP")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)
plt.plot([1.5,2.5],[30,30],'k',lw=5,label="ATP")
plt.xlim(0,5)
plt.ylim(-900,300)
plt.legend(loc=0,fontsize=10) 
plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_100uMATP_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_1000uMATP_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_3000uMATP_full_cat.pickle

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_100uMATP_full_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_1000uMATP_full_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/p2x7_Chessel1st_3000uMATP_full_cat.pickle")

stateLabel2 = "I_ptxs"
subData1a = ao.GetData(data1,stateLabel2)
subData2a = ao.GetData(data2,stateLabel2)
subData3a = ao.GetData(data3,stateLabel2)


stateLabel2 = "I_ptxsL"
subData1b = ao.GetData(data1,stateLabel2)
subData2b = ao.GetData(data2,stateLabel2)
subData3b = ao.GetData(data3,stateLabel2)


plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(subData1a.t,subData1a.valsIdx*(10**9),'b-',linewidth=1,label="Full - 0.1 mM ATP")
plt.plot(subData2a.t,subData2a.valsIdx*(10**9),'r-',linewidth=1,label="Full - 1.0 mM ATP")
plt.plot(subData3a.t,subData3a.valsIdx*(10**9),'g-',linewidth=1,label="Full - 3.0 mM ATP")
plt.plot(subData1b.t,subData1b.valsIdx*(10**9),'b-',linewidth=3,label="Lumped - 0.1 mM ATP")
plt.plot(subData2b.t,subData2b.valsIdx*(10**9),'r-',linewidth=3,label="Lumped - 1.0 mM ATP")
plt.plot(subData3b.t,subData3b.valsIdx*(10**9),'g-',linewidth=3,label="Lumped - 3.0 mM ATP")
plt.plot(t1+1,y1,'b--x',label="Chessel et al.- 0.1 uM ATP")
plt.plot(t2+1.35,y2,'r--x',label="Chessel-1.0 uM ATP")
plt.plot(t3+1.35,y3,'g--x',label="Chessel-3.0 mM ATP")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)
plt.plot([1.5,2.5],[30,30],'k',lw=5,label="ATP")
plt.xlim(0,5)
plt.ylim(-900,300)
plt.legend(loc=0,fontsize=10) 
plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_100uMATP_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_1000uMATP_full_cat.pickle
# Reading /home/AD/bch265/Data_storage/p2x7_Chessel1st_3000uMATP_full_cat.pickle

# %%
#stateLabel1 = "I_ptxf"
#subData0 = ao.GetData(data0,stateLabel1)
stateLabel2 = "I_ptxs"
subData1 = ao.GetData(data2,stateLabel2)
subData2 = ao.GetData(data3,stateLabel2)
subData3 = ao.GetData(data4,stateLabel2)

subData1a = ao.GetData(data2a,stateLabel2)
subData2a = ao.GetData(data3a,stateLabel2)
subData3a = ao.GetData(data4a,stateLabel2)

plt.figure(figsize=(7,7),dpi=200)
ax = plt.subplot(1,1,1)
ax2 = ax.twinx()
ax.tick_params(labelsize=12)
ax2.tick_params(labelsize=12)
lns1 = ax.plot(subData1.t,subData1.valsIdx*10**9,'b-',label="Model - 100 uM ATP")
lns2 = ax.plot(subData2.t,subData2.valsIdx*10**9,'r-',label="Model - 320 uM ATP")
lns3 = ax2.plot(subData3.t,subData3.valsIdx*10**6,'g-',label="Model - 1.0 mM ATP")
lns4 = ax.plot(t12,y12*10**3,'b--x',label="Yan - 100 uM ATP")
lns5 = ax.plot(t11,y11*10**3,'r--x',label="Yan - 320 uM ATP")
lns6 = ax2.plot(t15,y15,'g--x',label="Yan - 1.0 mM ATP")
lns7 = ax2.plot([0,120],[0.02,0.02],'black',lw=5,label="ATP")
ax.set_xlabel("time (s)",fontsize=15)
ax.set_ylabel("I for 0.1 & 0.32 mM (pA)",fontsize=15)
ax2.set_ylabel("I for 1 mM (nA)",fontsize=15)
ax.set_ylim(-63,3)
ax2.set_ylim(-1.1,0.05)
ax.set_xlim(-10,130)
ax2.set_xlim(-10,130)
lns = lns1 + lns4 + lns2 + lns5 + lns3 + lns6 + lns7
labs = [l.get_label() for l in lns]
ax.legend(lns,labs,loc=3,fontsize=12) 
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-3c5475b17ccf> in <module>()
#       2 #subData0 = ao.GetData(data0,stateLabel1)
#       3 stateLabel2 = "I_ptxs"
# ----> 4 subData1 = ao.GetData(data2,stateLabel2)
#       5 subData2 = ao.GetData(data3,stateLabel2)
#       6 subData3 = ao.GetData(data4,stateLabel2)
#
# NameError: name 'data2' is not defined
