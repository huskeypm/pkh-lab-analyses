# %%
# %matplotlib inline

import matplotlib.pylab as plt 

# routlines for analyzing odes
import sys
import pickle as pk
import numpy as np
import math
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/P2X-project/pkh-code/fitting')
import analyzeGotran as ao

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

stateLabel = "Cai"
x0 = ao.GetData(data0,stateLabel)
x1 = ao.GetData(data1,stateLabel)
x2 = ao.GetData(data2,stateLabel)
x3 = ao.GetData(data3,stateLabel)

stateLabel = "CaF"
a0 = ao.GetData(data0,stateLabel)
a1 = ao.GetData(data1,stateLabel)
a2 = ao.GetData(data2,stateLabel)
a3 = ao.GetData(data3,stateLabel)

stateLabel = "Ca2_CaM"
b0 = ao.GetData(data0,stateLabel)
b1 = ao.GetData(data1,stateLabel)
b2 = ao.GetData(data2,stateLabel)
b3 = ao.GetData(data3,stateLabel)

stateLabel = "Ca4_CaM"
c0 = ao.GetData(data0,stateLabel)
c1 = ao.GetData(data1,stateLabel)
c2 = ao.GetData(data2,stateLabel)
c3 = ao.GetData(data3,stateLabel)

stateLabel = "Ca2_CN"
d0 = ao.GetData(data0,stateLabel)
d1 = ao.GetData(data1,stateLabel)
d2 = ao.GetData(data2,stateLabel)
d3 = ao.GetData(data3,stateLabel)

stateLabel = "Ca4_CN"
e0 = ao.GetData(data0,stateLabel)
e1 = ao.GetData(data1,stateLabel)
e2 = ao.GetData(data2,stateLabel)
e3 = ao.GetData(data3,stateLabel)

stateLabel = "CaBex"
f0 = ao.GetData(data0,stateLabel)
f1 = ao.GetData(data1,stateLabel)
f2 = ao.GetData(data2,stateLabel)
f3 = ao.GetData(data3,stateLabel)

all0 = a0.valsIdx + (b0.valsIdx + c0.valsIdx + d0.valsIdx + e0.valsIdx) + f0.valsIdx
all1 = a1.valsIdx + (b1.valsIdx + c1.valsIdx + d1.valsIdx + e1.valsIdx) + f1.valsIdx
all2 = a2.valsIdx + (b2.valsIdx + c2.valsIdx + d2.valsIdx + e2.valsIdx) + f2.valsIdx
all3 = a3.valsIdx + (b3.valsIdx + c3.valsIdx + d3.valsIdx + e3.valsIdx) + f3.valsIdx

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
#plt.plot((x0.t-800)/60+0.9,(a0.valsIdx-a3.valsIdx),'g--',label="By Fura2 - 1.0 mM [ATP]")
#plt.plot((x1.t-800)/60+0.9,(a1.valsIdx-a3.valsIdx),'b--',label="By Fura2 - 100 uM [ATP]")
#plt.plot((x2.t-800)/60+0.9,(a2.valsIdx-a3.valsIdx),'r--',label="By Fura2 - 10 uM [ATP]")

plt.plot((a0.t-800)/60+0.9,(all0-all3),'g-',label="By all buffers - 1.0 mM [ATP]")
plt.plot((a1.t-800)/60+0.9,(all1-all3),'b-',label="By all buffers - 100 uM [ATP]")
plt.plot((a2.t-800)/60+0.9,(all2-all3),'r-',label="By all buffers - 10 uM [ATP]")

plt.plot([1,7.5],[-0.25,-0.25],'k',label='ATP',linewidth=7)

plt.xlabel("time (min)",fontsize=12)
plt.ylabel("Buffered amount of Ca (uM)",fontsize=12)
plt.xlim(0,9)
#plt.ylim(468.5,468.75)
plt.legend(loc=0,fontsize=10)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")

stateLabel = "Cai"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx),'g-',label="Control - 1.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx),'b-',label="Control - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx),'r-',label="Control - 10 uM [ATP]")

data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoFura_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoFura_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoFura_0.01mMATP_cat.pickle")

stateLabel = "Cai"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)

plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx),'g--',label="No Fura - 1.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx),'b--',label="No Fura - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx),'r--',label="No Fura - 10 uM [ATP]")

data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoBuffer_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoBuffer_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoBuffer_0.01mMATP_cat.pickle")

stateLabel = "Cai"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)

plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx),'g-x',label="No Buffer - 1.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx),'b-x',label="No Buffer - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx),'r-x',label="No Buffer - 10 uM [ATP]")

#plt.plot([1,7.5],[-5,-5],'k',label='ATP',linewidth=7)

plt.xlabel("time (min)",fontsize=12)
plt.ylabel("[Ca] (uM)",fontsize=12)
#plt.xlim(0,9)
#plt.ylim(-8,60)
plt.legend(loc=0,fontsize=10)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoFura_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoFura_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoFura_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoBuffer_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoBuffer_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoBuffer_0.01mMATP_cat.pickle
