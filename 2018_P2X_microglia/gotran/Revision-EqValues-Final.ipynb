# %%
# %matplotlib inline

import matplotlib.pylab as plt 


# routlines for analyzing odes
import sys
import pickle as pk
import numpy as np
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/P2X-project/pkh-code/fitting')
import analyzeGotran as ao

# %%
data = ao.readPickle("/home/AD/bch265/Data_storage/MG_0mMATP_cat.pickle")

stateLabel = "Cai"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "CaF"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "Ca2_CaM"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "Ca4_CaM"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "Ca4_CN"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "CaMCN"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "CaER"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "CaS"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "CaBex"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "NFATpc"
subData = ao.GetData(data,stateLabel)
print stateLabel
N1 = subData.valsIdx[-1]
print N1

stateLabel = "NFATpn"
subData = ao.GetData(data,stateLabel)
print stateLabel
N2 = subData.valsIdx[-1]
print N2

stateLabel = "NFATNc"
subData = ao.GetData(data,stateLabel)
print stateLabel
N3 = subData.valsIdx[-1]
print N3

stateLabel = "NFATNn"
subData = ao.GetData(data,stateLabel)
print stateLabel
N3 = subData.valsIdx[-1]
print N3

stateLabel = "pp38"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "DNA_TNF"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "DNATNF"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "mRNA_TNF"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

stateLabel = "TNFa"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]

#stateLabel = "TNFa_release"
#subData = ao.GetData(data,stateLabel)
#print stateLabel
#print subData.valsIdx[-1]

stateLabel = "Ca2_CN"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]
# Out:
# Reading /home/AD/bch265/Data_storage/MG_0mMATP_cat.pickle
# Cai
# 0.100038045982
# CaF
# 9.87069319474
# Ca2_CaM
# 0.0291451336519
# Ca4_CaM
# 0.00291673149752
# Ca4_CN
# 0.0381531280412
# CaMCN
# 0.0556412151435
# CaER
# 734.157542602
# CaS
# 74.2560386378
# CaBex
# 0.90940532782
# NFATpc
# 0.805184759841
# NFATpn
# 0.121273003976
# NFATNc
# 0.0374767269231
# NFATNn
# 0.236065509259
# pp38
# 52.5777259093
# DNA_TNF
# 40.8723010085
# DNATNF
# 6.92769899133
# mRNA_TNF
# 29.4794592715
# TNFa
# 0.42450389403
# Ca2_CN
# 1.90620565682

# %%
data = ao.readPickle("/home/AD/bch265/Data_storage/MG_0mMATP_cat.pickle")

stateLabel = "TNFa"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]
plt.figure(figsize=(7,7),dpi=100)
plt.tick_params(labelsize=12)
plt.plot((subData.t),(subData.valsIdx),'g-',label="TNFa")
# Out:
# Reading /home/AD/bch265/Data_storage/MG_0mMATP_cat.pickle
# TNFa
# 0.42450389403

# %%
stateLabel = "Cai"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]
plt.figure(figsize=(7,7),dpi=100)
plt.tick_params(labelsize=12)
plt.plot((subData.t),(subData.valsIdx),'g-',label="Cai - nM")

stateLabel = "CaF"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]
plt.figure(figsize=(7,7),dpi=100)
plt.tick_params(labelsize=12)
plt.plot((subData.t),(subData.valsIdx),'g-',label="Cai - nM")

stateLabel = "CaER"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]
plt.figure(figsize=(7,7),dpi=100)
plt.tick_params(labelsize=12)
plt.plot((subData.t),(subData.valsIdx),'g-',label="Cai - nM")

stateLabel = "CaS"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]
plt.figure(figsize=(7,7),dpi=100)
plt.tick_params(labelsize=12)
plt.plot((subData.t),(subData.valsIdx),'g-',label="Cai - nM")

stateLabel = "CaBex"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]
plt.figure(figsize=(7,7),dpi=100)
plt.tick_params(labelsize=12)
plt.plot((subData.t),(subData.valsIdx),'g-',label="Cai - nM")

stateLabel = "NFATNn"
subData = ao.GetData(data,stateLabel)
print stateLabel
print subData.valsIdx[-1]
plt.figure(figsize=(7,7),dpi=100)
plt.tick_params(labelsize=12)
plt.plot((subData.t),(subData.valsIdx),'g-',label="NFATNn - uM")
# Out:
# Cai
# 0.0881931621387
# CaF
# 9.12872539784
# CaER
# 597.256498834
# CaS
# 67.0398670321
# CaBex
# 121.568254434
# NFATNn
# 0.12696375886

# %%
# Out:
# 1.1704809999999999
