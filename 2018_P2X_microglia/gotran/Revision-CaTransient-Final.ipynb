# %%
# %matplotlib inline

import matplotlib.pylab as plt 

# routlines for analyzing odes
import sys
import pickle as pk
import numpy as np
import math
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/P2X-project/pkh-code/fitting')
import analyzeGotran as ao

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")
# Hide's Data #################################################################
ly1 = np.array([0,0,27.11,36.42,17.8,-1.62,-6.47])
ly2 = np.array([0,-0.40,46.93,35.61,35.2,39.65,39.6,17.4,10.9,7.28,4.45,3.6])
ly3 = np.array([0,0,52.60,26.71,27.11,25.9,21.4,19.0,17,17,16.18])

lt1 = np.array([0,1.18,1.26,1.7,2.3,3.41,7.63])
lt2 = np.array([0,1.18,1.33,1.48,1.56,1.85,2.15,3.56,4.15,4.96,6.22,7.48])
lt3 = np.array([0,1.41,1.56,1.78,2.07,2.37,2.74,2.96,3.93,6.59,7.70])
###############################################################################

stateLabel = "Cai"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData0.t)/60+0.9,(subData0.valsIdx-subData3.valsIdx)*1000,'g-',linewidth=1.5,label="Model - 1000 uM [ATP]")
plt.plot((subData1.t)/60+0.9,(subData1.valsIdx-subData3.valsIdx)*1000,'b-',linewidth=1.5,label="Model - 100 uM [ATP]")
plt.plot((subData2.t)/60+0.9,(subData2.valsIdx-subData3.valsIdx)*1000,'r-',linewidth=1.5,label="Model - 10 uM [ATP]")

plt.plot(lt3-0.5,ly3,'g--',alpha=0.8,linewidth=2,label="Hide et al. - 1000 uM [ATP]")
plt.plot(lt2-0.3,ly2,'b--',alpha=0.8,linewidth=2,label="Hide et al. - 100 uM [ATP]")
plt.plot(lt1-0.3,ly1,'r--',alpha=0.8,linewidth=2,label="Hide et al. - 10 uM [ATP]") 

plt.plot([1,7.5],[-5,-5],'k',label='ATP',linewidth=7)

plt.xlabel("time (min)",fontsize=12)
plt.ylabel("d[Ca] (nM)",fontsize=12)
plt.xlim(0,9)
#plt.ylim(-8,60)
plt.legend(loc=0,fontsize=10)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

stateLabel1 = "I_ptxsL"
subData11 = ao.GetData(data0,stateLabel1)
subData12 = ao.GetData(data1,stateLabel1)
subData13 = ao.GetData(data2,stateLabel1)
subData14 = ao.GetData(data3,stateLabel1)

stateLabel2 = "I_ptxf"
subData21 = ao.GetData(data0,stateLabel2)
subData22 = ao.GetData(data1,stateLabel2)
subData23 = ao.GetData(data2,stateLabel2)
subData24 = ao.GetData(data3,stateLabel2)

stateLabel3 = "INCX"
subData31 = ao.GetData(data0,stateLabel3)
subData32 = ao.GetData(data1,stateLabel3)
subData33 = ao.GetData(data2,stateLabel3)
subData34 = ao.GetData(data3,stateLabel3)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData21.t-800)/60+0.9,subData21.valsIdx*1e9,'g-',linewidth=1.5,label="P2X4 - 1000 uM [ATP]")
plt.plot((subData22.t-800)/60+0.9,subData22.valsIdx*1e9,'b-',linewidth=1.5,label="P2X4 - 100 uM [ATP]")
plt.plot((subData23.t-800)/60+0.9,subData23.valsIdx*1e9,'r-',linewidth=1.5,label="P2X4 - 10 uM [ATP]")
plt.plot((subData11.t-800)/60+0.9,subData11.valsIdx*1e9,'g--',linewidth=1.5,label="P2X7 - 1000 uM [ATP]")
plt.plot((subData12.t-800)/60+0.9,subData12.valsIdx*1e9,'b--',linewidth=1.5,label="P2X7 - 100 uM [ATP]")
plt.plot((subData13.t-800)/60+0.9,subData13.valsIdx*1e9,'r--',linewidth=1.5,label="P2X7 - 10 uM [ATP]")
plt.plot([1,7.5],[5,5],'k',label='ATP',linewidth=7)

plt.xlabel("time (min)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)

plt.legend(loc=0,fontsize=10) 

plt.xlim(0/60,9)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

stateLabel = "CaER"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx)/1000,'g-',label="Model - 1000 uM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx)/1000,'b-',label="Model - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx)/1000,'r-',label="Model - 10 uM [ATP]")
plt.plot([1,7.5],[0.64,0.64],'k',label='ATP',linewidth=7)

plt.xlim(0/60,9)
#plt.ylim(0,0.6)
plt.legend(loc=0,fontsize=10)
plt.xlabel("time (min)",fontsize=12)
plt.ylabel("CaER (mM)",fontsize=12)
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")
# Hide's Data #################################################################
ly1 = np.array([0,0,27.11,36.42,17.8,-1.62,-6.47])
ly2 = np.array([0,-0.40,46.93,35.61,35.2,39.65,39.6,17.4,10.9,7.28,4.45,3.6])
ly3 = np.array([0,0,52.60,26.71,27.11,25.9,21.4,19.0,17,17,16.18])

lt1 = np.array([0,1.18,1.26,1.7,2.3,3.41,7.63])
lt2 = np.array([0,1.18,1.33,1.48,1.56,1.85,2.15,3.56,4.15,4.96,6.22,7.48])
lt3 = np.array([0,1.41,1.56,1.78,2.07,2.37,2.74,2.96,3.93,6.59,7.70])
###############################################################################

stateLabel = "Cai"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx-subData3.valsIdx)*1000,'g-',label="Model - 1000 uM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx-subData3.valsIdx)*1000,'b-',label="Model - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx-subData3.valsIdx)*1000,'r-',label="Model - 10 uM [ATP]")

plt.plot(lt3-0.5,ly3,'g--',alpha=0.8,label="Hide et al. - 1000 uM [ATP]")
plt.plot(lt2-0.3,ly2,'b--',alpha=0.8,label="Hide et al. - 100 uM [ATP]")
plt.plot(lt1-0.3,ly1,'r--',alpha=0.8,label="Hide et al. - 10 uM [ATP]") 

plt.plot([1,7.5],[-5,-5],'k',label='ATP',linewidth=7)

plt.xlabel("time (min)",fontsize=12)
plt.ylabel("d[Ca] (nM)",fontsize=12)
plt.xlim(0,9)
#plt.ylim(-8,60)
plt.legend(loc=0,fontsize=10)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")


plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
ax = plt.subplot(1,1,1)
#ax2 = ax.twinx()
ax.tick_params(labelsize=12)
#ax2.tick_params(labelsize=12)

stateLabel = "JERtoCy"
lea0 = ao.GetData(data0,stateLabel)
lea1 = ao.GetData(data1,stateLabel)
lea2 = ao.GetData(data2,stateLabel)
lea3 = ao.GetData(data3,stateLabel)
stateLabel = "JExtoCy"
lea4 = ao.GetData(data0,stateLabel)
lea5 = ao.GetData(data1,stateLabel)
lea6 = ao.GetData(data2,stateLabel)
lea7 = ao.GetData(data3,stateLabel)
stateLabel = "J_ptxs"
i0 = ao.GetData(data0,stateLabel)
i1 = ao.GetData(data1,stateLabel)
i2 = ao.GetData(data2,stateLabel)
i3 = ao.GetData(data3,stateLabel)
stateLabel = "J_ptxf"
i4 = ao.GetData(data0,stateLabel)
i5 = ao.GetData(data1,stateLabel)
i6 = ao.GetData(data2,stateLabel)
i7 = ao.GetData(data3,stateLabel)
l1=ax.plot((lea0.t-800)/60+0.9,(lea0.valsIdx+lea4.valsIdx+i0.valsIdx+i4.valsIdx)
           ,'g-',label="Influx - 1000 uM [ATP]")
l2=ax.plot((lea1.t-800)/60+0.9,(lea1.valsIdx+lea5.valsIdx+i1.valsIdx+i5.valsIdx)
           ,'b-',label="Influx - 100 uM [ATP]")
l3=ax.plot((lea2.t-800)/60+0.9,(lea2.valsIdx+lea6.valsIdx+i2.valsIdx+i6.valsIdx)
           ,'r-',label="Influx - 10 uM [ATP]")

stateLabel = "JNCX"
unb0 = ao.GetData(data0,stateLabel)
unb1 = ao.GetData(data1,stateLabel)
unb2 = ao.GetData(data2,stateLabel)
unb3 = ao.GetData(data3,stateLabel)
stateLabel = "JCyttoER"
unb4 = ao.GetData(data0,stateLabel)
unb5 = ao.GetData(data1,stateLabel)
unb6 = ao.GetData(data2,stateLabel)
unb7 = ao.GetData(data3,stateLabel)
l7=ax.plot((unb3.t-800)/60+0.9,(unb0.valsIdx-unb4.valsIdx),'g--',alpha=1,label="Efflux - 1000 uM [ATP]")
l8=ax.plot((unb2.t-800)/60+0.9,(unb1.valsIdx-unb5.valsIdx),'b--',alpha=1,label="Efflux - 100 uM [ATP]")
l9=ax.plot((unb1.t-800)/60+0.9,(unb2.valsIdx-unb6.valsIdx),'r--',alpha=1,label="Efflux - 10 uM [ATP]") 

l10=ax.plot([1,7.5],[0,0],'k',label='ATP',linewidth=7)

ax.set_xlabel("Time (min)",fontsize=12)
ax.set_ylabel("Flux rate (mM/s)",fontsize=12)
#ax2.set_ylabel("Rate (mM/s)",fontsize=15)

lns = l1 + l2 + l3 + l7 + l8 + l9 + l10 
labs = [l.get_label() for l in lns]

ax.legend(lns,labs,loc=0,fontsize=10) 

plt.xlim(0,9)
#ax2.set_ylim(-0.4,2.5)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")
data4 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MGlumped_1mMATP_cat.pickle")
data5 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MGlumped_0.1mMATP_cat.pickle")
data6 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MGlumped_0.01mMATP_cat.pickle")

stateLabel = "Cai"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)
subData4 = ao.GetData(data4,stateLabel)
subData5 = ao.GetData(data5,stateLabel)
subData6 = ao.GetData(data6,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx-subData3.valsIdx)*1000,'g-',label="Full - 1.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx-subData3.valsIdx)*1000,'b-',label="Full - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx-subData3.valsIdx)*1000,'r-',label="Full - 10 uM [ATP]")
plt.plot((subData4.t-800)/60+0.9,(subData4.valsIdx-subData3.valsIdx)*1000,'g--',linewidth=2,label="Lumped - 1.0 mM [ATP]")
plt.plot((subData5.t-800)/60+0.9,(subData5.valsIdx-subData3.valsIdx)*1000,'b--',linewidth=2,label="Lumped - 100 uM [ATP]")
plt.plot((subData6.t-800)/60+0.9,(subData6.valsIdx-subData3.valsIdx)*1000,'r--',linewidth=2,label="Lumped - 10 uM [ATP]")

plt.plot([1,7.5],[-5,-5],'k',label='ATP',linewidth=7)

plt.xlabel("time (min)",fontsize=12)
plt.ylabel("d[Ca] (nM)",fontsize=12)
plt.xlim(0,9)
#plt.ylim(-8,60)
plt.legend(loc=0,fontsize=10)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MGlumped_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MGlumped_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MGlumped_0.01mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

data4 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_2mMATP_cat.pickle")
data5 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_3mMATP_cat.pickle")
data6 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_5mMATP_cat.pickle")

# Hide's Data #################################################################
ly1 = np.array([0,0,27.11,36.42,17.8,-1.62,-6.47])
ly2 = np.array([0,-0.40,46.93,35.61,35.2,39.65,39.6,17.4,10.9,7.28,4.45,3.6])
ly3 = np.array([0,0,52.60,26.71,27.11,25.9,21.4,19.0,17,17,16.18])

lt1 = np.array([0,1.18,1.26,1.7,2.3,3.41,7.63])
lt2 = np.array([0,1.18,1.33,1.48,1.56,1.85,2.15,3.56,4.15,4.96,6.22,7.48])
lt3 = np.array([0,1.41,1.56,1.78,2.07,2.37,2.74,2.96,3.93,6.59,7.70])
###############################################################################

stateLabel = "Cai"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

subData4 = ao.GetData(data4,stateLabel)
subData5 = ao.GetData(data5,stateLabel)
subData6 = ao.GetData(data6,stateLabel)


plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData1.t-800)/60+0.9,(subData6.valsIdx-subData3.valsIdx)*1000,'y-',label="Model - 5.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData5.valsIdx-subData3.valsIdx)*1000,'c-',label="Model - 3.0 mM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData4.valsIdx-subData3.valsIdx)*1000,'m-',label="Model - 2.0 mM [ATP]")
plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx-subData3.valsIdx)*1000,'g-',label="Model - 1.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx-subData3.valsIdx)*1000,'b-',label="Model - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx-subData3.valsIdx)*1000,'r-',label="Model - 10 uM [ATP]")
plt.plot(lt3-0.5,ly3,'g--',alpha=0.8,label="Hide et al. - 1.0 mM [ATP]")
plt.plot(lt2-0.3,ly2,'b--',alpha=0.8,label="Hide et al. - 100 uM [ATP]")
plt.plot(lt1-0.3,ly1,'r--',alpha=0.8,label="Hide et al. - 10 uM [ATP]") 

plt.plot([1,7.5],[-5,-5],'k',label='ATP',linewidth=7)

plt.xlabel("time (min)",fontsize=12)
plt.ylabel("d[Ca] (nM)",fontsize=12)
plt.xlim(0,9)
#plt.ylim(-8,60)
plt.legend(loc=0,fontsize=10)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_2mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_3mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_5mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")
# Hide's Data #################################################################
ly1 = np.array([0,0,27.11,36.42,17.8,-1.62,-6.47])
ly2 = np.array([0,-0.40,46.93,35.61,35.2,39.65,39.6,17.4,10.9,7.28,4.45,3.6])
ly3 = np.array([0,0,52.60,26.71,27.11,25.9,21.4,19.0,17,17,16.18])

lt1 = np.array([0,1.18,1.26,1.7,2.3,3.41,7.63])
lt2 = np.array([0,1.18,1.33,1.48,1.56,1.85,2.15,3.56,4.15,4.96,6.22,7.48])
lt3 = np.array([0,1.41,1.56,1.78,2.07,2.37,2.74,2.96,3.93,6.59,7.70])
###############################################################################

stateLabel = "Cai"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

plt.figure(figsize=(6,6),dpi=200)
plt.tick_params(labelsize=12)
ax = plt.subplot(1,1,1)
ax2 = ax.twinx()
ax.tick_params(labelsize=12)
ax2.tick_params(labelsize=12)

l1=ax.plot((subData0.t-800)/60+0.9,(subData0.valsIdx-subData3.valsIdx)*1000,'g-',label="Model - 1.0 mM [ATP]")
l2=ax.plot((subData1.t-800)/60+0.9,(subData1.valsIdx-subData3.valsIdx)*1000,'b-',label="Model - 100 uM [ATP]")
l3=ax.plot((subData2.t-800)/60+0.9,(subData2.valsIdx-subData3.valsIdx)*1000,'r-',label="Model - 10 uM [ATP]")

#l4=ax.plot(lt3-0.5,ly3,'g--',alpha=0.8,label="Hide et al. - 1.0 mM [ATP]")
#l5=ax.plot(lt2-0.3,ly2,'b--',alpha=0.8,label="Hide et al. - 100 uM [ATP]")
#l6=ax.plot(lt1-0.3,ly1,'r--',alpha=0.8,label="Hide et al. - 10 uM [ATP]") 

stateLabel = "J_ptxs"
unb0 = ao.GetData(data0,stateLabel)
unb1 = ao.GetData(data1,stateLabel)
unb2 = ao.GetData(data2,stateLabel)
unb3 = ao.GetData(data3,stateLabel)
stateLabel = "J_ptxf"
unb4 = ao.GetData(data0,stateLabel)
unb5 = ao.GetData(data1,stateLabel)
unb6 = ao.GetData(data2,stateLabel)
unb7 = ao.GetData(data3,stateLabel)
l7=ax2.plot((unb3.t-800)/60+0.9,(unb0.valsIdx+unb4.valsIdx),'g-.',alpha=1,label="J-P2X - 1.0 mM [ATP]")
l8=ax2.plot((unb2.t-800)/60+0.9,(unb1.valsIdx+unb5.valsIdx),'b-.',alpha=1,label="J-P2X - 100 uM [ATP]")
l9=ax2.plot((unb1.t-800)/60+0.9,(unb2.valsIdx+unb6.valsIdx),'r-.',alpha=1,label="J-P2X - 10 uM [ATP]") 

l10=ax.plot([1,7.5],[-5,-5],'k',label='ATP',linewidth=7)

ax.set_xlabel("time (min)",fontsize=15)
ax.set_ylabel("d[Ca] (nM)",fontsize=15)
ax2.set_ylabel("Rate (mM/s)",fontsize=15)

lns = l1 + l2 + l3 + l7 + l8 + l9 + l10 
labs = [l.get_label() for l in lns]

ax.legend(lns,labs,loc=0,fontsize=10) 

plt.xlim(0,9)
ax2.set_ylim(-0.28,1.6)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MGlumped_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MGlumped_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MGlumped_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")


plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
ax = plt.subplot(1,1,1)
#ax2 = ax.twinx()
ax.tick_params(labelsize=12)
#ax2.tick_params(labelsize=12)

stateLabel = "JERtoCy"
lea0 = ao.GetData(data0,stateLabel)
lea1 = ao.GetData(data1,stateLabel)
lea2 = ao.GetData(data2,stateLabel)
lea3 = ao.GetData(data3,stateLabel)
stateLabel = "JExtoCy"
lea4 = ao.GetData(data0,stateLabel)
lea5 = ao.GetData(data1,stateLabel)
lea6 = ao.GetData(data2,stateLabel)
lea7 = ao.GetData(data3,stateLabel)
stateLabel = "J_ptxs"
i0 = ao.GetData(data0,stateLabel)
i1 = ao.GetData(data1,stateLabel)
i2 = ao.GetData(data2,stateLabel)
i3 = ao.GetData(data3,stateLabel)
stateLabel = "J_ptxf"
i4 = ao.GetData(data0,stateLabel)
i5 = ao.GetData(data1,stateLabel)
i6 = ao.GetData(data2,stateLabel)
i7 = ao.GetData(data3,stateLabel)
l1=ax.plot((lea0.t-800)/60+0.9,(lea0.valsIdx+lea4.valsIdx+i0.valsIdx+i4.valsIdx)
           ,'g-',label="Influx - 1.0 mM [ATP]")
l2=ax.plot((lea1.t-800)/60+0.9,(lea1.valsIdx+lea5.valsIdx+i1.valsIdx+i5.valsIdx)
           ,'b-',label="Influx - 100 uM [ATP]")
l3=ax.plot((lea2.t-800)/60+0.9,(lea2.valsIdx+lea6.valsIdx+i2.valsIdx+i6.valsIdx)
           ,'r-',label="Influx - 10 uM [ATP]")

stateLabel = "JNCX"
unb0 = ao.GetData(data0,stateLabel)
unb1 = ao.GetData(data1,stateLabel)
unb2 = ao.GetData(data2,stateLabel)
unb3 = ao.GetData(data3,stateLabel)
stateLabel = "JCyttoER"
unb4 = ao.GetData(data0,stateLabel)
unb5 = ao.GetData(data1,stateLabel)
unb6 = ao.GetData(data2,stateLabel)
unb7 = ao.GetData(data3,stateLabel)
l7=ax.plot((unb3.t-800)/60+0.9,(unb0.valsIdx-unb4.valsIdx),'g--',alpha=1,label="Efflux - 1.0 mM [ATP]")
l8=ax.plot((unb2.t-800)/60+0.9,(unb1.valsIdx-unb5.valsIdx),'b--',alpha=1,label="Efflux - 100 uM [ATP]")
l9=ax.plot((unb1.t-800)/60+0.9,(unb2.valsIdx-unb6.valsIdx),'r--',alpha=1,label="Efflux - 10 uM [ATP]") 

l10=ax.plot([1,7.5],[0,0],'k',label='ATP',linewidth=7)

ax.set_xlabel("Time (min)",fontsize=12)
ax.set_ylabel("Flux rate (mM/s)",fontsize=12)
#ax2.set_ylabel("Rate (mM/s)",fontsize=15)

lns = l1 + l2 + l3 + l7 + l8 + l9 + l10 
labs = [l.get_label() for l in lns]

ax.legend(lns,labs,loc=0,fontsize=10) 

plt.xlim(0,9)
#ax2.set_ylim(-0.4,2.5)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MGlumped_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MGlumped_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MGlumped_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)

data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

stateLabel = "Cai"
unb0 = ao.GetData(data0,stateLabel)
unb1 = ao.GetData(data1,stateLabel)
unb2 = ao.GetData(data2,stateLabel)
unb3 = ao.GetData(data3,stateLabel)

t0 = (unb3.t-800)/60+0.9
v0 = (unb0.valsIdx-unb3.valsIdx)*1000
v1 = (unb1.valsIdx-unb3.valsIdx)*1000
v2 = (unb2.valsIdx-unb3.valsIdx)*1000

T0 = np.linspace(0,9,150)  # point at t=0 was pretty bad
V0 = np.interp(T0,t0,v0)
V1 = np.interp(T0,t0,v1)
V2 = np.interp(T0,t0,v2)
plt.plot(T0,V0,'gx',alpha=1,label="Model - 1000 uM [ATP]")
plt.plot(T0,V1,'bx',alpha=1,label="Model - 100 uM [ATP]")
plt.plot(T0,V2,'rx',alpha=1,label="Model - 10 uM [ATP]")

data10 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoFura_1mMATP_cat.pickle")
data11 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoFura_0.1mMATP_cat.pickle")
data12 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoFura_0.01mMATP_cat.pickle")
data13 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoFura_0mMATP_cat.pickle")

stateLabel = "Cai"
unb0 = ao.GetData(data0,stateLabel)
unb1 = ao.GetData(data1,stateLabel)
unb2 = ao.GetData(data2,stateLabel)
unb3 = ao.GetData(data3,stateLabel)

plt.plot((unb3.t-800)/60+0.9,(unb0.valsIdx-unb3.valsIdx)*1000,
         'g--',alpha=1,label="No Fura - 1000 uM [ATP]")
plt.plot((unb2.t-800)/60+0.9,(unb1.valsIdx-unb3.valsIdx)*1000,
         'b--',alpha=1,label="No Fura - 100 uM [ATP]")
plt.plot((unb1.t-800)/60+0.9,(unb2.valsIdx-unb3.valsIdx)*1000,
         'r--',alpha=1,label="No Fura - 10 uM [ATP]") 

plt.plot([1,7.5],[-5,-5],'k',label='ATP',linewidth=7)

plt.xlabel("time (min)",fontsize=12)
plt.ylabel("d[Ca] (nM)",fontsize=12)

plt.legend(loc=0,fontsize=10) 

plt.xlim(0,9)
ax2.set_ylim(-10,60)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoFura_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoFura_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoFura_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoFura_0mMATP_cat.pickle
# ------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-157-cbabb7816043> in <module>()
#      52
#      53 plt.xlim(0,9)
# ---> 54 ax2.set_ylim(-10,60)
#      55
#      56 plt.tight_layout()
#
# NameError: name 'ax2' is not defined

# %%
plt.figure(figsize=(6,6),dpi=200)
plt.tick_params(labelsize=12)

data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

stateLabel = "Cai"
unb0 = ao.GetData(data0,stateLabel)
unb1 = ao.GetData(data1,stateLabel)
unb2 = ao.GetData(data2,stateLabel)
unb3 = ao.GetData(data3,stateLabel)

t0 = (unb3.t-800)/60+0.9
v0 = (unb0.valsIdx-unb3.valsIdx)*1000
v1 = (unb1.valsIdx-unb3.valsIdx)*1000
v2 = (unb2.valsIdx-unb3.valsIdx)*1000

T0 = np.linspace(0,9,150)  # point at t=0 was pretty bad
V0 = np.interp(T0,t0,v0)
V1 = np.interp(T0,t0,v1)
V2 = np.interp(T0,t0,v2)
plt.plot(T0,V0,'gx',alpha=1,label="Model - 1.0 mM [ATP]")
plt.plot(T0,V1,'bx',alpha=1,label="Model - 100 uM [ATP]")
plt.plot(T0,V2,'rx',alpha=1,label="Model - 10 uM [ATP]")

data10 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoBuffer_1mMATP_cat.pickle")
data11 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoBuffer_0.1mMATP_cat.pickle")
data12 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoBuffer_0.01mMATP_cat.pickle")
data13 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_NoBuffer_0mMATP_cat.pickle")

stateLabel = "Cai"
unb0 = ao.GetData(data0,stateLabel)
unb1 = ao.GetData(data1,stateLabel)
unb2 = ao.GetData(data2,stateLabel)
unb3 = ao.GetData(data3,stateLabel)

plt.plot((unb3.t-800)/60+0.9,(unb0.valsIdx-unb3.valsIdx)*1000,
         'g--',alpha=1,label="Unbuffered - 1.0 mM [ATP]")
plt.plot((unb2.t-800)/60+0.9,(unb1.valsIdx-unb3.valsIdx)*1000,
         'b--',alpha=1,label="Unbuffered - 100 uM [ATP]")
plt.plot((unb1.t-800)/60+0.9,(unb2.valsIdx-unb3.valsIdx)*1000,
         'r--',alpha=1,label="Unbuffered - 10 uM [ATP]") 

plt.plot([1,7.5],[-5,-5],'k',label='ATP',linewidth=7)

plt.xlabel("time (min)",fontsize=15)
plt.ylabel("d[Ca] (nM)",fontsize=15)

plt.legend(loc=0,fontsize=10) 

plt.xlim(0,9)
ax2.set_ylim(-10,60)

plt.tight_layout()
print ((subData0.valsIdx[4])*1000,(unb0.valsIdx[4])*1000)
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoBuffer_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoBuffer_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoBuffer_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_NoBuffer_0mMATP_cat.pickle
# (156.65055179495508, 156.65055179495508)

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

stateLabel1 = "I_ptxs"
subData11 = ao.GetData(data0,stateLabel1)
subData12 = ao.GetData(data1,stateLabel1)
subData13 = ao.GetData(data2,stateLabel1)
subData14 = ao.GetData(data3,stateLabel1)

stateLabel2 = "I_ptxf"
subData21 = ao.GetData(data0,stateLabel2)
subData22 = ao.GetData(data1,stateLabel2)
subData23 = ao.GetData(data2,stateLabel2)
subData24 = ao.GetData(data3,stateLabel2)

stateLabel3 = "INCX"
subData31 = ao.GetData(data0,stateLabel3)
subData32 = ao.GetData(data1,stateLabel3)
subData33 = ao.GetData(data2,stateLabel3)
subData34 = ao.GetData(data3,stateLabel3)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData21.t-800)/60+0.9,subData21.valsIdx*1e9*0.082,'g-',linewidth=1.5,label="P2X4 - 1000 uM [ATP]")
plt.plot((subData22.t-800)/60+0.9,subData22.valsIdx*1e9*0.082,'b-',linewidth=1.5,label="P2X4 - 100 uM [ATP]")
plt.plot((subData23.t-800)/60+0.9,subData23.valsIdx*1e9*0.082,'r-',linewidth=1.5,label="P2X4 - 10 uM [ATP]")
plt.plot((subData11.t-800)/60+0.9,subData11.valsIdx*1e9*0.1,'g--',linewidth=1.5,label="P2X7 - 1000 uM [ATP]")
plt.plot((subData12.t-800)/60+0.9,subData12.valsIdx*1e9*0.1,'b--',linewidth=1.5,label="P2X7 - 100 uM [ATP]")
plt.plot((subData13.t-800)/60+0.9,subData13.valsIdx*1e9*0.1,'r--',linewidth=1.5,label="P2X7 - 10 uM [ATP]")
plt.plot([1,7.5],[1,1],'k',label='ATP',linewidth=7)

plt.xlabel("time (min)",fontsize=12)
plt.ylabel("Inward Current (pA)",fontsize=12)

plt.legend(loc=0,fontsize=10) 

plt.xlim(0/60,9)

plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle
# I_ptxs  not found
# -------------------------------------------------
# AttributeError  Traceback (most recent call last)
# <ipython-input-9-44fa15b6d07b> in <module>()
#       5
#       6 stateLabel1 = "I_ptxs"
# ----> 7 subData11 = ao.GetData(data0,stateLabel1)
#       8 subData12 = ao.GetData(data1,stateLabel1)
#       9 subData13 = ao.GetData(data2,stateLabel1)
#
# /home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/P2X-project/pkh-code/fitting/analyzeGotran.pyc in GetData(data, idxName)
#     119       datac.v =None
#     120
# --> 121     idx = datac.v_idx.index(idxName)
#     122     datac.valsIdx = datac.v[:,idx]
#     123
#
# AttributeError: empty instance has no attribute 'v_idx'

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

stateLabel = "CaMCN"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx),'g-',label="Model - 1.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx),'b-',label="Model - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx),'r-',label="Model - 10 uM [ATP]")
plt.plot([1,7.5],[0.03,0.03],'k',label='ATP',linewidth=7)

plt.xlim(0/60,9)
#plt.ylim(0,0.6)
plt.legend(loc=0,fontsize=10)
plt.xlabel("time (min)",fontsize=12)
plt.ylabel("CaMCN (uM)",fontsize=12)
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

stateLabel = "CaBex"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx),'g-',label="CaBex - 1.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx),'b-',label="CaBex - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx),'r-',label="CaBex - 10 uM [ATP]")

stateLabel = "CaF"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx),'g--',label="Ca-Fura - 1.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx),'b--',label="Ca-Fura - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx),'r--',label="Ca-Fura - 10 uM [ATP]")

plt.plot([1,7.5],[5,5],'k',label='ATP',linewidth=7)

plt.xlim(0/60,9)
#plt.ylim(0,0.6)
plt.legend(loc=0,fontsize=10)
plt.xlabel("time (min)",fontsize=12)
plt.ylabel("Ca-Buffer (uM)",fontsize=12)
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

stateLabel = "CaBex"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx),'g-',label="CaBex - 1.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx),'b-',label="CaBex - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx),'r-',label="CaBex - 10 uM [ATP]")

stateLabel = "CaF"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)

plt.plot((subData0.t-800)/60+0.9,(subData0.valsIdx),'g--',label="Ca-Fura - 1.0 mM [ATP]")
plt.plot((subData1.t-800)/60+0.9,(subData1.valsIdx),'b--',label="Ca-Fura - 100 uM [ATP]")
plt.plot((subData2.t-800)/60+0.9,(subData2.valsIdx),'r--',label="Ca-Fura - 10 uM [ATP]")

plt.plot([1,7.5],[5,5],'k',label='ATP',linewidth=7)

plt.xlim(0/60,9)
#plt.ylim(0,0.6)
plt.legend(loc=0,fontsize=10)
plt.xlabel("time (min)",fontsize=12)
plt.ylabel("Ca-Buffer (uM)",fontsize=12)
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/1st1rsMGCaN_1mMATPnew_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/1st200rsMGCaN_1mMATPnew_cat.pickle")

stateLabel1 = "Cai"
stateLabel2 = "CaMCN"

subData01 = ao.GetData(data0,stateLabel1)
subData02 = ao.GetData(data0,stateLabel2)

subData11 = ao.GetData(data1,stateLabel1)
subData12 = ao.GetData(data1,stateLabel2)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)


plt.plot(subData01.t,
         (subData01.valsIdx-min(subData01.valsIdx))/max(subData01.valsIdx-min(subData01.valsIdx)),
         'b-',label="Cai - 0.5 Hz",linewidth=1.5)
plt.plot(subData02.t,
         (subData02.valsIdx-min(subData02.valsIdx))/max(subData02.valsIdx-min(subData02.valsIdx)),
         'b--',label="Active CaN - 0.5 Hz",linewidth=1.5)
plt.plot(subData11.t,
         (subData11.valsIdx-min(subData11.valsIdx[0:100]))/max(subData11.valsIdx-min(subData11.valsIdx[0:100])),
         'r-',label="Cai - 0 Hz",linewidth=1.5)
plt.plot(subData12.t,
         (subData12.valsIdx-min(subData12.valsIdx[100:200]))/max(subData12.valsIdx-min(subData12.valsIdx[100:200]))
         ,'r--',label="Active CaN - 0 Hz",linewidth=1.5)

plt.xlim(-5,50)         
plt.ylim(-0.01,1.05)

plt.legend(loc=0,fontsize=10)
plt.xlabel("time (sec)",fontsize=12)
plt.ylabel("Relative Conc. (Fraction of Max)",fontsize=12)
plt.tight_layout()

#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/CaMCNValidall.png")
# Out:
# Reading /home/AD/bch265/Data_storage/1st1rsMGCaN_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st200rsMGCaN_1mMATPnew_cat.pickle

# %%
stateLabel = "CaER"
subData1 = ao.GetData(data0,stateLabel)
subData2 = ao.GetData(data1,stateLabel)
subData3 = ao.GetData(data2,stateLabel)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)
plt.plot((subData1.t-800)/60,subData1.valsIdx/1000,'g-',label="1.0 mM [ATP]")
plt.plot((subData2.t-800)/60,subData2.valsIdx/1000,'b-',label="0.1 mM [ATP]")
plt.plot((subData3.t-800)/60,subData3.valsIdx/1000,'r-',label="0.01 mM [ATP]")
plt.xlim(-0.5,7.5)
#plt.ylim(0,0.6)
plt.legend(loc=0,fontsize=12)
plt.xlabel("time (min)",fontsize=15)
plt.ylabel("CaER(mM)",fontsize=15)
#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/CaMCN8minnew2.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-30b035b9968c> in <module>()
#       1 stateLabel = "CaER"
# ----> 2 subData1 = ao.GetData(data0,stateLabel)
#       3 subData2 = ao.GetData(data1,stateLabel)
#       4 subData3 = ao.GetData(data2,stateLabel)
#       5
#
# NameError: name 'ao' is not defined

# %%
stateLabel = "Cai"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)

plt.figure(figsize=(6,6),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(subData0.t,subData0.valsIdx*1000,'g-',label="Model - 1.0 mM [ATP]")
plt.plot(subData1.t,subData1.valsIdx*1000,'b-',label="Model - 100 uM [ATP]")
plt.plot(subData2.t,subData2.valsIdx*1000,'r-',label="Model - 10 uM [ATP]")


plt.xlabel("time (min)",fontsize=15)
plt.ylabel("d[Ca] (nM)",fontsize=15)
#plt.xlim(-10,20)

plt.tight_layout()

# %%
Q10 = ao.GetData(data1,"Q1_7")
Q20 = ao.GetData(data1,"Q2_7")
Q30 = ao.GetData(data1,"Q3_7")
Q40 = ao.GetData(data1,"Q4_7")

plt.figure(figsize=(7,7),dpi=80)
plt.tick_params(labelsize=12)
plt.plot(Q10.t,Q10.valsIdx,label="Q1")
plt.plot(Q20.t,Q20.valsIdx,label="Q2")
plt.plot(Q30.t,Q30.valsIdx,label="Q3")
plt.plot(Q40.t,Q40.valsIdx,label="Q4")
plt.plot(Q10.t,Q10.valsIdx+Q20.valsIdx+Q30.valsIdx+Q40.valsIdx,label="Total")
plt.legend(loc=0)
plt.xlabel("time (second)",fontsize=15)
plt.ylabel("probability",fontsize=15)
#plt.xlim(-10,20)

plt.tight_layout()

# %%
import math
data = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")

Cm = 12e-12 # in the unit of F
F = 96485.33289 # in the unit of C/mol
rmg = 3.68e-6 # in the unit of meter
Vmg = (4/3)*math.pi*rmg**3 # in the unit of L
Ver = Vmg*0.035

ncx = ao.GetData(data,"INCX")
Incx = ncx.valsIdx*Cm*1e12/F # current via ncx channel in pA -> pmol/second

pxs = ao.GetData(data,"I_ptxs")
Ipxs = pxs.valsIdx*1e9/F*0.1 # uC/ms -> 1e-6/1e-3 = x 1e-3 (A) x 1e12 = pA -> pmol/second

pxf = ao.GetData(data,"I_ptxf")
Ipxf = pxf.valsIdx*1e9/F*0.0824*4 # pmol

ertocy = ao.GetData(data,"JERtoCy")
IER = ertocy.valsIdx*1e9*Vmg # pmol

extocy = ao.GetData(data,"JExtoCy")
IEX = extocy.valsIdx*1e9*Vmg # pmol

serca = ao.GetData(data,"JCyttoER")
Iserca = serca.valsIdx*1e9*Vmg

buff = ao.GetData(data,"JBuffer")
Ibuff = buff.valsIdx*1e9*Vmg

leaks = IER + IEX # this must be positive 
p2xmol = -(Ipxs + Ipxf) # this must be positive 
ncxmol = Incx # this must be negative 
sercamol = -Iserca # this mus be negative 

plt.figure(figsize=(6,6),dpi=200)
plt.tick_params(labelsize=12)
plt.plot(ncx.t,ncxmol,label="NCX")
#plt.plot(pxs.t,Ipxs,label="iP2X7")
#plt.plot(pxs.t,Ipxf,label="iP2X4")
#plt.plot(caf.t,buffers,label="buffer")
plt.plot(serca.t,sercamol,label="SERCA")
plt.plot(pxs.t,p2xmol,label="p2x")
plt.plot(pxs.t,leaks,label="addition by leak")
plt.plot(buff.t,Ibuff,label="buffer")
#plt.plot(extocy.t,-IEX,label="iEXtoCy")
#plt.plot(ertocy.t,-IER,label="iERtoCy")
#plt.plot(ncx.t,-Incx+Ipxs_mod+Iserca_mod+Ipxf-IEX-IER,'k--',label="iNCX + iSERCA + iP2X7 + iP2X4 + iLeak")
plt.legend(loc=0)
plt.xlabel("time(sec)")
plt.ylabel("rate(pico-mol per second)")
plt.xlim(-10,2000)
#plt.ylim(-2,2)
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# (-10, 2000)

# %%
stateLabel = "CaER"
subData0 = ao.GetData(data0,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)

plt.figure(figsize=(7,7),dpi=80)
plt.tick_params(labelsize=12)
plt.plot(subData0.t,subData0.valsIdx,'g-',label="Model - 1.0 mM [ATP]")
plt.plot(subData1.t,subData1.valsIdx,'b-',label="Model - 100 uM [ATP]")
plt.plot(subData2.t,subData2.valsIdx,'r-',label="Model - 10 uM [ATP]")

plt.xlabel("time (min)",fontsize=15)
plt.ylabel("Ca (uM)",fontsize=15)
#plt.xlim(-10,20)

plt.tight_layout()

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle")
data1 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle")

stateLabel1 = "Captxs"
subData11 = ao.GetData(data0,stateLabel1)
subData12 = ao.GetData(data1,stateLabel1)
subData13 = ao.GetData(data2,stateLabel1)
subData14 = ao.GetData(data3,stateLabel1)

stateLabel2 = "Captxf"
subData21 = ao.GetData(data0,stateLabel2)
subData22 = ao.GetData(data1,stateLabel2)
subData23 = ao.GetData(data2,stateLabel2)
subData24 = ao.GetData(data3,stateLabel2)

min11 = min(subData14.valsIdx)
min12 = min(subData14.valsIdx)
min13 = min(subData14.valsIdx)

min21 = min(subData24.valsIdx)
min22 = min(subData24.valsIdx)
min23 = min(subData24.valsIdx)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)

plt.plot((subData11.t)/60,(subData11.valsIdx-min11)/1000,'g-',linewidth=1.5,label="P2X7 - 1.0 mM [ATP]")
plt.plot((subData12.t)/60,(subData12.valsIdx-min12)/1000,'b-',linewidth=1.5,label="P2X7 - 100 uM [ATP]")
plt.plot((subData13.t)/60,(subData13.valsIdx-min13)/1000,'r-',linewidth=1.5,label="P2X7 - 10 uM [ATP]")
plt.plot((subData21.t)/60,(subData21.valsIdx-min21)/1000,'g--',linewidth=1.5,label="P2X4 - 1.0 mM [ATP]")
plt.plot((subData22.t)/60,(subData22.valsIdx-min22)/1000,'b--',linewidth=1.5,label="P2X4 - 100 uM [ATP]")
plt.plot((subData23.t)/60,(subData23.valsIdx-min23)/1000,'r--',linewidth=1.5,label="P2X4 - 10 uM [ATP]")

plt.plot([0,6.8],[-10,-10],'k',label='ATP',linewidth=7)

plt.legend(loc=0,fontsize=12)

plt.xlim(0,460/60)
plt.ylim(-20,250)

#ax2.set_ylim(-0.06,0.5)

plt.xlabel("time (min)",fontsize=15)
plt.ylabel("[Ca] via P2X (mM)",fontsize=15)
plt.tight_layout()
# Out:
# Reading /home/AD/bch265/Data_storage/8min_MG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0.01mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/8min_MG_0mMATP_cat.pickle

# %%
stateLabel1 = "Captxs"
subData11 = ao.GetData(data0,stateLabel1)
subData12 = ao.GetData(data1,stateLabel1)
subData13 = ao.GetData(data2,stateLabel1)
subData14 = ao.GetData(data3,stateLabel1)

stateLabel2 = "Captxf"
subData21 = ao.GetData(data0,stateLabel2)
subData22 = ao.GetData(data1,stateLabel2)
subData23 = ao.GetData(data2,stateLabel2)
subData24 = ao.GetData(data3,stateLabel2)

min11 = min(subData14.valsIdx)
min12 = min(subData14.valsIdx)
min13 = min(subData14.valsIdx)

min21 = min(subData24.valsIdx)
min22 = min(subData24.valsIdx)
min23 = min(subData24.valsIdx)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)

plt.plot((subData11.t)/60,(subData11.valsIdx-min11+subData21.valsIdx-min21)/1000,'g-',linewidth=1.5,label="1.0 mM [ATP]")
plt.plot((subData12.t)/60,(subData12.valsIdx-min12+subData22.valsIdx-min22)/1000,'b-',linewidth=1.5,label="100 uM [ATP]")
plt.plot((subData13.t)/60,(subData13.valsIdx-min13+subData23.valsIdx-min23)/1000,'r-',linewidth=1.5,label="10 uM [ATP]")

plt.plot([0,6.8],[-10,-10],'k',label='ATP',linewidth=7)

plt.legend(loc=0,fontsize=12)

plt.xlim(0,460/60)
plt.ylim(-20,250)
#ax.set_ylim(-1,8)
#ax2.set_ylim(-0.06,0.5)

plt.xlabel("time (min)",fontsize=15)
plt.ylabel("[Ca] via P2X (mM)",fontsize=15)
plt.tight_layout()

# %%
stateLabel1 = "CaNCX"
subData11 = ao.GetData(data0,stateLabel1)
subData12 = ao.GetData(data1,stateLabel1)
subData13 = ao.GetData(data2,stateLabel1)
subData14 = ao.GetData(data3,stateLabel1)

stateLabel2 = "CaSERCA"
subData21 = ao.GetData(data0,stateLabel2)
subData22 = ao.GetData(data1,stateLabel2)
subData23 = ao.GetData(data2,stateLabel2)
subData24 = ao.GetData(data3,stateLabel2)

min11 = min(subData14.valsIdx)
min12 = min(subData14.valsIdx)
min13 = min(subData14.valsIdx)

min21 = min(subData24.valsIdx)
min22 = min(subData24.valsIdx)
min23 = min(subData24.valsIdx)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)

plt.plot((subData11.t)/60,(subData11.valsIdx-min11)/1000,'g-',linewidth=1.5,label="P2X7 - 1.0 mM [ATP]")
plt.plot((subData12.t)/60,(subData12.valsIdx-min12)/1000,'b-',linewidth=1.5,label="P2X7 - 100 uM [ATP]")
plt.plot((subData13.t)/60,(subData13.valsIdx-min13)/1000,'r-',linewidth=1.5,label="P2X7 - 10 uM [ATP]")
plt.plot((subData21.t)/60,(subData21.valsIdx-min21)/1000,'g--',linewidth=1.5,label="P2X4 - 1.0 mM [ATP]")
plt.plot((subData22.t)/60,(subData22.valsIdx-min22)/1000,'b--',linewidth=1.5,label="P2X4 - 100 uM [ATP]")
plt.plot((subData23.t)/60,(subData23.valsIdx-min23)/1000,'r--',linewidth=1.5,label="P2X4 - 10 uM [ATP]")

plt.plot([0,6.8],[-10,-10],'k',label='ATP',linewidth=7)

plt.legend(loc=0,fontsize=12)

plt.xlim(0,460/60)
#plt.ylim(-20,250)

#ax2.set_ylim(-0.06,0.5)

plt.xlabel("time (min)",fontsize=15)
plt.ylabel("[Ca] via P2X (mM)",fontsize=15)
plt.tight_layout()

# %%
stateLabel1 = "CaERtoCy"
subData11 = ao.GetData(data0,stateLabel1)
subData12 = ao.GetData(data1,stateLabel1)
subData13 = ao.GetData(data2,stateLabel1)
subData14 = ao.GetData(data3,stateLabel1)

stateLabel2 = "CaExtoCy"
subData21 = ao.GetData(data0,stateLabel2)
subData22 = ao.GetData(data1,stateLabel2)
subData23 = ao.GetData(data2,stateLabel2)
subData24 = ao.GetData(data3,stateLabel2)

min11 = min(subData14.valsIdx)
min12 = min(subData14.valsIdx)
min13 = min(subData14.valsIdx)

min21 = min(subData24.valsIdx)
min22 = min(subData24.valsIdx)
min23 = min(subData24.valsIdx)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)

plt.plot((subData11.t)/60,(subData11.valsIdx-min11)/1000,'g-',linewidth=1.5,label="P2X7 - 1.0 mM [ATP]")
plt.plot((subData12.t)/60,(subData12.valsIdx-min12)/1000,'b-',linewidth=1.5,label="P2X7 - 100 uM [ATP]")
plt.plot((subData13.t)/60,(subData13.valsIdx-min13)/1000,'r-',linewidth=1.5,label="P2X7 - 10 uM [ATP]")
plt.plot((subData21.t)/60,(subData21.valsIdx-min21)/1000,'g--',linewidth=1.5,label="P2X4 - 1.0 mM [ATP]")
plt.plot((subData22.t)/60,(subData22.valsIdx-min22)/1000,'b--',linewidth=1.5,label="P2X4 - 100 uM [ATP]")
plt.plot((subData23.t)/60,(subData23.valsIdx-min23)/1000,'r--',linewidth=1.5,label="P2X4 - 10 uM [ATP]")

plt.plot([0,6.8],[-10,-10],'k',label='ATP',linewidth=7)

plt.legend(loc=0,fontsize=12)

plt.xlim(0,460/60)
#plt.ylim(-20,250)

#ax2.set_ylim(-0.06,0.5)

plt.xlabel("time (min)",fontsize=15)
plt.ylabel("[Ca] via P2X (mM)",fontsize=15)
plt.tight_layout()

# %%
stateLabel1 = "I_ptxs"
subData11 = ao.GetData(data0,stateLabel1)
subData12 = ao.GetData(data1,stateLabel1)
subData13 = ao.GetData(data2,stateLabel1)
subData14 = ao.GetData(data3,stateLabel1)

stateLabel2 = "I_ptxf"
subData21 = ao.GetData(data0,stateLabel2)
subData22 = ao.GetData(data1,stateLabel2)
subData23 = ao.GetData(data2,stateLabel2)
subData24 = ao.GetData(data3,stateLabel2)

stateLabel3 = "INCX"
subData31 = ao.GetData(data0,stateLabel3)
subData32 = ao.GetData(data1,stateLabel3)
subData33 = ao.GetData(data2,stateLabel3)
subData34 = ao.GetData(data3,stateLabel3)

plt.figure(figsize=(7,7),dpi=200)
plt.tick_params(labelsize=12)

plt.plot((subData11.t)/60,subData11.valsIdx*1e9*0.1,'g-',linewidth=1.5,label="P2X7 - 1.0 mM [ATP]")
plt.plot((subData12.t)/60,subData12.valsIdx*1e9*0.1,'b-',linewidth=1.5,label="P2X7 - 100 uM [ATP]")
plt.plot((subData13.t)/60,subData13.valsIdx*1e9*0.1,'r-',linewidth=1.5,label="P2X7 - 10 uM [ATP]")
plt.plot((subData21.t)/60,subData21.valsIdx*1e9*0.082,'g--',linewidth=1.5,label="P2X4 - 1.0 mM [ATP]")
plt.plot((subData22.t)/60,subData22.valsIdx*1e9*0.082,'b--',linewidth=1.5,label="P2X4 - 100 uM [ATP]")
plt.plot((subData23.t)/60,subData23.valsIdx*1e9*0.082,'r--',linewidth=1.5,label="P2X4 - 10 uM [ATP]")
plt.plot((subData31.t)/60,subData31.valsIdx*12*-1,'g-.',linewidth=1.5,label="NCX - 1.0 mM [ATP]")
plt.plot((subData32.t)/60,subData32.valsIdx*12*-1,'b-.',linewidth=1.5,label="NCX - 100 uM [ATP]")
plt.plot((subData33.t)/60,subData33.valsIdx*12*-1,'r-.',linewidth=1.5,label="NCX - 10 uM [ATP]")


#plt.plot([0,6.8],[-10,-10],'k',label='ATP',linewidth=7)

plt.legend(loc=0,fontsize=12)

plt.xlim(0,460/60)
#plt.ylim(-20,250)

#ax2.set_ylim(-0.06,0.5)

plt.xlabel("time (min)",fontsize=15)
plt.ylabel("Current (pA)",fontsize=15)
plt.tight_layout()

# %%
stateLabel = "CaBex"
subData1 = ao.GetData(data0,stateLabel)
subData2 = ao.GetData(data1,stateLabel)
subData3 = ao.GetData(data2,stateLabel)

plt.figure(figsize=(7,7),dpi=100)
plt.tick_params(labelsize=12)
plt.plot((subData1.t-800)/60,subData1.valsIdx,'g-',label="1.0 mM [ATP]")
plt.plot((subData2.t-800)/60,subData2.valsIdx,'b-',label="0.1 mM [ATP]")
plt.plot((subData3.t-800)/60,subData3.valsIdx,'r-',label="0.01 mM [ATP]")
plt.xlim(-0.5,7.5)
#plt.ylim(0,0.6)
plt.legend(loc=0,fontsize=12)
plt.xlabel("time (min)",fontsize=15)
plt.ylabel("Ca-Buffer(uM)",fontsize=15)
#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/CaMCN8minnew2.png")

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/1st200rsMGCaN_1mMATPnew_cat.pickle")
ca2cam = ao.GetData(data1,"Ca2_CaM")
ca4cam = ao.GetData(data1,"Ca4_CaM")
ca2cn = ao.GetData(data1,"Ca2_CN")
ca4cn = ao.GetData(data1,"Ca4_CN")
camcn = ao.GetData(data1,"CaMCN")

plt.figure(figsize=(7,7),dpi=100)
plt.plot(ca2cam.t,ca2cam.valsIdx,label="ca2cam")
plt.plot(ca4cam.t,ca4cam.valsIdx,label="ca4cam")
plt.plot(ca2cn.t,ca2cn.valsIdx,label="ca2cn")
plt.plot(ca4cn.t,ca4cn.valsIdx,label="ca4cn")
plt.plot(camcn.t,camcn.valsIdx,label="camcn")
plt.legend(loc=0)
plt.xlim(-1,15)
# Out:
# Reading /home/AD/bch265/Data_storage/1st200rsMGCaN_1mMATPnew_cat.pickle
# (-1, 15)

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/1st200rsMGCaN_0mMATPnew_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/1st200rsMGCaN_0.01mMATPnew_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/1st200rsMGCaN_0.1mMATPnew_cat.pickle")
data4 = ao.readPickle("/home/AD/bch265/Data_storage/1st200rsMGCaN_1mMATPnew_cat.pickle")

zero = ao.GetData(data1,"CaMCN")
ten = ao.GetData(data2,"CaMCN")
hund = ao.GetData(data3,"CaMCN")
milli = ao.GetData(data4,"CaMCN")

plt.figure(figsize=(7,7),dpi=100)
plt.plot(zero.t,zero.valsIdx,label="0 mM")
plt.plot(ten.t,ten.valsIdx,label="0.01 mM")
plt.plot(hund.t,hund.valsIdx,label="0.1 mM")
plt.plot(milli.t,milli.valsIdx,label="1 mM")
plt.legend(loc=0)
plt.xlim(-1,15)
# Out:
# Reading /home/AD/bch265/Data_storage/1st200rsMGCaN_0mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st200rsMGCaN_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st200rsMGCaN_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st200rsMGCaN_1mMATPnew_cat.pickle
# (-1, 15)
