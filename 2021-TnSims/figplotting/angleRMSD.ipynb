# %%
import matplotlib.pylab as plt
import numpy as np

# %%
wtang = np.loadtxt("1J1Eangle")
wtMutang = np.loadtxt("1J1Emutangle")
Lwtang = np.loadtxt("6KN8ang")
LwtMutang = np.loadtxt("6KN8mutang")

L7ang = np.loadtxt("6KN7ang")
L7Mutang = np.loadtxt("6KN7mutang")
#Lwtang = np.loadtxt("6KN8ang")
#LwtMutang = np.loadtxt("6KN8mutang")

# %%
plt.figure(dpi=200,figsize=(2,6))
plt.subplot(3,1,1)
plt.hist(wtang,bins=20,density=True,color='gray',label='1J1E')
plt.hist(wtMutang,bins=20,alpha=0.5,density=True,label='1J1E_C84Y',color='red')
plt.legend(loc=(0.8,0.6))
plt.xlim([40,100])
#plt.xlabel("AB interhelical angle ($\degree$)")
plt.ylabel("Probability")

plt.subplot(3,1,2)
plt.hist(Lwtang,bins=20,density=True,color='gray',label='6KN8')
plt.hist(LwtMutang,bins=20,alpha=0.5,density=True,label='6KN8_C84Y',color='red')
plt.xlim([40,100])
plt.ylabel("Probability")

plt.legend(loc=(0.8,0.6))
plt.subplot(3,1,3)
plt.hist(L7ang,bins=20,density=True,color='gray',label='6KN7')
plt.hist(L7Mutang,bins=20,alpha=0.5,density=True,label='6KN7_C84Y',color='red')


plt.xlim([40,100])
plt.legend(loc=(0.8,0.6))
plt.xlabel("AB interhelical angle ($\degree$)")
plt.ylabel("Probability")
# Out:
# Text(0, 0.5, 'Probability')

# %%
wtang = np.loadtxt("1J1E",usecols=[1])
wtMutang = np.loadtxt("1J1E_C84Y",usecols=[1])
Lwtang = np.loadtxt("6KN8",usecols=[1])
LwtMutang = np.loadtxt("6KN8_C84Y",usecols=[1])

L7tang = np.loadtxt("6KN7",usecols=[1])
L7Mutang = np.loadtxt("6KN7_C84Y",usecols=[1])



wtTI = np.loadtxt("1J1ETI",usecols=[1])
wtMuTI = np.loadtxt("1J1EmutTI",usecols=[1])
N8TI = np.loadtxt("6KN8TI",usecols=[1])
N8mutTI = np.loadtxt("6KN8mutTI",usecols=[1])

#L7tang = np.loadtxt("6KN7",usecols=[1])
#L7Mutang = np.loadtxt("6KN7_C84Y",usecols=[1])

# %%
plt.figure(dpi=200,figsize=(4,3))
plt.subplot(3,1,1)
plt.plot(range(1,101),wtang,label='1J1E',color='gray',lw=0.7)
plt.plot(range(1,101),wtMutang,"--",label="1J1E_C84Y",color="red",lw=0.7)
plt.legend(fontsize=8)
plt.ylim([0,7])
plt.xticks([])
plt.yticks(fontsize=8)
plt.ylabel('C$_\\alpha$ atom \n RMSF ($\AA$)',fontsize=8)

plt.subplot(3,1,2)

plt.plot(range(2,103),Lwtang,label='6KN8',color='gray',lw=0.7)
plt.plot(range(2,103),LwtMutang,"--",label="6KN8_C84Y",color="red",lw=0.7)
plt.ylabel('C$_\\alpha$ atom \n RMSF ($\AA$)',fontsize=8)
plt.legend(fontsize=8)
plt.xticks([])
plt.ylim([0,7])


plt.subplot(3,1,3)


plt.plot(range(2,103),L7tang,label='6KN7',color='gray',lw=0.7)
plt.plot(range(2,103),L7Mutang,"--",label="6KN7_C84Y",color="red",lw=0.7)
plt.ylabel('C$_\\alpha$ atom \n RMSF ($\AA$)',fontsize=8)
plt.legend(fontsize=8)
plt.ylim([0,7])



plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
plt.xlabel('N-TnC residue #',fontsize=8)
# Out:
# Text(0.5, 0, 'N-TnC residue #')

# %%
plt.figure(dpi=200,figsize=(4,3))
plt.subplot(2,1,1)
plt.plot(range(1,14),wtTI,label='1J1E',color='gray',lw=0.7)
plt.plot(range(1,14),wtMuTI,"--",label="1J1E_C84Y",color="red",lw=0.7)
plt.legend(fontsize=8)
plt.ylim([0,3])
plt.xticks([])
plt.yticks(fontsize=8)
plt.ylabel('C$_\\alpha$ atom \n RMSF ($\AA$)',fontsize=8)

plt.subplot(2,1,2)

plt.plot(range(1,14),N8TI,label='6KN8',color='gray',lw=0.7)
plt.plot(range(1,14),N8mutTI,"--",label="6KN8_C84Y",color="red",lw=0.7)
plt.ylabel('C$_\\alpha$ atom \n RMSF ($\AA$)',fontsize=8)
plt.legend(fontsize=8)
plt.xticks([])
plt.ylim([0,3])



plt.xlabel('TnI reidues 152-164 ',fontsize=8)
# Out:
# Text(0.5, 0, 'TnI reidues 152-164 ')
