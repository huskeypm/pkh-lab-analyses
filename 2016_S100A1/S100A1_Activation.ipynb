# %% [markdown]
# ## Figure 2

# %%
####Order parameters

font = {'weight' : 'bold',
        'size'   : 22}
matplotlib.rc('font', **font)

#Helical start/stop residues reference Nowakowski et al, 2013. 
#pEF/cEF start/stop residues don't correspond to helical start/stop residues.
#Subtract two residues because N-terminus residue isn't included, and counter starts at 0 in the script.
h1Astr=3-2
h1Aend=20-2
h2Astr=30-2
h2Aend=40-2
h3Astr=53-2
h3Aend=61-2
h4Astr=71-2
h4Aend=91-2
linkAstr=41-2
linkAend=50-2
pEFAstr=19-2
pEFAend=32-2
cEFAstr=62-2
cEFAend=73-2

h1Bstr=96-2
h1Bend=113-2
h2Bstr=123-2
h2Bend=133-2
h3Bstr=146-2
h3Bend=154-2
h4Bstr=164-2
h4Bend=184-2
linkBstr=134-2
linkBend=143-2
pEFBstr=112-2
pEFBend=125-2
cEFBstr=155-2
cEFBend=166-2

#Reference Nowakowski et al, 2013.  The values listed herein are based on Figure 3.  
#Exact values were not given in paper or SI.
avgsapoS2h1=.95
stdsapoS2h1=.04

avgsapoS2pEF=.79
stdsapoS2pEF=.02

avgsapoS2h2=.92
stdsapoS2h2=.02

avgsapoS2link=.85
stdsapoS2link=.03

avgsapoS2h3=.93 
stdsapoS2h3=.02

avgsapoS2cEF=.78
stdsapoS2cEF=.02

avgsapoS2h4=.94
stdsapoS2h4=.01

#Reference Nowakowski et al, 2013.  The values listed herein are based on Figure 3.  Exact values were not given in paper or SI.
avgsholoS2h1=.96
stdsholoS2h1=.05

avgsholoS2pEF=.95
stdsholoS2pEF=.02

avgsholoS2h2=.93
stdsholoS2h2=.02

avgsholoS2link=.69
stdsholoS2link=.06

avgsholoS2h3=.92
stdsholoS2h3=.04

avgsholoS2cEF=.90
stdsholoS2cEF=.02

avgsholoS2h4=.96
stdsholoS2h4=.05

def calAveOP(startA,stopA,startB,stopB,file1,file2,file3,file4):
  data1 = np.loadtxt(file1)
  data2 = np.loadtxt(file2)
  data3 = np.loadtxt(file3)
  data4 = np.loadtxt(file4)

  data1SubsetA=data1[startA:stopA]
  data1SubsetB=data1[startB:stopB]
  data1Subset=np.concatenate((data1SubsetA,data1SubsetB),axis=1)
  avg1 = np.mean(data1Subset)
    
  data2SubsetA=data2[startA:stopA]
  data2SubsetB=data2[startB:stopB]
  data2Subset=np.concatenate((data2SubsetA,data2SubsetB),axis=1)
  avg2 = np.mean(data2Subset)
    
  data3SubsetA=data3[startA:stopA]
  data3SubsetB=data3[startB:stopB]
  data3Subset=np.concatenate((data3SubsetA,data3SubsetB),axis=1)
  avg3 = np.mean(data3Subset)
    
  data4SubsetA=data4[startA:stopA]
  data4SubsetB=data4[startB:stopB]
  data4Subset=np.concatenate((data4SubsetA,data4SubsetB),axis=1)
  avg4 = np.mean(data4Subset)
    
  four_avgs = np.array([avg1, avg2, avg3, avg4])
  mean_avgs = np.mean(four_avgs)
  stds = np.std(four_avgs)

#print np.shape(dataSubset)
#print dataSubset
  return mean_avgs, stds

startA=pEFAstr
stopA=pEFAend

startB=pEFBstr
stopB=pEFBend
#print start, stop

file1="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_1/order_parameters/op_master2500.dat"
file2="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_2/order_parameters/op_master2500.dat"
file3="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_3/order_parameters/op_master2500.dat"
file4="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_4/order_parameters/op_master2500.dat"

holopEFave,holopEFstd=calAveOP(startA,stopA,startB,stopB,file1,file2,file3,file4)
print holopEFave, holopEFstd

startA=cEFAstr
stopA=cEFAend

startB=cEFBstr
stopB=cEFBend

holocEFave,holocEFstd=calAveOP(startA,stopA,startB,stopB,file1,file2,file3,file4)
print holocEFave, holocEFstd

startA=linkAstr
stopA=linkAend

startB=linkBstr
stopB=linkBend

hololinkave,hololinkstd=calAveOP(startA,stopA,startB,stopB,file1,file2,file3,file4)
print hololinkave, hololinkstd

startA=pEFAstr
stopA=pEFAend

startB=pEFBstr
stopB=pEFBend
#print start, stop

file1="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/order_parameters/op_master2500.dat"
file2="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/order_parameters/op_master2500.dat"
file3="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/order_parameters/op_master2500.dat"
file4="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/order_parameters/op_master2500.dat"

apopEFave,apopEFstd=calAveOP(startA,stopA,startB,stopB,file1,file2,file3,file4)
print apopEFave, apopEFstd

startA=cEFAstr
stopA=cEFAend

startB=cEFBstr
stopB=cEFBend

apocEFave,apocEFstd=calAveOP(startA,stopA,startB,stopB,file1,file2,file3,file4)
print apocEFave, apocEFstd

startA=linkAstr
stopA=linkAend

startB=linkBstr
stopB=linkBend

apolinkave,apolinkstd=calAveOP(startA,stopA,startB,stopB,file1,file2,file3,file4)
print apolinkave, apolinkstd

startA=pEFAstr
stopA=pEFAend

startB=pEFBstr
stopB=pEFBend
#print start, stop

file1="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_1/order_parameters/op_master2500.dat"
file2="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_2/order_parameters/op_master2500.dat"
file3="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_3/order_parameters/op_master2500.dat"
file4="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_4/order_parameters/op_master2500.dat"

singlepEFave,singlepEFstd=calAveOP(startA,stopA,startB,stopB,file1,file2,file3,file4)
print singlepEFave, singlepEFstd

startA=cEFAstr
stopA=cEFAend

startB=cEFBstr
stopB=cEFBend

singlecEFave,singlecEFstd=calAveOP(startA,stopA,startB,stopB,file1,file2,file3,file4)
print singlecEFave, singlecEFstd

startA=linkAstr
stopA=linkAend

startB=linkBstr
stopB=linkBend

singlelinkave,singlelinkstd=calAveOP(startA,stopA,startB,stopB,file1,file2,file3,file4)
print singlelinkave, singlelinkstd

names=['apo-ref/pEF','apo/Helix 1','holo-ref/pEF','holo/pEF','+cEF/pEF',\
      'apo-ref/Linker','apo/Helix 1','holo-ref/Linker','holo/Linker','+cEF/Linker',\
      'apo-ref/cEF','apo/cEF','holo-ref/cEF','holo/cEF','+cEF/cEF']

stds=np.array([stdsapoS2pEF,apopEFstd,stdsholoS2pEF,holopEFstd,singlepEFstd,\
               stdsapoS2link,apolinkstd,stdsholoS2link,hololinkstd,hololinkstd,\
               stdsapoS2cEF,apocEFstd,stdsholoS2cEF,holocEFstd,singlecEFstd])

means=np.array([avgsapoS2pEF,apopEFave,avgsholoS2pEF,holopEFave,singlepEFave,\
               avgsapoS2link,apolinkave,avgsholoS2link,hololinkave,singlelinkave,\
               avgsapoS2cEF,apocEFave,avgsholoS2cEF,holocEFave,singlecEFave,])

import numpy as np
import matplotlib.pyplot as plt

N = 3.

ind = np.arange(N)  # the x locations for the groups
width = 0.10  

class empty:pass
apo_ref=empty()
apo_ref.names = names[::5]
apo_ref.means = means[::5]
apo_ref.stds = stds[::5]

holo_ref = empty()
holo_ref.names = names[2::5]
holo_ref.means = means[2::5]
holo_ref.stds = stds[2::5]

apo_ave = empty()
apo_ave.names = names[1::5]
apo_ave.means = means[1::5]
apo_ave.stds = stds[1::5]

holo_ave = empty()
holo_ave.names = names[3::5]
holo_ave.means = means[3::5]
holo_ave.stds = stds[3::5]

single_ave = empty()
single_ave.names = names[4::5]
single_ave.means = means[4::5]
single_ave.stds = stds[4::5]

fig, ax = plt.subplots(dpi=300,figsize=(15,6))
rects1 = ax.bar(ind, apo_ref.means, width, color='w',yerr=apo_ref.stds, edgecolor='b',\
                hatch='////', error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects2 = ax.bar(ind+width, apo_ave.means, width, color='b',yerr=apo_ave.stds,\
                edgecolor='b',error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects3 = ax.bar(ind+2*width+.08, holo_ref.means, width, color='w',yerr=holo_ref.stds, edgecolor='r',\
                hatch='////', error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects4 = ax.bar(ind+3*width+.08, holo_ave.means, width, color='r',yerr=holo_ave.stds,\
                edgecolor='r',error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects5 = ax.bar(ind+4*width+.12, single_ave.means, width, color='g',yerr=single_ave.stds,\
               edgecolor='g',error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))

ax.set_ylabel(r'$S^2$',fontsize=24)
#ax.set_title('S100A1 Order Parameters (2500)')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('pEF', 'Linker', 'cEF') ,fontsize=20)
ax.legend( (rects1[0],rects2[0],rects3[0],rects4[0], rects5[0]), ('Apo-Ref','Apo','Holo-Ref','Holo','Half-sat.'),\
          fontsize=14,loc=(4)) 

#plt.gcf().savefig("/home/AD/cesc235/order-parameters/all-ave2500order_parameters_ref_mean.png",dpi=600)
# Out:
# 0.854756981005 0.00898181874486
# 0.838036864674 0.0237283064189
# 0.783737554015 0.021997387314
# 0.798432059319 0.0105554590802
# 0.808406277563 0.0114867738171
# 0.830280438403
#  0.0227302547414
# 0.755968323426 0.0402966515431
# 0.821979047243 0.0152475194593
# 0.787233546497 0.0148781792276

# %% [markdown]
# ## Figure 3

# %%
####Carbonyl Density Analysis
import loos
import sys
import math
import PyTraj

class empty:pass

# %load_ext autoreload
# %autoreload 2

font = {'weight' : 'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

###Holo Chain A cEF

# add python path
sys.path.append("/home/AD/cesc235/labscripts/parvalbumin/")
import parvfuncs as pf

prefix = "/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/"
runs = ["1"]
# might consider http://matplotlib.org/1.2.1/examples/pylab_examples/dash_control.html
cols = ["-","-.","--"]

cases = []
case="WT_holo_2LP3_"
caseNames = ["1"]#,"L85F", "L85A"]

# timing 
NS_PER_FRAME=0.002 # [ps/fr] Verified 
PTRAJ_DOWNSAMPLE = 1 # Verified, was 10 
FRAME_TO_TIME = NS_PER_FRAME * PTRAJ_DOWNSAMPLE

for i, caseName in enumerate(caseNames):
 
    holo = empty()
    holo.dcdFile = prefix+case+caseName#+ run + ".dcd"
    #holo.pdbFile = prefix+caseName+"_holo_2LP3_"#+ run + ".pdb"
    holo.pdbFile = "first" #+runs+".pdb"
    holo.aligned="alignedCA_A" 
    holo.col='r'
    holo.name = case+" "+caseName#+run
    holo.frame_to_time = FRAME_TO_TIME
    cases.append(holo)


# hack
#apos = cases[0::2]

holos = cases[0::1]   
#cases = [apo, holo]


pf.FRAME_TO_TIME = FRAME_TO_TIME
pf.cols = cols

import binfuncs as bf

for i, case in enumerate(cases):
    case.trajs = []
    for j, run in enumerate(runs):
        pdbFile = case.dcdFile+"/"+case.pdbFile+".pdb"
        dcdFile = case.dcdFile+"/"+case.aligned+".dcd"
        print "Loading " + dcdFile
        print "Loading " + pdbFile
        case.system=loos.createSystem(pdbFile) # only loading once, since should be same across runs
        traj=loos.createTrajectory(dcdFile,case.system)
        case.trajs.append(traj)
        print "Frames for %s: %d" %(case.name, traj.nframes())

##Chain A canonical EF

##Back-bone carbonyls
case = holos[0]
idx = 1
selAllOs = loos.selectAtoms(case.system,'name=="O"&&(resid>=62&&resid<=73)')
selCa = loos.selectAtoms(case.system,'name=="CA"&& resid==188')
nOs = selAllOs.size()
nTs = 50000
allDists = np.zeros((nOs,nTs))
ts = np.zeros(nTs)
for i in range(nOs):
    run=idx-1
    selO = selAllOs.subset(i,1)
    dists = pf.dodist(case,run,selO,selCa)
    allDists[i,:] = dists[:,1]
    ts  = dists[:,0]

binMin=0.; binMax=12.
res = 0.5

zs=[]
for i in range(nOs):
  grid_t,grid_r,z = bf.BinTimeSeries(allDists[i,:],binMin,binMax,res=res,plot=False)
  zs.append(z)

def plotOxyDensity(grid_t,grid_r,zs,title="NONE"):
  scaleByCoordinationNumber=1/7.
  frames_to_time = 0.002
  ar = np.sum(zs,axis=0)

  plt.subplot(211)
  plt.tight_layout()  
  plt.title(title)
  plt.xlabel("Time (ns)",fontsize=14, weight="bold")
  plt.ylabel("Ca/O \n distance [A]",fontsize=14, weight="bold")  
  plt.pcolormesh(grid_t*frames_to_time,grid_r,ar.transpose())
  plt.colorbar()
  plt.clim([0,7])
    
  plt.subplot(212)
  plt.tight_layout()
  plt.xlabel("Ca/O distance [A]",fontsize=14, weight="bold")
  plt.ylabel("Radial \n Distribution",fontsize=14, weight="bold") 
  histo=np.sum(ar,axis=1)
  nTs  = np.shape(ar)[1]
  plt.plot(grid_r[0,:],histo/nTs)
  
  plt.ylim([0,7])
     
 # output=np.column_stack((grid_r[0,:],ar))  
  ar_title="ar_"+title+".txt"
  #np.savetxt(ar_title,ar)
 # print ar
    
  #plt.gcf().savefig(title+".png")

  l=np.mean(ar,axis=1) #Same as summing up and averaging over nTs.  See above.
  s=np.std(ar,axis=1)
  j=np.zeros([np.shape(l)[0],3])
  j[:,0]=grid_r[0,:]
  j[:,1]=l
  j[:,2]=s 

  #np.savetxt(title+".txt",j) 
    
plt.figure()    
plotOxyDensity(grid_t,grid_r,zs,title="full-holo1_chainAcEF_bbO")    
np.shape(zs)
np.shape(grid_r)

v=np.sum(zs,axis=0)
##Side-chain carbonyls

case = holos[0]
idx = 1
selAllOs = loos.selectAtoms(case.system,'name=~"O"&&!(name=="O")&&(resid>=62&&resid<=73)')
selCa = loos.selectAtoms(case.system,'name=="CA"&& resid==188')
nOs = selAllOs.size()
nTs = 50000
allDists = np.zeros((nOs,nTs))
ts = np.zeros(nTs)
for i in range(nOs):
    run=idx-1
    selO = selAllOs.subset(i,1)
    dists = pf.dodist(case,run,selO,selCa)
    allDists[i,:] = dists[:,1]
    ts  = dists[:,0]

binMin=0.; binMax=12.
res = 0.5

zs=[]
for i in range(nOs):
  grid_t,grid_r,z = bf.BinTimeSeries(allDists[i,:],binMin,binMax,res=res,plot=False)
  zs.append(z)
    
plt.figure()
plotOxyDensity(grid_t,grid_r,zs,title="full-holo1_chainAcEF_scO") 

##All carbonyls

case = holos[0]
idx = 1
selAllOs = loos.selectAtoms(case.system,'name=~"O"&&(resid>=62&&resid<=73)')
selCa = loos.selectAtoms(case.system,'name=="CA"&& resid==188')
nOs = selAllOs.size()
nTs = 50000
allDists = np.zeros((nOs,nTs))
ts = np.zeros(nTs)
for i in range(nOs):
    run=idx-1
    selO = selAllOs.subset(i,1)
    dists = pf.dodist(case,run,selO,selCa)
    allDists[i,:] = dists[:,1]
    ts  = dists[:,0]
    
binMin=0.; binMax=12.
res = 0.5

zs=[]
for i in range(nOs):
  grid_t,grid_r,z = bf.BinTimeSeries(allDists[i,:],binMin,binMax,res=res,plot=False)
  zs.append(z)

plt.figure()
plotOxyDensity(grid_t,grid_r,zs,title="full-holo1_chainAcEF_allO") 

#Chain A pEF
case = holos[0]
idx = 1
selAllOs = loos.selectAtoms(case.system,'name=~"O"&&(resid>=19&&resid<=32)')
selCa = loos.selectAtoms(case.system,'name=="CA"&& resid==187')
nOs = selAllOs.size()
nTs = 50000
allDists = np.zeros((nOs,nTs))
ts = np.zeros(nTs)
for i in range(nOs):
    run=idx-1
    selO = selAllOs.subset(i,1)
    dists = pf.dodist(case,run,selO,selCa)
    allDists[i,:] = dists[:,1]
    ts  = dists[:,0]

binMin=0.; binMax=12.
res = 0.5

zs=[]
for i in range(nOs):
  grid_t,grid_r,z = bf.BinTimeSeries(allDists[i,:],binMin,binMax,res=res,plot=False)
  zs.append(z)

plt.figure()
plotOxyDensity(grid_t,grid_r,zs,title="full-holo1_chainApEF_allO")

####Apo case

#%cd /net/home/huskeypm/localTemp/parv/amber_holo/
prefix = "/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/"
#caseName= "WT"
#case= "WT_holo_1"
#case= "L85A_apo_1"
#case= "L85A_holo_1"
#prefix = "/home/AD/pmke226/localTemp/parv/xx/"
runs = ["1"]#,"2","3"]  # expects all three triplicate runs to be available for apo/holo states
# might consider http://matplotlib.org/1.2.1/examples/pylab_examples/dash_control.html
cols = ["-","-.","--"]

cases = []
case="WT_apo_2L0P_"
caseNames = ["1"]#,"L85F", "L85A"]

# timing 
NS_PER_FRAME=0.002 # [ps/fr] Verified 
PTRAJ_DOWNSAMPLE = 1 # Verified, was 10 
FRAME_TO_TIME = NS_PER_FRAME * PTRAJ_DOWNSAMPLE

for i, caseName in enumerate(caseNames):
 
    apo = empty()
    apo.dcdFile = prefix+case+caseName#+ run + ".dcd"
    #holo.pdbFile = prefix+caseName+"_holo_2LP3_"#+ run + ".pdb"
    apo.pdbFile = "first" #+runs+".pdb"
    apo.aligned="alignedA-2LP3cEF" 
    apo.col='r'
    apo.name = case+caseName#+run
    apo.frame_to_time = FRAME_TO_TIME
    apo.refFile=prefix+case
    apo.refName = "2LP3-1_prot-cal"
    print "Name of Directory: "+apo.name
    print "Name of File: "+apo.aligned
    print "Ref File: "+apo.refFile
    print "Name of ref: " +apo.refName
    cases.append(apo)

apos = cases[0::1]   
#cases = [apo, holo]


pf.FRAME_TO_TIME = FRAME_TO_TIME
pf.cols = cols

import binfuncs as bf

for i, case in enumerate(cases):
    case.trajs = []
    for j, run in enumerate(runs):
        pdbFile = case.dcdFile+"/"+case.pdbFile+".pdb"
        dcdFile = case.dcdFile+"/"+case.aligned+".dcd"
        refFile = case.refFile+run+"/"+case.refName+".pdb"
        print "Loading " + dcdFile
        print "Loading " + pdbFile
        print "Ref File: " +refFile
        case.system=loos.createSystem(pdbFile) # only loading once, since should be same across runs
        traj=loos.createTrajectory(dcdFile,case.system)
        case.trajs.append(traj)
        reference=loos.createSystem(refFile)
        print "Frames for %s: %d" %(case.name, traj.nframes())


def plotOxyDensity(grid_t,grid_r,zs,title="NONE"):
  scaleByCoordinationNumber=1/7.
  frames_to_time = 0.002
  ar = np.sum(zs,axis=0)

  plt.subplot(211)
  plt.tight_layout()  
  plt.title(title)
  plt.xlabel("Time (ns)",fontsize=14, weight="bold")
  plt.ylabel("Ca/O \n distance [A]",fontsize=14, weight="bold")  
  plt.pcolormesh(grid_t*frames_to_time,grid_r,ar.transpose())
  plt.colorbar()
  plt.clim([0,7])
    
  plt.subplot(212)
  plt.tight_layout()
  plt.xlabel("Ca/O distance [A]",fontsize=14, weight="bold")
  plt.ylabel("Radial \n Distribution",fontsize=14, weight="bold") 
  histo=np.sum(ar,axis=1)
  nTs  = np.shape(ar)[1]
  plt.plot(grid_r[0,:],histo/nTs)
  
  plt.ylim([0,7])
     
 # output=np.column_stack((grid_r[0,:],ar))  
  ar_title="ar_"+title+".txt"
 # np.savetxt(ar_title,ar)
    
  #plt.gcf().savefig(title+".png")

  l=np.mean(ar,axis=1) #Same as summing up and averaging over nTs.  See above.
  s=np.std(ar,axis=1)
  j=np.zeros([np.shape(l)[0],3])
  j[:,0]=grid_r[0,:]
  j[:,1]=l
  j[:,2]=s 

 # np.savetxt(title+".txt",j) 

plt.figure()
#plotOxyDensity(grid_t,grid_r,zs,title="full-apo1_chainAcEF_bbO")    
np.shape(zs)
np.shape(grid_r)

v=np.sum(zs,axis=0)

##All carbonyls
case = apos[0]
idx = 1
selAllOs = loos.selectAtoms(case.system,'name=~"O"&&(resid>=62&&resid<=73)')
selCa = loos.selectAtoms(reference,'name=="CA"&& resid==188')
nOs = selAllOs.size()
nTs = 50000
allDists = np.zeros((nOs,nTs))
ts = np.zeros(nTs)
for i in range(nOs):
    run=idx-1
    selO = selAllOs.subset(i,1)
    dists = pf.dodist(case,run,selO,selCa)
    allDists[i,:] = dists[:,1]
    ts  = dists[:,0]

binMin=0.; binMax=12.
res = 0.5

zs=[]
for i in range(nOs):
  grid_t,grid_r,z = bf.BinTimeSeries(allDists[i,:],binMin,binMax,res=res,plot=False)
  zs.append(z)

plt.figure()
plotOxyDensity(grid_t,grid_r,zs,title="full-apo1_chainAcEF_allO")

##Chain A pEF
case = apos[0]
idx = 1
selAllOs = loos.selectAtoms(case.system,'name=~"O"&&(resid>=19&&resid<=32)')
selCa = loos.selectAtoms(reference,'name=="CA"&& resid==187')
nOs = selAllOs.size()
nTs = 50000
allDists = np.zeros((nOs,nTs))
ts = np.zeros(nTs)
for i in range(nOs):
    run=idx-1
    selO = selAllOs.subset(i,1)
    dists = pf.dodist(case,run,selO,selCa)
    allDists[i,:] = dists[:,1]
    ts  = dists[:,0]

binMin=0.; binMax=12.
res = 0.5

zs=[]
for i in range(nOs):
  grid_t,grid_r,z = bf.BinTimeSeries(allDists[i,:],binMin,binMax,res=res,plot=False)
  zs.append(z)

plt.figure()
plotOxyDensity(grid_t,grid_r,zs,title="full-apo1_chainApEF_allO")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading /u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_1/alignedCA_A.dcd
# Loading /u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_1/first.pdb
# Frames for WT_holo_2LP3_ 1: 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# Name of Directory: WT_apo_2L0P_1
# Name of File: alignedA-2LP3cEF
# ...

# %%
font = {'weight' : 'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

def plotOxyDensityMeanPlot_RunpEF(ofname1,ofname2,ofname3,ofname4,ofname5,ofname6,ofname7,ofname8,\
                            ofname9,ofname10,ofname11,ofname12,ofname13,ofname14,ofname15,ofname16,\
                            title="NONE"):
                       
 import numpy as np
 import matplotlib.pyplot as plt

 o1=np.loadtxt(ofname1,usecols=(0,1,2))
 
 o2=np.loadtxt(ofname2,usecols=(0,1,2))
 
 o3=np.loadtxt(ofname3,usecols=(0,1,2))
 
 o4=np.loadtxt(ofname4,usecols=(0,1,2))
 
 o5=np.loadtxt(ofname5,usecols=(0,1,2))
 
 o6=np.loadtxt(ofname6,usecols=(0,1,2))
 
 o7=np.loadtxt(ofname7,usecols=(0,1,2))
 
 o8=np.loadtxt(ofname8,usecols=(0,1,2))
 
 o9=np.loadtxt(ofname9,usecols=(0,1,2))
 
 o10=np.loadtxt(ofname10,usecols=(0,1,2))
 
 o11=np.loadtxt(ofname11,usecols=(0,1,2))
 
 o12=np.loadtxt(ofname12,usecols=(0,1,2))
        
 o13=np.loadtxt(ofname13,usecols=(0,1,2))
 
 o14=np.loadtxt(ofname14,usecols=(0,1,2))
 
 o15=np.loadtxt(ofname15,usecols=(0,1,2))
 
 o16=np.loadtxt(ofname16,usecols=(0,1,2))
        
 dataHoloAll = np.zeros([np.shape(o1)[0],8])
 dataHoloAll[:,0] = o1[:,1]; dataHoloAll[:,1] = o2[:,1]; \
        dataHoloAll[:,2] = o3[:,1]; dataHoloAll[:,3] = o4[:,1];\
        dataHoloAll[:,4] = o5[:,1]; dataHoloAll[:,5] = o6[:,1]; \
        dataHoloAll[:,6] = o7[:,1]; dataHoloAll[:,7] = o8[:,1]
 WTholoAllmean = np.mean(dataHoloAll,axis=1)
 WTholoAllstd = np.std(dataHoloAll,axis=1)

 dataApoAll = np.zeros([np.shape(o9)[0],8])
 dataApoAll[:,0] = o9[:,1]; dataApoAll[:,1] = o10[:,1]; \
        dataApoAll[:,2] = o11[:,1]; dataApoAll[:,3] = o12[:,1];\
        dataApoAll[:,4] = o13[:,1]; dataApoAll[:,5] = o14[:,1]; \
        dataApoAll[:,6] = o15[:,1]; dataApoAll[:,7] = o16[:,1]
 WTapoAllmean = np.mean(dataApoAll,axis=1)
 WTapoAllstd = np.std(dataApoAll,axis=1)

 data1 = np.zeros([np.shape(o1)[0],2])
 data1[:,0] = o1[:,1]; data1[:,1] = o5[:,1]
 WTholo1mean = np.mean(data1,axis=1)

 data2 = np.zeros([np.shape(o2)[0],2])
 data2[:,0] = o2[:,1]; data2[:,1] = o6[:,1]
 WTholo2mean = np.mean(data2,axis=1)

 data3 = np.zeros([np.shape(o3)[0],2])
 data3[:,0] = o3[:,1]; data3[:,1] = o7[:,1]
 WTholo3mean = np.mean(data3,axis=1)
 
 data4 = np.zeros([np.shape(o4)[0],2])
 data4[:,0] = o3[:,1]; data4[:,1] = o8[:,1]
 WTholo4mean = np.mean(data4,axis=1)
        
 dataHoloMean = np.zeros([np.shape(o1)[0],4])
 dataHoloMean[:,0]=WTholo1mean; dataHoloMean[:,1]=WTholo2mean; dataHoloMean[:,2]=WTholo3mean; \
        dataHoloMean[:,3]=WTholo4mean
 Mean_of_HoloMeans=np.mean(dataHoloMean,axis=1)
 Std_of_HoloMeans=np.std(dataHoloMean,axis=1)

 data5 = np.zeros([np.shape(o9)[0],2])
 data5[:,0] = o9[:,1]; data5[:,1] = o13[:,1]
 WTapo1mean = np.mean(data5,axis=1)

 data6 = np.zeros([np.shape(o10)[0],2])
 data6[:,0] = o10[:,1]; data6[:,1] = o14[:,1]
 WTapo2mean = np.mean(data6,axis=1)

 data7 = np.zeros([np.shape(o11)[0],2])
 data7[:,0] = o11[:,1]; data7[:,1] = o15[:,1]
 WTapo3mean = np.mean(data7,axis=1)
 
 data8 = np.zeros([np.shape(o12)[0],2])
 data8[:,0] = o12[:,1]; data8[:,1] = o16[:,1]
 WTapo4mean = np.mean(data8,axis=1)
        
 dataHoloMean = np.zeros([np.shape(o1)[0],4])
 dataHoloMean[:,0]=WTholo1mean; dataHoloMean[:,1]=WTholo2mean; dataHoloMean[:,2]=WTholo3mean; \
        dataHoloMean[:,3]=WTholo4mean
 Mean_of_HoloMeans=np.mean(dataHoloMean,axis=1)
 Std_of_HoloMeans=np.std(dataHoloMean,axis=1)
 print "Holo: ", Mean_of_HoloMeans, Std_of_HoloMeans
        
 dataApoMean = np.zeros([np.shape(o9)[0],4])
 dataApoMean[:,0]=WTapo1mean; dataApoMean[:,1]=WTapo2mean; dataApoMean[:,2]=WTapo3mean; \
        dataApoMean[:,3]=WTapo4mean
 Mean_of_ApoMeans=np.mean(dataApoMean,axis=1)
 Std_of_ApoMeans=np.std(dataApoMean,axis=1)
 print "Apo: ", Mean_of_ApoMeans, Std_of_ApoMeans
        
 plt.figure()
 plt.errorbar(x=o1[:,0],y=WTholoAllmean,yerr=Std_of_HoloMeans,fmt='r-',linewidth=2.0,label='Holo')
 plt.errorbar(x=o9[:,0],y=WTapoAllmean,yerr=Std_of_ApoMeans,fmt='b-',linewidth=2.0,label='Apo')
 plt.ylim([-0.2,7.2])
 plt.title(title)
 plt.legend(loc=0)
 plt.xlabel('Ca/O Distance [A]',fontsize=14, weight="bold")
 plt.ylabel('Radial Distribution',fontsize=14, weight="bold")
 #plt.gcf().savefig("/home/AD/cesc235/labscripts/efhands/WTholo"+title+"_RunpEF.png")

title="pEF"
protein="full-holo"
state="holo"
ofname1="/home/AD/cesc235/ipython/efhands/%s/%s1_chainA%s_allO.txt"%(state,protein,title)
ofname2="/home/AD/cesc235/ipython/efhands/%s/%s2_chainA%s_allO.txt"%(state,protein,title)
ofname3="/home/AD/cesc235/ipython/efhands/%s/%s3_chainA%s_allO.txt"%(state,protein,title)
ofname4="/home/AD/cesc235/ipython/efhands/%s/%s4_chainA%s_allO.txt"%(state,protein,title)
ofname5="/home/AD/cesc235/ipython/efhands/%s/%s1_chainB%s_allO.txt"%(state,protein,title)
ofname6="/home/AD/cesc235/ipython/efhands/%s/%s2_chainB%s_allO.txt"%(state,protein,title)
ofname7="/home/AD/cesc235/ipython/efhands/%s/%s3_chainB%s_allO.txt"%(state,protein,title)
ofname8="/home/AD/cesc235/ipython/efhands/%s/%s4_chainB%s_allO.txt"%(state,protein,title)
protein2="full-apo"
state2="apo"
ofname9="/home/AD/cesc235/ipython/efhands/%s/%s1_chainA%s_allO.txt"%(state2,protein2,title)
ofname10="/home/AD/cesc235/ipython/efhands/%s/%s2_chainA%s_allO.txt"%(state2,protein2,title)
ofname11="/home/AD/cesc235/ipython/efhands/%s/%s3_chainA%s_allO.txt"%(state2,protein2,title)
ofname12="/home/AD/cesc235/ipython/efhands/%s/%s4_chainA%s_allO.txt"%(state2,protein2,title)
ofname13="/home/AD/cesc235/ipython/efhands/%s/%s1_chainB%s_allO.txt"%(state2,protein2,title)
ofname14="/home/AD/cesc235/ipython/efhands/%s/%s2_chainB%s_allO.txt"%(state2,protein2,title)
ofname15="/home/AD/cesc235/ipython/efhands/%s/%s3_chainB%s_allO.txt"%(state2,protein2,title)
ofname16="/home/AD/cesc235/ipython/efhands/%s/%s4_chainB%s_allO.txt"%(state2,protein2,title)
plotOxyDensityMeanPlot_RunpEF(ofname1,ofname2,ofname3,ofname4,ofname5,ofname6,ofname7,ofname8,\
                        ofname9,ofname10,ofname11,ofname12,ofname13,ofname14,ofname15,ofname16,\
                        title)

def plotOxyDensityMeanPlot_RuncEF(ofname1,ofname2,ofname3,ofname4,ofname5,ofname6,ofname7,ofname8,\
                            ofname9,ofname10,ofname11,ofname12,ofname13,ofname14,ofname15,ofname16,\
                            ofname17,ofname18,ofname19,ofname20,ofname21,ofname22,ofname23,ofname24,\
                            title="NONE"):
                       
 import numpy as np
 import matplotlib.pyplot as plt

 o1=np.loadtxt(ofname1,usecols=(0,1,2))
 
 o2=np.loadtxt(ofname2,usecols=(0,1,2))
 
 o3=np.loadtxt(ofname3,usecols=(0,1,2))
 
 o4=np.loadtxt(ofname4,usecols=(0,1,2))
 
 o5=np.loadtxt(ofname5,usecols=(0,1,2))
 
 o6=np.loadtxt(ofname6,usecols=(0,1,2))
 
 o7=np.loadtxt(ofname7,usecols=(0,1,2))
 
 o8=np.loadtxt(ofname8,usecols=(0,1,2))
 
 o9=np.loadtxt(ofname9,usecols=(0,1,2))
 
 o10=np.loadtxt(ofname10,usecols=(0,1,2))
 
 o11=np.loadtxt(ofname11,usecols=(0,1,2))
 
 o12=np.loadtxt(ofname12,usecols=(0,1,2))
        
 o13=np.loadtxt(ofname13,usecols=(0,1,2))
 
 o14=np.loadtxt(ofname14,usecols=(0,1,2))
 
 o15=np.loadtxt(ofname15,usecols=(0,1,2))
 
 o16=np.loadtxt(ofname16,usecols=(0,1,2))

 o17=np.loadtxt(ofname17,usecols=(0,1,2))
 
 o18=np.loadtxt(ofname18,usecols=(0,1,2))
 
 o19=np.loadtxt(ofname19,usecols=(0,1,2))
 
 o20=np.loadtxt(ofname20,usecols=(0,1,2))
        
 o21=np.loadtxt(ofname21,usecols=(0,1,2))
 
 o22=np.loadtxt(ofname22,usecols=(0,1,2))
 
 o23=np.loadtxt(ofname23,usecols=(0,1,2))
 
 o24=np.loadtxt(ofname24,usecols=(0,1,2))
        
 dataHoloAll = np.zeros([np.shape(o1)[0],8])
 dataHoloAll[:,0] = o1[:,1]; dataHoloAll[:,1] = o2[:,1]; \
        dataHoloAll[:,2] = o3[:,1]; dataHoloAll[:,3] = o4[:,1];\
        dataHoloAll[:,4] = o5[:,1]; dataHoloAll[:,5] = o6[:,1]; \
        dataHoloAll[:,6] = o7[:,1]; dataHoloAll[:,7] = o8[:,1]
 WTholoAllmean = np.mean(dataHoloAll,axis=1)
 WTholoAllstd = np.std(dataHoloAll,axis=1)

 dataApoAll = np.zeros([np.shape(o9)[0],8])
 dataApoAll[:,0] = o9[:,1]; dataApoAll[:,1] = o10[:,1]; \
        dataApoAll[:,2] = o11[:,1]; dataApoAll[:,3] = o12[:,1];\
        dataApoAll[:,4] = o13[:,1]; dataApoAll[:,5] = o14[:,1]; \
        dataApoAll[:,6] = o15[:,1]; dataApoAll[:,7] = o16[:,1]
 WTapoAllmean = np.mean(dataApoAll,axis=1)
 WTapoAllstd = np.std(dataApoAll,axis=1)

 dataCtermAll = np.zeros([np.shape(o17)[0],8])
 dataCtermAll[:,0] = o17[:,1]; dataCtermAll[:,1] = o18[:,1]; \
        dataCtermAll[:,2] = o19[:,1]; dataCtermAll[:,3] = o20[:,1];\
        dataCtermAll[:,4] = o21[:,1]; dataCtermAll[:,5] = o22[:,1]; \
        dataCtermAll[:,6] = o23[:,1]; dataCtermAll[:,7] = o24[:,1]
 WTCtermAllmean = np.mean(dataCtermAll,axis=1)
 WTCtermAllstd = np.std(dataCtermAll,axis=1)
 
 data1 = np.zeros([np.shape(o1)[0],2])
 data1[:,0] = o1[:,1]; data1[:,1] = o5[:,1]
 WTholo1mean = np.mean(data1,axis=1)

 data2 = np.zeros([np.shape(o2)[0],2])
 data2[:,0] = o2[:,1]; data2[:,1] = o6[:,1]
 WTholo2mean = np.mean(data2,axis=1)

 data3 = np.zeros([np.shape(o3)[0],2])
 data3[:,0] = o3[:,1]; data3[:,1] = o7[:,1]
 WTholo3mean = np.mean(data3,axis=1)
 
 data4 = np.zeros([np.shape(o4)[0],2])
 data4[:,0] = o3[:,1]; data4[:,1] = o8[:,1]
 WTholo4mean = np.mean(data4,axis=1)
        
 dataHoloMean = np.zeros([np.shape(o1)[0],4])
 dataHoloMean[:,0]=WTholo1mean; dataHoloMean[:,1]=WTholo2mean; dataHoloMean[:,2]=WTholo3mean; \
        dataHoloMean[:,3]=WTholo4mean
 Mean_of_HoloMeans=np.mean(dataHoloMean,axis=1)
 Std_of_HoloMeans=np.std(dataHoloMean,axis=1)

 data5 = np.zeros([np.shape(o9)[0],2])
 data5[:,0] = o9[:,1]; data5[:,1] = o13[:,1]
 WTapo1mean = np.mean(data5,axis=1)

 data6 = np.zeros([np.shape(o10)[0],2])
 data6[:,0] = o10[:,1]; data6[:,1] = o14[:,1]
 WTapo2mean = np.mean(data6,axis=1)

 data7 = np.zeros([np.shape(o11)[0],2])
 data7[:,0] = o11[:,1]; data7[:,1] = o15[:,1]
 WTapo3mean = np.mean(data7,axis=1)
 
 data8 = np.zeros([np.shape(o12)[0],2])
 data8[:,0] = o12[:,1]; data8[:,1] = o16[:,1]
 WTapo4mean = np.mean(data8,axis=1)
 
 data9 = np.zeros([np.shape(o17)[0],2])
 data9[:,0] = o17[:,1]; data9[:,1] = o21[:,1]
 WTcterm1mean = np.mean(data9,axis=1)

 data10 = np.zeros([np.shape(o18)[0],2])
 data10[:,0] = o18[:,1]; data10[:,1] = o22[:,1]
 WTcterm2mean = np.mean(data10,axis=1)

 data11 = np.zeros([np.shape(o19)[0],2])
 data11[:,0] = o19[:,1]; data11[:,1] = o23[:,1]
 WTcterm3mean = np.mean(data11,axis=1)
 
 data12 = np.zeros([np.shape(o20)[0],2])
 data12[:,0] = o20[:,1]; data12[:,1] = o24[:,1]
 WTcterm4mean = np.mean(data12,axis=1)
        
 dataHoloMean = np.zeros([np.shape(o1)[0],4])
 dataHoloMean[:,0]=WTholo1mean; dataHoloMean[:,1]=WTholo2mean; dataHoloMean[:,2]=WTholo3mean; \
        dataHoloMean[:,3]=WTholo4mean
 Mean_of_HoloMeans=np.mean(dataHoloMean,axis=1)
 Std_of_HoloMeans=np.std(dataHoloMean,axis=1)
 print "Holo: ", Mean_of_HoloMeans, Std_of_HoloMeans
        
 dataApoMean = np.zeros([np.shape(o9)[0],4])
 dataApoMean[:,0]=WTapo1mean; dataApoMean[:,1]=WTapo2mean; dataApoMean[:,2]=WTapo3mean; \
        dataApoMean[:,3]=WTapo4mean
 Mean_of_ApoMeans=np.mean(dataApoMean,axis=1)
 Std_of_ApoMeans=np.std(dataApoMean,axis=1)
 print "Apo: ", Mean_of_ApoMeans, Std_of_ApoMeans
        
 dataCtermMean = np.zeros([np.shape(o17)[0],4])
 dataCtermMean[:,0]=WTcterm1mean; dataCtermMean[:,1]=WTcterm2mean; dataCtermMean[:,2]=WTcterm3mean; \
        dataCtermMean[:,3]=WTcterm4mean
 Mean_of_CtermMeans=np.mean(dataCtermMean,axis=1)
 Std_of_CtermMeans=np.std(dataCtermMean,axis=1)
 print "Cterm: ", Mean_of_CtermMeans, Std_of_CtermMeans
        
 plt.figure()
 plt.errorbar(x=o1[:,0],y=WTholoAllmean,yerr=Std_of_HoloMeans,fmt='r-',linewidth=2.0,label='Holo')
 plt.errorbar(x=o9[:,0],y=WTapoAllmean,yerr=Std_of_ApoMeans,fmt='b-',linewidth=2.0,label='Apo')
 plt.errorbar(x=o17[:,0],y=WTCtermAllmean,yerr=Std_of_CtermMeans,fmt='g-',linewidth=2.0,label='Half-Saturated')
 plt.ylim([-0.2,7.2])
 plt.title(title)
 plt.legend(loc=0)
 plt.xlabel('Ca/O Distance [A]',fontsize=14, weight="bold")
 plt.ylabel('Radial Distribution',fontsize=14, weight="bold")
 plt.gcf().savefig("/home/AD/cesc235/labscripts/efhands/WTholo"+title+"_RuncEF.png")

title="cEF"
protein="full-holo"
state="holo"
ofname1="/home/AD/cesc235/ipython/efhands/%s/%s1_chainA%s_allO.txt"%(state,protein,title)
ofname2="/home/AD/cesc235/ipython/efhands/%s/%s2_chainA%s_allO.txt"%(state,protein,title)
ofname3="/home/AD/cesc235/ipython/efhands/%s/%s3_chainA%s_allO.txt"%(state,protein,title)
ofname4="/home/AD/cesc235/ipython/efhands/%s/%s4_chainA%s_allO.txt"%(state,protein,title)
ofname5="/home/AD/cesc235/ipython/efhands/%s/%s1_chainB%s_allO.txt"%(state,protein,title)
ofname6="/home/AD/cesc235/ipython/efhands/%s/%s2_chainB%s_allO.txt"%(state,protein,title)
ofname7="/home/AD/cesc235/ipython/efhands/%s/%s3_chainB%s_allO.txt"%(state,protein,title)
ofname8="/home/AD/cesc235/ipython/efhands/%s/%s4_chainB%s_allO.txt"%(state,protein,title)
protein2="full-apo"
state2="apo"
ofname9="/home/AD/cesc235/ipython/efhands/%s/%s1_chainA%s_allO.txt"%(state2,protein2,title)
ofname10="/home/AD/cesc235/ipython/efhands/%s/%s2_chainA%s_allO.txt"%(state2,protein2,title)
ofname11="/home/AD/cesc235/ipython/efhands/%s/%s3_chainA%s_allO.txt"%(state2,protein2,title)
ofname12="/home/AD/cesc235/ipython/efhands/%s/%s4_chainA%s_allO.txt"%(state2,protein2,title)
ofname13="/home/AD/cesc235/ipython/efhands/%s/%s1_chainB%s_allO.txt"%(state2,protein2,title)
ofname14="/home/AD/cesc235/ipython/efhands/%s/%s2_chainB%s_allO.txt"%(state2,protein2,title)
ofname15="/home/AD/cesc235/ipython/efhands/%s/%s3_chainB%s_allO.txt"%(state2,protein2,title)
ofname16="/home/AD/cesc235/ipython/efhands/%s/%s4_chainB%s_allO.txt"%(state2,protein2,title)
protein3="full-single"
state3="single"
ofname17="/home/AD/cesc235/ipython/efhands/%s/%s1_chainA%s_allO.txt"%(state3,protein3,title)
ofname18="/home/AD/cesc235/ipython/efhands/%s/%s2_chainA%s_allO.txt"%(state3,protein3,title)
ofname19="/home/AD/cesc235/ipython/efhands/%s/%s3_chainA%s_allO.txt"%(state3,protein3,title)
ofname20="/home/AD/cesc235/ipython/efhands/%s/%s4_chainA%s_allO.txt"%(state3,protein3,title)
ofname21="/home/AD/cesc235/ipython/efhands/%s/%s1_chainB%s_allO.txt"%(state3,protein3,title)
ofname22="/home/AD/cesc235/ipython/efhands/%s/%s2_chainB%s_allO.txt"%(state3,protein3,title)
ofname23="/home/AD/cesc235/ipython/efhands/%s/%s3_chainB%s_allO.txt"%(state3,protein3,title)
ofname24="/home/AD/cesc235/ipython/efhands/%s/%s4_chainB%s_allO.txt"%(state3,protein3,title)
plotOxyDensityMeanPlot_RuncEF(ofname1,ofname2,ofname3,ofname4,ofname5,ofname6,ofname7,ofname8,\
                        ofname9,ofname10,ofname11,ofname12,ofname13,ofname14,ofname15,ofname16,\
                        ofname17,ofname18,ofname19,ofname20,ofname21,ofname22,ofname23,ofname24,\
                        title)
# Out:
# Holo:  [ 0.         0.         0.         0.         0.         5.32205    0.5566025
#   0.029475   0.1803575  1.0650675  1.2606175  1.610335   2.180745   2.18803
#   2.1469075  1.1013725  0.8173975  1.2889475  0.9902175  0.5013175
#   0.708785   0.11607    0.101845   0.247585   0.309845 ] [ 0.          0.          0.          0.          0.          0.05517787
#   0.05268177  0.00659584  0.04710635  0.1061256   0.09581703  0.22449666
#   0.24363119  0.42879603  0.11166725  0.13307952  0.08252273  0.07284096
#   0.08648079  0.04864015  0.02245078  0.02338059  0.02862749  0.07550593
#   0.04848788]
# Apo:  [ 0.         0.00859    0.0589625  0.14111    0.2068225  0.27001    0.365975
#   0.4638675  0.5365975  0.6546075  0.6111125  0.6830075  0.775295   0.741795
#   0.7505325  0.7824425  0.830735   0.8817075  0.96898    1.09031    1.0023375
#   0.75759    0.647005   0.6061025  0.6216825] [ 0.          0.007459    0.04981531  0.1148685   0.14293653  0.13812359
# ...

# %% [markdown]
# ## Figure 4

# %%
####Electrostatic Scores

##Different charges
font = {'weight' : 'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

def ElectroScore(ofnameBB,ofnameSC):
 qCa=2
 qCOsc=-0.76
 qCObb=-0.51

 #ofnameBB="/home/AD/cesc235/ipython/efhands/ar_full-holo2_chainAcEF_bbO.txt"
 heightBB=np.loadtxt(ofnameBB,skiprows=1,unpack=True)#,usecols=(0,2))#,unpack=True)
 #print heightBB
 #print np.shape(heightBB)

 #ofnameSC="/home/AD/cesc235/ipython/efhands/ar_full-holo2_chainAcEF_scO.txt"
 heightSC=np.loadtxt(ofnameSC,skiprows=1,unpack=True)#,usecols=(0,2))#,unpack=True)
#print heightSC
#print np.shape(heightSC)

 rs=np.linspace(0.5,12,24)
#print rs

 nts=np.shape(heightBB)[0]
#print nts

 ts=np.ones(nts)
#print ts

 denom=np.outer(ts,rs)
 #print denom

#print np.shape(denom)

 fracBB=qCObb*7*heightBB/denom
#print fracBB

 fracSC=qCOsc*7*heightSC/denom
#print fracSC

 fracTot=qCa*(fracBB+fracSC)
#print fracTot

 sumTot=np.sum(fracTot,axis=1)
 #print sumTot

 aver=np.mean(sumTot)
#print aver

 stdev=np.std(sumTot)
#print stdev
 return aver

caseNames=["chainApEF","chainBpEF"]
runs = ["full-holo1","full-holo2","full-holo3","full-holo4"]
nCs=2 #number of cases
nRs=4 #number of runs
Eele=np.zeros((nCs,nRs))
for i,case in enumerate(caseNames):
  for j,run in enumerate(runs): 
    myFileBB="/home/AD/cesc235/ipython/efhands/holo/temp/ar_%s_%s_bbO.txt"%(run,case)
    myFileSC="/home/AD/cesc235/ipython/efhands/holo/temp/ar_%s_%s_scO.txt"%(run,case)
 #   print myFileBB
   # for k in np.arange(nTs):
    Eele[i,j]=ElectroScore(myFileBB,myFileSC)
holo_pEFmean=np.mean(Eele)
holo_pEFstd=np.std(Eele)
print holo_pEFmean, holo_pEFstd

caseNames=["chainAcEF","chainBcEF"]
runs = ["full-holo1","full-holo2","full-holo3","full-holo4"]
nCs=2 #number of cases
nRs=4 #number of runs
Eele=np.zeros((nCs,nRs))
for i,case in enumerate(caseNames):
  for j,run in enumerate(runs): 
    myFileBB="/home/AD/cesc235/ipython/efhands/holo/temp/ar_%s_%s_bbO.txt"%(run,case)
    myFileSC="/home/AD/cesc235/ipython/efhands/holo/temp/ar_%s_%s_scO.txt"%(run,case)
 #   print myFileBB
   # for k in np.arange(nTs):
    Eele[i,j]=ElectroScore(myFileBB,myFileSC)
holo_cEFmean=np.mean(Eele)
holo_cEFstd=np.std(Eele)
print holo_cEFmean, holo_cEFstd

caseNames=["chainApEF","chainBpEF"]
runs = ["full-apo1","full-apo2","full-apo3","full-apo4"]
nCs=2 #number of cases
nRs=4 #number of runs
Eele=np.zeros((nCs,nRs))
for i,case in enumerate(caseNames):
  for j,run in enumerate(runs): 
    myFileBB="/home/AD/cesc235/ipython/efhands/apo/temp/ar_%s_%s_bbO.txt"%(run,case)
    myFileSC="/home/AD/cesc235/ipython/efhands/apo/temp/ar_%s_%s_scO.txt"%(run,case)
 #   print myFileBB
   # for k in np.arange(nTs):
    Eele[i,j]=ElectroScore(myFileBB,myFileSC)
apo_pEFmean=np.mean(Eele)
apo_pEFstd=np.std(Eele)
print apo_pEFmean, apo_pEFstd

caseNames=["chainAcEF","chainBcEF"]
runs = ["full-apo1","full-apo2","full-apo3","full-apo4"]
nCs=2 #number of cases
nRs=4 #number of runs
Eele=np.zeros((nCs,nRs))
for i,case in enumerate(caseNames):
  for j,run in enumerate(runs): 
    myFileBB="/home/AD/cesc235/ipython/efhands/apo/temp/ar_%s_%s_bbO.txt"%(run,case)
    myFileSC="/home/AD/cesc235/ipython/efhands/apo/temp/ar_%s_%s_scO.txt"%(run,case)
 #   print myFileBB
   # for k in np.arange(nTs):
    Eele[i,j]=ElectroScore(myFileBB,myFileSC)
apo_cEFmean=np.mean(Eele)
apo_cEFstd=np.std(Eele)
print apo_cEFmean, apo_cEFstd

caseNames=["chainAcEF","chainBcEF"]
runs = ["full-single1","full-single2","full-single3","full-single4"]
nCs=2 #number of cases
nRs=4 #number of runs
Eele=np.zeros((nCs,nRs))
for i,case in enumerate(caseNames):
  for j,run in enumerate(runs): 
    myFileBB="/home/AD/cesc235/ipython/efhands/single/temp/ar_%s_%s_bbO.txt"%(run,case)
    myFileSC="/home/AD/cesc235/ipython/efhands/single/temp/ar_%s_%s_scO.txt"%(run,case)
 #   print myFileBB
   # for k in np.arange(nTs):
    Eele[i,j]=ElectroScore(myFileBB,myFileSC)
single_cEFmean=np.mean(Eele)
single_cEFstd=np.std(Eele)
print single_cEFmean, single_cEFstd

names=['Apo pEF','Half-Saturated pEF','Holo pEF','Apo cEF','Half-Saturated cEF','Holo cEF']

stds=np.array([apo_pEFstd, 0,  holo_pEFstd, apo_cEFstd, single_cEFstd, holo_cEFstd])

mean=np.array([apo_pEFmean, 0, holo_pEFmean, apo_cEFmean, single_cEFmean, holo_cEFmean])

N = 2.

ind = np.arange(N)  # the x locations for the groups
width = 0.15  

class empty:pass
apo=empty()
apo.names = names[::3]
apo.stds = stds[::3]
apo.mean = mean[::3]
print apo.mean

single = empty()
single.names = names[1::3]
single.stds = stds[1::3]
single.mean = mean[1::3]
print single.mean

holo = empty()
holo.names = names[2::3]
holo.stds = stds[2::3]
holo.mean = mean[2::3]

N = 2.

ind = np.arange(N)  # the x locations for the groups
width = 0.3

class empty:pass
apo=empty()
apo.names = names[::3]
apo.stds = stds[::3]
apo.mean = mean[::3]
print apo.mean

single = empty()
single.names = names[1::3]
single.stds = stds[1::3]
single.mean = mean[1::3]
print single.mean

holo = empty()
holo.names = names[2::3]
holo.stds = stds[2::3]
holo.mean = mean[2::3]
print holo.mean

#fig, ax = plt.subplots(dpi=300,figsize=(15,6))
fig, ax = plt.subplots(dpi=600)
rects1 = ax.bar(ind, apo.mean, width, color='b',yerr=apo.stds,error_kw=dict(elinewidth=2,ecolor='black'))
rects2 = ax.bar(ind+width, single.mean, width, color='g',yerr=single.stds,error_kw=dict(elinewidth=2,ecolor='black'))
rects3 = ax.bar(ind+2*width, holo.mean, width, color='r',yerr=holo.stds,error_kw=dict(elinewidth=2,ecolor='black'))
plt.plot((0.95, 0.95), (0, -8), 'k--')

ax.set_ylabel('Electrostatic Score',fontsize=20,weight="bold")
#ax.set_title('S100A1 Average Electrostatic Score of Ca2+-binding EF hands in the Holo States')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('pEF hand', 'cEF hand'), weight="bold" ,fontsize=20)
ax.legend( (rects1[0],rects2[0],rects3[0]), ('Apo','Half-sat.','Holo'), loc=(2), fontsize=14) 
#ax.legend( (rects1[0]), ('Chain A','Chain B'), loc=(2)) 
ax.set_ylim([-8,0])
ax.set_xlim([0,2])
#plt.gcf().savefig("/home/AD/cesc235/ipython/Eelec/tleap-Eelec_bbsc.png")

##Same charges
font = {'weight' : 'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

def ElectroScore_same(ofnameBB,ofnameSC):
 qCa=2
 qCObb=-0.51
 qCOsc=qCObb

 #ofnameBB="/home/AD/cesc235/ipython/efhands/ar_full-holo2_chainAcEF_bbO.txt"
 heightBB=np.loadtxt(ofnameBB,skiprows=1,unpack=True)#,usecols=(0,2))#,unpack=True)
 #print heightBB
 #print np.shape(heightBB)

 #ofnameSC="/home/AD/cesc235/ipython/efhands/ar_full-holo2_chainAcEF_scO.txt"
 heightSC=np.loadtxt(ofnameSC,skiprows=1,unpack=True)#,usecols=(0,2))#,unpack=True)
#print heightSC
#print np.shape(heightSC)

 rs=np.linspace(0.5,12,24)
#print rs

 nts=np.shape(heightBB)[0]
#print nts

 ts=np.ones(nts)
#print ts

 denom=np.outer(ts,rs)
 #print denom

#print np.shape(denom)

 fracBB=qCObb*7*heightBB/denom
#print fracBB

 fracSC=qCOsc*7*heightSC/denom
#print fracSC

 fracTot=qCa*(fracBB+fracSC)
#print fracTot

 sumTot=np.sum(fracTot,axis=1)
 #print sumTot

 aver=np.mean(sumTot)
#print aver

 stdev=np.std(sumTot)
#print stdev
 return aver

caseNames=["chainApEF","chainBpEF"]
runs = ["full-holo1","full-holo2","full-holo3","full-holo4"]
nCs=2 #number of cases
nRs=4 #number of runs
Eele=np.zeros((nCs,nRs))
for i,case in enumerate(caseNames):
  for j,run in enumerate(runs): 
    myFileBB="/home/AD/cesc235/ipython/efhands/holo/temp/ar_%s_%s_bbO.txt"%(run,case)
    myFileSC="/home/AD/cesc235/ipython/efhands/holo/temp/ar_%s_%s_scO.txt"%(run,case)
 #   print myFileBB
   # for k in np.arange(nTs):
    Eele[i,j]=ElectroScore_same(myFileBB,myFileSC)
holo_pEFmean=np.mean(Eele)
holo_pEFstd=np.std(Eele)
print holo_pEFmean, holo_pEFstd

caseNames=["chainAcEF","chainBcEF"]
runs = ["full-holo1","full-holo2","full-holo3","full-holo4"]
nCs=2 #number of cases
nRs=4 #number of runs
Eele=np.zeros((nCs,nRs))
for i,case in enumerate(caseNames):
  for j,run in enumerate(runs): 
    myFileBB="/home/AD/cesc235/ipython/efhands/holo/temp/ar_%s_%s_bbO.txt"%(run,case)
    myFileSC="/home/AD/cesc235/ipython/efhands/holo/temp/ar_%s_%s_scO.txt"%(run,case)
 #   print myFileBB
   # for k in np.arange(nTs):
    Eele[i,j]=ElectroScore_same(myFileBB,myFileSC)
holo_cEFmean=np.mean(Eele)
holo_cEFstd=np.std(Eele)
print holo_cEFmean, holo_cEFstd

caseNames=["chainApEF","chainBpEF"]
runs = ["full-apo1","full-apo2","full-apo3","full-apo4"]
nCs=2 #number of cases
nRs=4 #number of runs
Eele=np.zeros((nCs,nRs))
for i,case in enumerate(caseNames):
  for j,run in enumerate(runs): 
    myFileBB="/home/AD/cesc235/ipython/efhands/apo/temp/ar_%s_%s_bbO.txt"%(run,case)
    myFileSC="/home/AD/cesc235/ipython/efhands/apo/temp/ar_%s_%s_scO.txt"%(run,case)
 #   print myFileBB
   # for k in np.arange(nTs):
    Eele[i,j]=ElectroScore_same(myFileBB,myFileSC)
apo_pEFmean=np.mean(Eele)
apo_pEFstd=np.std(Eele)
print apo_pEFmean, apo_pEFstd

caseNames=["chainAcEF","chainBcEF"]
runs = ["full-apo1","full-apo2","full-apo3","full-apo4"]
nCs=2 #number of cases
nRs=4 #number of runs
Eele=np.zeros((nCs,nRs))
for i,case in enumerate(caseNames):
  for j,run in enumerate(runs): 
    myFileBB="/home/AD/cesc235/ipython/efhands/apo/temp/ar_%s_%s_bbO.txt"%(run,case)
    myFileSC="/home/AD/cesc235/ipython/efhands/apo/temp/ar_%s_%s_scO.txt"%(run,case)
 #   print myFileBB
   # for k in np.arange(nTs):
    Eele[i,j]=ElectroScore_same(myFileBB,myFileSC)
apo_cEFmean=np.mean(Eele)
apo_cEFstd=np.std(Eele)
print apo_cEFmean, apo_cEFstd

caseNames=["chainAcEF","chainBcEF"]
runs = ["full-single1","full-single2","full-single3","full-single4"]

nCs=2 #number of cases
nRs=4 #number of runs
Eele=np.zeros((nCs,nRs))
for i,case in enumerate(caseNames):
  for j,run in enumerate(runs): 
    myFileBB="/home/AD/cesc235/ipython/efhands/single/temp/ar_%s_%s_bbO.txt"%(run,case)
    myFileSC="/home/AD/cesc235/ipython/efhands/single/temp/ar_%s_%s_scO.txt"%(run,case)
 #   print myFileBB
   # for k in np.arange(nTs):
    Eele[i,j]=ElectroScore_same(myFileBB,myFileSC)
single_cEFmean=np.mean(Eele)
single_cEFstd=np.std(Eele)
print single_cEFmean, single_cEFstd

names=['Apo pEF','Half-Sat. pEF','Holo pEF','Apo cEF','Half-Sat. cEF','Holo cEF']

stds=np.array([apo_pEFstd, 0,  holo_pEFstd, apo_cEFstd, single_cEFstd, holo_cEFstd])

mean=np.array([apo_pEFmean, 0, holo_pEFmean, apo_cEFmean, single_cEFmean, holo_cEFmean])

N = 2.

ind = np.arange(N)  # the x locations for the groups
width = 0.15  
width = 0.3

class empty:pass
apo=empty()
apo.names = names[::3]
apo.stds = stds[::3]
apo.mean = mean[::3]
print apo.mean

single = empty()
single.names = names[1::3]
single.stds = stds[1::3]
single.mean = mean[1::3]
print single.mean

holo = empty()
holo.names = names[2::3]
holo.stds = stds[2::3]
holo.mean = mean[2::3]
print holo.mean

plt.figure()
#fig, ax = plt.subplots(dpi=300,figsize=(15,6))
fig, ax = plt.subplots(dpi=600)
rects1 = ax.bar(ind, apo.mean, width, color='b',yerr=apo.stds,error_kw=dict(elinewidth=2,ecolor='black'))
rects2 = ax.bar(ind+width, single.mean, width, color='g',yerr=single.stds,error_kw=dict(elinewidth=2,ecolor='black'))
rects3 = ax.bar(ind+2*width, holo.mean, width, color='r',yerr=holo.stds,error_kw=dict(elinewidth=2,ecolor='black'))
plt.plot((0.95, 0.95), (0, -8), 'k--')
         
ax.set_ylabel('Electrostatic Score',fontsize=20,weight="bold")
#ax.set_title('S100A1 Average Electrostatic Score of Ca2+-binding EF hands in the Holo States')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('pEF hand', 'cEF hand'), weight="bold" ,fontsize=20)
ax.legend( (rects1[0],rects2[0],rects3[0]), ('Apo','Half-sat.','Holo'), loc=(2), fontsize=14) 
#ax.legend( (rects1[0]), ('Chain A','Chain B'), loc=(2)) 
ax.set_ylim([-8,0])
ax.set_xlim([0,2])
#plt.gcf().savefig("/home/AD/cesc235/ipython/Eelec/tleap-Eelec_same.png")
# Out:
# -5.86806062125 0.0424539214708
# -7.32512843234
#  0.28860490611
# -4.72203489193
#  0.320597281148
# -3.80466982939
#  0.295579344633
# -7.58325032377
#  0.0668331524723
# [-4.72203489 -3.80466983]
# [ 0.         -7.58325032]
# [-4.72203489 -3.80466983]
# [ 0.         -7.58325032]
# [-5.86806062 -7.32512843]
# -4.96024538199
#  0.0426786238607
# -5.57513044333
#  0.203271992436
# -4.05187909298
#  0.242403370414
# -3.16727018888
#  0.20929343815
# -5.7361408922
#  0.0668205675005
# [-4.05187909 -3.16727019]
# [ 0.         -5.73614089]
# [-4.96024538 -5.57513044]
# (0, 2)

# %% [markdown]
# ## Figure 5

# %%
font = {'weight' : 'bold',
        'size'   : 16}
matplotlib.rc('font', **font)

import numpy as np
import matplotlib.pyplot as plt
    
def plotAveAtomicDist(inNameA, inNameB, inNameC, inNameD, inNameE, inNameF, inNameG, inNameH):

 time=[]

 a=np.loadtxt(inNameA, usecols=(0,1))
 time=a[:,0]/5

 b=np.loadtxt(inNameB, usecols=(0,1))
 c=np.loadtxt(inNameC, usecols=(0,1))
 d=np.loadtxt(inNameD, usecols=(0,1))
 e=np.loadtxt(inNameE, usecols=(0,1))
 f=np.loadtxt(inNameF, usecols=(0,1))
 g=np.loadtxt(inNameG, usecols=(0,1)) 
 h=np.loadtxt(inNameH, usecols=(0,1))

 data_1 = np.zeros([np.shape(a)[0],2])
 data_1[:,0]=a[:,1];data_1[:,1] = b[:,1]
 AveDistAve1=np.mean(data_1)
    
 data_2 = np.zeros([np.shape(c)[0],2])
 data_2[:,0]=c[:,1];data_2[:,1] = d[:,1]
 AveDistAve2=np.mean(data_2)
    
 data_3 = np.zeros([np.shape(e)[0],2])   
 data_3[:,0]=e[:,1];data_3[:,1] = f[:,1]
 AveDistAve3=np.mean(data_3)
    
 data_4 = np.zeros([np.shape(g)[0],2]) 
 data_4[:,0]=g[:,1];data_4[:,1] = h[:,1]
 AveDistAve4=np.mean(data_4)
  
 array_AveDist=np.array([AveDistAve1,AveDistAve2,AveDistAve3,AveDistAve4])
 AveDistAve=np.mean(array_AveDist)
 AveDistStd=np.std(array_AveDist)
 
 return (AveDistAve, AveDistStd) 

residN1="28"
residO1="69"
residN2="121"
residO2="162"
file1="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/N%s-O%s.txt"%(residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/N%s-O%s.txt"%(residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/N%s-O%s.txt"%(residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/N%s-O%s.txt"%(residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/N%s-O%s.txt"%(residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/N%s-O%s.txt"%(residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/N%s-O%s.txt"%(residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/N%s-O%s.txt"%(residN2,residO2)
apo1Ave, apo1Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print apo1Ave
print apo1Std

residN1="30"
residO1="67"
residN2="123"
residO2="160"
file1="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/N%s-O%s.txt"%(residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/N%s-O%s.txt"%(residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/N%s-O%s.txt"%(residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/N%s-O%s.txt"%(residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/N%s-O%s.txt"%(residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/N%s-O%s.txt"%(residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/N%s-O%s.txt"%(residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/N%s-O%s.txt"%(residN2,residO2)
apo2Ave, apo2Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print apo2Ave
print apo2Std

residN1="31"
residO1="65"
residN2="124"
residO2="158"
file1="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/N%s-O%s.txt"%(residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/N%s-O%s.txt"%(residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/N%s-O%s.txt"%(residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/N%s-O%s.txt"%(residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/N%s-O%s.txt"%(residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/N%s-O%s.txt"%(residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/N%s-O%s.txt"%(residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/N%s-O%s.txt"%(residN2,residO2)
apo3Ave, apo3Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print apo3Ave
print apo3Std

residN1="71"
residO1="26"
residN2="164"
residO2="119"
file1="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/N%s-O%s.txt"%(residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/N%s-O%s.txt"%(residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/N%s-O%s.txt"%(residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/N%s-O%s.txt"%(residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/N%s-O%s.txt"%(residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/N%s-O%s.txt"%(residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/N%s-O%s.txt"%(residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/N%s-O%s.txt"%(residN2,residO2)
apo5Ave, apo5Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print apo5Ave
print apo5Std

residN1="28"
residO1="69"
residN2="121"
residO2="162"
file1="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_1/N%s-O%s.txt"%(residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_1/N%s-O%s.txt"%(residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_2/N%s-O%s.txt"%(residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_2/N%s-O%s.txt"%(residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_3/N%s-O%s.txt"%(residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_3/N%s-O%s.txt"%(residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_4/N%s-O%s.txt"%(residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_4/N%s-O%s.txt"%(residN2,residO2)
holo1Ave, holo1Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print holo1Ave
print holo1Std

residN1="30"
residO1="67"
residN2="123"
residO2="160"
state="holo"
nmr="2LP3"
file1="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
holo2Ave, holo2Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print holo2Ave
print holo2Std

residN1="31"
residO1="65"
residN2="124"
residO2="158"
state="holo"
nmr="2LP3"
file1="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
holo3Ave, holo3Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print holo3Ave
print holo3Std

residN1="71"
residO1="26"
residN2="164"
residO2="119"
state="holo"
nmr="2LP3"
file1="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state,state,nmr,residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state,state,nmr,residN2,residO2)
holo5Ave, holo5Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print holo5Ave
print holo5Std

residN1="28"
residO1="69"
residN2="121"
residO2="162"
state1="single"
state2="holo"
nmr="Cterm"
file1="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
cterm1Ave, cterm1Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print cterm1Ave
print cterm1Std

residN1="30"
residO1="67"
residN2="123"
residO2="160"
state1="single"
state2="holo"
nmr="Cterm"
file1="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
cterm2Ave, cterm2Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print cterm2Ave
print cterm2Std

residN1="31"
residO1="65"
residN2="124"
residO2="158"
state1="single"
state2="holo"
nmr="Cterm"
file1="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
cterm3Ave, cterm3Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print cterm3Ave
print cterm3Std

residN1="71"
residO1="26"
residN2="164"
residO2="119"
state1="single"
state2="holo"
nmr="Cterm"
file1="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file2="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_1/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file3="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file4="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_2/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file5="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file6="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_3/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
file7="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state1,state2,nmr,residN1,residO1)
file8="/u1/cesc235/analysis/tleap/full-%s/full-traj-141215/WT_%s_%s_4/N%s-O%s.txt"%(state1,state2,nmr,residN2,residO2)
cterm5Ave, cterm5Std = plotAveAtomicDist(file1,file2,file3,file4,file5,file6,file7,file8)
print cterm5Ave
print cterm5Std

names=['Apo: 28-69', 'Holo: 28-69','+cEF: 28-69',\
       'Apo: 30-67','Holo: 30-67','+cEF: 30-67',\
       'Apo: 31-65','Holo: 31-65','+cEF: 31-65',\
       'Apo: 71-25','Holo: 71-25','+cEF: 71-25']

stds=np.array([apo1Std,holo1Std,cterm1Std,\
               apo2Std,holo2Std,cterm2Std,\
               apo3Std,holo3Std,cterm3Std,\
               apo5Std,holo5Std,cterm5Std])

means=np.array([apo1Ave,holo1Ave,cterm1Ave,\
               apo2Ave,holo2Ave,cterm2Ave,\
               apo3Ave,holo3Ave,cterm3Ave,\
               apo5Ave,holo5Ave,cterm5Ave])

N = 4.

ind = np.arange(N)  # the x locations for the groups
width = 0.25  

class empty:pass
apo=empty()
apo.names = names[::3]
apo.means = means[::3]
apo.stds = stds[::3]

holo = empty()
holo.names = names[1::3]
holo.means = means[1::3]
holo.stds = stds[1::3]

cterm = empty()
cterm.names = names[2::3]
cterm.means = means[2::3]
cterm.stds = stds[2::3]

fig, ax = plt.subplots(dpi=300,figsize=(15,6))
rects1 = ax.bar(ind, apo.means, width, color='b',yerr=apo.stds,error_kw=dict(elinewidth=3,capsize=3,markeredgewidth=3,ecolor="k"))
rects2 = ax.bar(ind+width, holo.means, width, color='r',yerr=holo.stds,error_kw=dict(elinewidth=3,capsize=3,markeredgewidth=3,ecolor="k"))
rects3 = ax.bar(ind+2*width, cterm.means, width, color='g',yerr=cterm.stds,error_kw=dict(elinewidth=3,capsize=3,markeredgewidth=3,ecolor="k"))

#name="Dist. between backbone N and O"
#ax.set_title(name)
ax.set_ylabel('Dist. between backbone \n atoms N and O [$\AA$]',fontsize=20, weight="bold")
ax.set_xticks(ind+width)
ax.set_ylim([0,20])
ax.set_xticklabels( ('K28-V69', 'K30-D67', 'K31-G65', 'F71-K25'),fontsize=20)
ax.legend( (rects1[0],rects2[0],rects3[0]), \
          ('Apo Ave.','Holo Ave.','Half-Sat. Ave.'), loc=(0)) 
plt.plot([0,4],[3.5,3.5],linewidth=3,color="y")

#outFile="/u1/cesc235/analysis/tleap/MeanDist-tleap_N-O.png"
#plt.gcf().savefig(outFile)
# Out:
# 3.24654316075
# 0.338582798473
# 3.003768133
# 0.0441071951049
# 4.3253371865
# 1.76587966524
# 4.57698162525
# 1.06275517307
# 3.4694748105
# 0.777852910382
# 6.3353585705
# 1.2585226242
# 15.429438785
# 0.85069333515
# 5.2730225765
# 0.561374543574
# 3.800116879
# 0.824721480299
# 7.23925382875
# 1.26611758789
# 15.9791223097
# 1.03983787348
# 4.7395873385
# 0.96022062198

# %% [markdown]
# ## Figure 6

# %%
####Interhelical analysis for MD simulations of the Apo vs. Half-saturated S100A1 protein

##Please run the bash script located on kafka at: /u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_*/interhlx/analyze.sh

##See therein for details.

font = {'weight' : 'bold',
        'size'   : 16}
matplotlib.rc('font', **font)

#Reference Apo Angles

#2L0P 
#Angles *checked with interhlx (boell: /u1/cesc235/pdb/)
#H1-3 -44.6
#H2-3  154.2 (Rat is 148 according to Rustandi et al., 2001)
#H3-4 -166.6 (from Nowakowski et al., 2013)

#Alpha-Helices Start/Stop residues (from Nowakowski et al., 2011)
#H1 3-18
#H2 30-41
#H3 51-64
#H4 71-86

#2LLU (different from Zivkovic et al., 2012) *checked with interhlx (boell: /u1/cesc235/pdb/2LLU)
#Angles
#H1-3 -31.1
#H2-3 -125.7
#H3-4 -152.4

#Alpha-Helices Start/Stop residues
#H1 3-17
#H2 30-40
#H3 51-63
#H4 71-86

#Calculations run with interhlx here: boell:/u1/cesc235/pdb
apo2L0PH13Std_ref=21.894
apo2L0PH13Ang_ref=-44.6
apo2L0PH23Std_ref=1.275
apo2L0PH23Ang_ref=154.2
apo2L0PH43Std_ref=1.719
apo2L0PH43Ang_ref=-166.6

apo2LLUH13Std_ref=15.259
apo2LLUH13Ang_ref=-31.1
apo2LLUH23Std_ref=1.226
apo2LLUH23Ang_ref=125.7
apo2LLUH43Std_ref=0.993
apo2LLUH43Ang_ref=-152.4

def findAverageMeanAngleApo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,apo_ref):
    
     vAi=np.loadtxt(ofnameA,usecols=(1,3))
     vBi=np.loadtxt(ofnameB,usecols=(1,3))
     vCi=np.loadtxt(ofnameC,usecols=(1,3))
     vDi=np.loadtxt(ofnameD,usecols=(1,3))
     vEi=np.loadtxt(ofnameE,usecols=(1,3))
     vFi=np.loadtxt(ofnameF,usecols=(1,3))
     vGi=np.loadtxt(ofnameG,usecols=(1,3))
     vHi=np.loadtxt(ofnameH,usecols=(1,3))
     
     sign=apo_ref/abs(apo_ref)
     vA=sign*abs(vAi)
     vB=sign*abs(vBi)
     vC=sign*abs(vCi)
     vD=sign*abs(vDi)
     vE=sign*abs(vEi)
     vF=sign*abs(vFi)
     vG=sign*abs(vGi)
     vH=sign*abs(vHi)
        
     #print vH
        
     data2L0P_1 = np.zeros([np.shape(vA)[0],2])
     data2L0P_1[:,0] = vA[:,0]; data2L0P_1[:,1] = vB[:,0] 
     mean2L0P_1=np.mean(data2L0P_1)
        
     data2L0P_2 = np.zeros([np.shape(vC)[0],2])
     data2L0P_2[:,0] = vC[:,0]; data2L0P_2[:,1] = vD[:,0]
     mean2L0P_2=np.mean(data2L0P_2)
     
     two_2L0Pmeans=np.array([mean2L0P_1,mean2L0P_2])
     mean2L0P=np.mean(two_2L0Pmeans)
     std2L0P=np.std(two_2L0Pmeans)
     
     data2LLU_1 = np.zeros([np.shape(vE)[0],2])
     data2LLU_1[:,0] = vE[:,0]; data2LLU_1[:,1] = vF[:,0]
     mean2LLU_1=np.mean(data2LLU_1)
    
     data2LLU_2 = np.zeros([np.shape(vG)[0],2])     
     data2LLU_2[:,0] = vG[:,0]; data2LLU_2[:,1] = vH[:,0]
     mean2LLU_2=np.mean(data2LLU_2)

     two_2LLUmeans=np.array([mean2LLU_1,mean2LLU_2])
     mean2LLU=np.mean(two_2LLUmeans)
     std2LLU=np.std(two_2LLUmeans)
    
     return mean2L0P,std2L0P,mean2LLU,std2LLU

prefix="/u1/cesc235/analysis/tleap/"
apo_ref=apo2L0PH13Ang_ref
helixA=1
helixB=3
state="apo"
nmr1="2L0P"
nmr2="2LLU"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr2,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr2,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr2,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr2,helixA,helixB)

apo2L0PH13Mean,apo2L0PH13Std,apo2LLUH13Mean,apo2LLUH13Std=findAverageMeanAngleApo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,\
                                                                              ofnameF,ofnameG,ofnameH,apo_ref)

print apo2L0PH13Mean,apo2L0PH13Std,apo2LLUH13Mean,apo2LLUH13Std

prefix="/u1/cesc235/analysis/tleap/"
apo_ref=apo2L0PH23Ang_ref
helixA=2
helixB=3
state="apo"
nmr1="2L0P"
nmr2="2LLU"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr2,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr2,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr2,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr2,helixA,helixB)

apo2L0PH23Mean,apo2L0PH23Std,apo2LLUH23Mean,apo2LLUH23Std=findAverageMeanAngleApo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,\
                                                                              ofnameF,ofnameG,ofnameH,apo_ref)

print apo2L0PH23Mean,apo2L0PH23Std,apo2LLUH23Mean,apo2LLUH23Std

prefix="/u1/cesc235/analysis/tleap/"
apo_ref=apo2L0PH43Ang_ref
helixA=4
helixB=3
state="apo"
nmr1="2L0P"
nmr2="2LLU"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr1,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr2,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr2,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state,state,nmr2,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state,state,nmr2,helixA,helixB)

apo2L0PH43Mean,apo2L0PH43Std,apo2LLUH43Mean,apo2LLUH43Std=findAverageMeanAngleApo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,\
                                                                              ofnameF,ofnameG,ofnameH,apo_ref)

print apo2L0PH43Mean,apo2L0PH43Std,apo2LLUH43Mean,apo2LLUH43Std

def findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref):
    
     vAi=np.loadtxt(ofnameA,usecols=(1,3))
     vBi=np.loadtxt(ofnameB,usecols=(1,3))
     vCi=np.loadtxt(ofnameC,usecols=(1,3))
     vDi=np.loadtxt(ofnameD,usecols=(1,3))
     vEi=np.loadtxt(ofnameE,usecols=(1,3))
     vFi=np.loadtxt(ofnameF,usecols=(1,3))
     vGi=np.loadtxt(ofnameG,usecols=(1,3))
     vHi=np.loadtxt(ofnameH,usecols=(1,3))
     
     sign=holo_ref/abs(holo_ref)
     vA=sign*abs(vAi)
     vB=sign*abs(vBi)
     vC=sign*abs(vCi)
     vD=sign*abs(vDi)
     vE=sign*abs(vEi)
     vF=sign*abs(vFi)
     vG=sign*abs(vGi)
     vH=sign*abs(vHi)
        
     #print vH
        
     data1 = np.zeros([np.shape(vA)[0],2])
     data2 = np.zeros([np.shape(vC)[0],2])
     data3 = np.zeros([np.shape(vE)[0],2])
     data4 = np.zeros([np.shape(vG)[0],2])   
     data1[:,0] = vA[:,0]; data1[:,1] = vB[:,0]
     data2[:,0] = vC[:,0]; data2[:,1] = vD[:,0]
     data3[:,0] = vE[:,0]; data3[:,1] = vF[:,0]
     data4[:,0] = vG[:,0]; data4[:,1] = vH[:,0]
     mean1=np.mean(data1)
     mean2=np.mean(data2)
     mean3=np.mean(data3)
     mean4=np.mean(data4)
     four_means=np.array([mean1,mean2,mean3,mean4])
     mean=np.mean(four_means)
     std=np.std(four_means)
     print mean1, mean2, mean3, mean4
       
     return mean,std

prefix="/u1/cesc235/analysis/tleap/"
holo_ref=holoH13Ang_ref
helixA=1
helixB=3
state1="single"
state2="holo"
nmr="Cterm"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)

CtermH13Mean,CtermH13Std=findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref)

print CtermH13Mean, CtermH13Std

prefix="/u1/cesc235/analysis/tleap/"
holo_ref=holoH23Ang_ref
helixA=2
helixB=3
state1="single"
state2="holo"
nmr="Cterm"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)

CtermH23Mean,CtermH23Std=findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref)

print CtermH23Mean, CtermH23Std

prefix="/u1/cesc235/analysis/tleap/"
holo_ref=holoH43Ang_ref
helixA=4
helixB=3
state1="single"
state2="holo"
nmr="Cterm"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)

CtermH43Mean,CtermH43Std=findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref)

print CtermH43Mean, CtermH43Std

aponames=(['apo-ref 2L0P H1-H3','apo 2L0P H1-H3','apo-ref 2LLU H1-H3','apo 2LLU H1-H3','+cEF H1-H3',\
       'apo-ref 2L0P H2-H3','apo 2L0P H2-H3','apo-ref 2LLU H2-H3','apo 2LLU H2-H3','+cEF H2-H3',\
       'apo-ref 2L0P H4-H3','apo 2L0P H4-H3','apo-ref 2LLU H4-H3','apo 2LLU H4-H3','+cEF H4-H3',])
       

apostds=np.array([apo2L0PH13Std_ref,apo2L0PH13Std,apo2LLUH13Std_ref,apo2LLUH13Std,CtermH13Std,\
               apo2L0PH23Std_ref,apo2L0PH23Std,apo2LLUH23Std_ref,apo2LLUH23Std,CtermH23Std,\
               apo2L0PH43Std_ref,apo2L0PH43Std,apo2LLUH13Std_ref,apo2LLUH43Std,CtermH43Std,])

apomeans=np.array([apo2L0PH13Ang_ref,apo2L0PH13Mean,apo2LLUH13Ang_ref,apo2LLUH13Mean,CtermH13Mean,\
               apo2L0PH23Ang_ref,apo2L0PH23Mean,apo2LLUH23Ang_ref,apo2LLUH23Mean,CtermH23Mean,\
               apo2L0PH43Ang_ref,apo2L0PH43Mean,apo2LLUH43Ang_ref,apo2LLUH43Mean,CtermH43Mean])

import numpy as np
import matplotlib.pyplot as plt

N = 3.

ind = np.arange(N)  # the x locations for the groups
width = 0.15  

class empty:pass
apo2L0P_ref=empty()
apo2L0P_ref.aponames = aponames[::5]
apo2L0P_ref.apomeans = apomeans[::5]
apo2L0P_ref.apostds = apostds[::5]

apo_2L0Pave = empty()
apo_2L0Pave.aponames = aponames[1::5]
apo_2L0Pave.apomeans = apomeans[1::5]
apo_2L0Pave.apostds = apostds[1::5]

apo2LLU_ref=empty()
apo2LLU_ref.aponames = aponames[2::5]
apo2LLU_ref.apomeans = apomeans[2::5]
apo2LLU_ref.apostds = apostds[2::5]

apo_2LLUave = empty()
apo_2LLUave.aponames = aponames[3::5]
apo_2LLUave.apomeans = apomeans[3::5]
apo_2LLUave.apostds = apostds[3::5]

cterm_ave=empty()
cterm_ave.aponames = aponames[4::5]
cterm_ave.apomeans = apomeans[4::5]
cterm_ave.apostds = apostds[4::5]

fig, ax = plt.subplots(dpi=300,figsize=(15,6))
rects1 = ax.bar(ind, apo2L0P_ref.apomeans, width, color='w',edgecolor='b',hatch='////',yerr=apo2L0P_ref.apostds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects2 = ax.bar(ind+width, apo_2L0Pave.apomeans, width, color='b',edgecolor='b',yerr=apo_2L0Pave.apostds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects3 = ax.bar(ind+2*width, apo2LLU_ref.apomeans, width, color='w',edgecolor='c',hatch='////',yerr=apo2LLU_ref.apostds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects4 = ax.bar(ind+3*width, apo_2LLUave.apomeans, width, color='c',edgecolor='c',yerr=apo_2LLUave.apostds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects5 = ax.bar(ind+4*width+0.04, cterm_ave.apomeans, width, color='g',edgecolor='g',yerr=cterm_ave.apostds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))

ax.set_ylabel('Angle between Two Helices',fontsize=20, weight="bold")
#ax.set_title('Apo Interhelix Angels')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('Helix1-\nHelix3','Helix2-\nHelix3','Helix3-\nHelix4'),fontsize=20,weight="bold")
ax.legend( (rects1[0],rects2[0],rects3[0],rects4[0],rects5[0]), \
          ('Apo-2L0P Ref','Apo-2L0P Ave','Apo-2LLU Ref','Apo-2LLU Ave','Half-Sat. Ave'),\
          fontsize=14,loc=(2)) 
plt.plot((0, 3), (0, 0), 'k--')

#plt.gcf().savefig("apo-interhlx.png",dpi=600)
# Out:
# -41.9246705 4.3202895 -34.0828125 3.6703045
# 148.1039595
#  3.1692145 138.5954525 7.0818835
# -157.1670875 3.8467005 -150.440055 7.275739
# -119.507801
#  -113.453156 -115.07349 -110.086781
# -114.530307 3.3902681266
# 113.708709 126.285305 123.59863 145.426306
# 127.2547375 11.4892091905
# 120.03387
#  128.132701 123.129927 145.162449
# 129.11473675 9.70532780678

# %% [markdown]
# ## Figure 7

# %%
####Interhelical analysis for MD simulations of the Holo vs. Half-saturated S100A1 protein

##In preparation for this workbook, some prior data analysis is necessary.

font = {'weight' : 'bold',
        'size'   : 16}
matplotlib.rc('font', **font)

#Reference Holo Angles

#2LP3 (from Nowakowski et al., 2013) *checked with interhlx (boell: /u1/cesc235/pdb/)
#Angles
#H1-3 -109.1
#H2-3  118.5
#H3-4  129.9

#Alpha-Helices Start/Stop residues (from Nowakowski et al., 2013)
#H1 3-20
#H2 30-40
#H3 53-61
#H4 71-91

#Calculations run with interhlx here: boell:/u1/cesc235/pdb
holoH13Std_ref=4.056
holoH13Ang_ref=-109.1
holoH23Std_ref=4.905
holoH23Ang_ref=118.5
holoH43Std_ref=3.561
holoH43Ang_ref=129.9

def findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref):
    
     vAi=np.loadtxt(ofnameA,usecols=(1,3))
     vBi=np.loadtxt(ofnameB,usecols=(1,3))
     vCi=np.loadtxt(ofnameC,usecols=(1,3))
     vDi=np.loadtxt(ofnameD,usecols=(1,3))
     vEi=np.loadtxt(ofnameE,usecols=(1,3))
     vFi=np.loadtxt(ofnameF,usecols=(1,3))
     vGi=np.loadtxt(ofnameG,usecols=(1,3))
     vHi=np.loadtxt(ofnameH,usecols=(1,3))
     
     sign=holo_ref/abs(holo_ref)
     vA=sign*abs(vAi)
     vB=sign*abs(vBi)
     vC=sign*abs(vCi)
     vD=sign*abs(vDi)
     vE=sign*abs(vEi)
     vF=sign*abs(vFi)
     vG=sign*abs(vGi)
     vH=sign*abs(vHi)
        
     #print vH
        
     data1 = np.zeros([np.shape(vA)[0],2])
     data2 = np.zeros([np.shape(vC)[0],2])
     data3 = np.zeros([np.shape(vE)[0],2])
     data4 = np.zeros([np.shape(vG)[0],2])   
     data1[:,0] = vA[:,0]; data1[:,1] = vB[:,0]
     data2[:,0] = vC[:,0]; data2[:,1] = vD[:,0]
     data3[:,0] = vE[:,0]; data3[:,1] = vF[:,0]
     data4[:,0] = vG[:,0]; data4[:,1] = vH[:,0]
     mean1=np.mean(data1)
     mean2=np.mean(data2)
     mean3=np.mean(data3)
     mean4=np.mean(data4)
     four_means=np.array([mean1,mean2,mean3,mean4])
     mean=np.mean(four_means)
     std=np.std(four_means)
     print mean1, mean2, mean3, mean4
       
     return mean,std

prefix="/u1/cesc235/analysis/tleap/"
holo_ref=holoH13Ang_ref
helixA=1
helixB=3
state1="holo"
state2="holo"
nmr="2LP3"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)

holoH13Mean,holoH13Std=findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref)

print holoH13Mean, holoH13Std

prefix="/u1/cesc235/analysis/tleap/"
holo_ref=holoH23Ang_ref
helixA=2
helixB=3
state1="holo"
state2="holo"
nmr="2LP3"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)

holoH23Mean,holoH23Std=findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref)

print holoH23Mean, holoH23Std

prefix="/u1/cesc235/analysis/tleap/"
holo_ref=holoH43Ang_ref
helixA=4
helixB=3
state1="holo"
state2="holo"
nmr="2LP3"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)

holoH43Mean,holoH43Std=findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref)

print holoH43Mean, holoH43Std

prefix="/u1/cesc235/analysis/tleap/"
holo_ref=holoH13Ang_ref
helixA=1
helixB=3
state1="single"
state2="holo"
nmr="Cterm"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)

CtermH13Mean,CtermH13Std=findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref)

print CtermH13Mean, CtermH13Std

prefix="/u1/cesc235/analysis/tleap/"
holo_ref=holoH23Ang_ref
helixA=2
helixB=3
state1="single"
state2="holo"
nmr="Cterm"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)

CtermH23Mean,CtermH23Std=findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref)

print CtermH23Mean, CtermH23Std

prefix="/u1/cesc235/analysis/tleap/"
holo_ref=holoH43Ang_ref
helixA=4
helixB=3
state1="single"
state2="holo"
nmr="Cterm"

ofnameA=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameB=prefix+"full-%s/full-traj-141215/WT_%s_%s_1/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameC=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameD=prefix+"full-%s/full-traj-141215/WT_%s_%s_2/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameE=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameF=prefix+"full-%s/full-traj-141215/WT_%s_%s_3/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameG=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listA.txt"\
%(state1,state2,nmr,helixA,helixB)
ofnameH=prefix+"full-%s/full-traj-141215/WT_%s_%s_4/interhlx/angle-output_H%s-H%s_listB.txt"\
%(state1,state2,nmr,helixA,helixB)

CtermH43Mean,CtermH43Std=findAverageMeanAngleHolo(ofnameA,ofnameB,ofnameC,ofnameD,ofnameE,ofnameF,ofnameG,ofnameH,holo_ref)

print CtermH43Mean, CtermH43Std

holonames=(['holo-ref H1-H3','holo H1-H3','+cEF H1-H3',\
       'holo-ref H2-H3','holo H2-H3','+cEF H2-H3',\
       'holo-ref H4-H3','holo H4-H3','+cEF H4-H3'])

holostds=([holoH13Std_ref,holoH13Std,CtermH13Std,\
               holoH23Std_ref,holoH23Std,CtermH23Std,\
               holoH43Std_ref,holoH43Std,CtermH43Std])
                
holomeans=([holoH13Ang_ref,holoH13Mean,CtermH13Mean,\
               holoH23Ang_ref,holoH23Mean,CtermH23Mean,\
               holoH43Ang_ref,holoH43Mean,CtermH43Mean])

import numpy as np
import matplotlib.pyplot as plt

N = 3.

ind = np.arange(N)  # the x locations for the groups
width = 0.20  

class empty:pass
holo_ref=empty()
holo_ref.holonames = holonames[::3]
holo_ref.holomeans = holomeans[::3]
holo_ref.holostds = holostds[::3]

holo_ave=empty()
holo_ave.holonames = holonames[1::3]
holo_ave.holomeans = holomeans[1::3]
holo_ave.holostds = holostds[1::3]

cterm_ave=empty()
cterm_ave.holonames = holonames[2::3]
cterm_ave.holomeans = holomeans[2::3]
cterm_ave.holostds = holostds[2::3]

fig, ax = plt.subplots(dpi=300,figsize=(15,6))
rects1 = ax.bar(ind, holo_ref.holomeans, width, color='w',edgecolor='r',hatch='////', yerr=holo_ref.holostds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects2 = ax.bar(ind+width, holo_ave.holomeans, width, color='r',yerr=holo_ave.holostds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects3 = ax.bar(ind+2*width+0.04, cterm_ave.holomeans, width, color='g',yerr=cterm_ave.holostds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))


ax.set_ylabel('Angle between Two Helices',fontsize=20, weight="bold")
#ax.set_title('Holo Interhelix Angels')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('Helix1-\nHelix3','Helix2-\nHelix3','Helix3-\nHelix4') ,fontsize=20)
ax.legend( (rects1[0],rects2[0],rects3[0]), ('Holo-2LP3 Ref','Holo Ave','Half-Sat. Ave'), loc=(0)) 
plt.plot((0, 3), (0, 0), 'k--')

#plt.gcf().savefig("holo-interhlx.png")
# Out:
# -133.371738 -117.92479 -114.831689 -126.328994
# -123.11430275 7.26432981862
# 101.784909 121.117806 115.907702 112.051363
# 112.715445 7.08356896766
# 102.134305
#  119.796015 126.197006 113.258155
# 115.34637025 8.89459028962
# -119.507801 -113.453156 -115.07349 -110.086781
# -114.530307
#  3.3902681266
# 113.708709 126.285305 123.59863 145.426306
# 127.2547375 11.4892091905
# 120.03387
#  128.132701 123.129927 145.162449
# 129.11473675 9.70532780678

# %% [markdown]
# ## Figure S1

# %%
####RMSF Analaysis
##Tleap: Correct protonation, 100 ns

font = {'weight' : 'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

import numpy as np
import matplotlib.pyplot as plt

myApoA1="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/CA_proA_rmsf.txt"
myApoB1="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_1/CA_proB_rmsf.txt"
a1=np.loadtxt(myApoA1, usecols=(1,2),skiprows=2)
b1=np.loadtxt(myApoB1, usecols=(1,2),skiprows=2)
dataApo1 = np.zeros([np.shape(a1)[0],2])
dataApo1[:,0]=a1[:,1];dataApo1[:,1] = b1[:,1]

myApoA2="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/CA_proA_rmsf.txt"
myApoB2="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2L0P_2/CA_proB_rmsf.txt"
a2=np.loadtxt(myApoA2, usecols=(1,2),skiprows=2)
b2=np.loadtxt(myApoB2, usecols=(1,2),skiprows=2)
dataApo2 = np.zeros([np.shape(a2)[0],2])
dataApo2[:,0]=a2[:,1];dataApo2[:,1] = b2[:,1]

myApoA3="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/CA_proA_rmsf.txt"
myApoB3="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_1/CA_proB_rmsf.txt"
a3=np.loadtxt(myApoA3, usecols=(1,2),skiprows=2)
b3=np.loadtxt(myApoB3, usecols=(1,2),skiprows=2)
dataApo3 = np.zeros([np.shape(a3)[0],2])
dataApo3[:,0]=a3[:,1];dataApo3[:,1] = b3[:,1]

myApoA4="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/CA_proA_rmsf.txt"
myApoB4="/u1/cesc235/analysis/tleap/full-apo/full-traj-141215/WT_apo_2LLU_2/CA_proB_rmsf.txt"
a4=np.loadtxt(myApoA4, usecols=(1,2),skiprows=2)
b4=np.loadtxt(myApoB4, usecols=(1,2),skiprows=2)
dataApo4 = np.zeros([np.shape(a4)[0],2])
dataApo4[:,0]=a4[:,1];dataApo4[:,1] = b4[:,1]

#Apo_array=np.array([dataApo1,dataApo2,dataApo3,dataApo4])
dataApo = np.zeros([np.shape(a1)[0],8])
dataApo[:,0]=a1[:,1];dataApo[:,1] = b1[:,1];\
dataApo[:,2]=a2[:,1];dataApo[:,3] = b2[:,1];\
dataApo[:,4]=a3[:,1];dataApo[:,5] = b3[:,1];\
dataApo[:,6]=a4[:,1];dataApo[:,7] = b4[:,1]

RMSFaveApo=np.mean(dataApo,axis=1)
RMSFstdApo=np.std(dataApo,axis=1)

myHoloA1="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_1/CA_proA_rmsf.txt"
myHoloB1="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_1/CA_proB_rmsf.txt"
d1=np.loadtxt(myHoloA1, usecols=(1,2),skiprows=2)
e1=np.loadtxt(myHoloB1, usecols=(1,2),skiprows=2)

myHoloA2="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_2/CA_proA_rmsf.txt"
myHoloB2="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_2/CA_proB_rmsf.txt"
d2=np.loadtxt(myHoloA2, usecols=(1,2),skiprows=2)
e2=np.loadtxt(myHoloB2, usecols=(1,2),skiprows=2)

myHoloA3="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_3/CA_proA_rmsf.txt"
myHoloB3="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_3/CA_proB_rmsf.txt"
d3=np.loadtxt(myHoloA3, usecols=(1,2),skiprows=2)
e3=np.loadtxt(myHoloB3, usecols=(1,2),skiprows=2)

myHoloA4="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_4/CA_proA_rmsf.txt"
myHoloB4="/u1/cesc235/analysis/tleap/full-holo/full-traj-141215/WT_holo_2LP3_4/CA_proB_rmsf.txt"
d4=np.loadtxt(myHoloA4, usecols=(1,2),skiprows=2)
e4=np.loadtxt(myHoloB4, usecols=(1,2),skiprows=2)

dataHolo = np.zeros([np.shape(d1)[0],8])
dataHolo[:,0]=d1[:,1];dataHolo[:,1] = e1[:,1];\
dataHolo[:,2]=d2[:,1];dataHolo[:,3] = e2[:,1];\
dataHolo[:,4]=d3[:,1];dataHolo[:,5] = e3[:,1];\
dataHolo[:,6]=d4[:,1];dataHolo[:,7] = e4[:,1]

RMSFaveHolo=np.mean(dataHolo,axis=1)
RMSFstdHolo=np.std(dataHolo,axis=1)

mySingleA1="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_1/CA_proA_rmsf.txt"
mySingleB1="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_1/CA_proB_rmsf.txt"
f1=np.loadtxt(mySingleA1, usecols=(1,2),skiprows=2)
g1=np.loadtxt(mySingleB1, usecols=(1,2),skiprows=2)

mySingleA2="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_2/CA_proA_rmsf.txt"
mySingleB2="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_2/CA_proB_rmsf.txt"
f2=np.loadtxt(mySingleA2, usecols=(1,2),skiprows=2)
g2=np.loadtxt(mySingleB2, usecols=(1,2),skiprows=2)

mySingleA3="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_3/CA_proA_rmsf.txt"
mySingleB3="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_3/CA_proB_rmsf.txt"
f3=np.loadtxt(mySingleA3, usecols=(1,2),skiprows=2)
g3=np.loadtxt(mySingleB3, usecols=(1,2),skiprows=2)

mySingleA4="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_4/CA_proA_rmsf.txt"
mySingleB4="/u1/cesc235/analysis/tleap/full-single/full-traj-141215/WT_holo_Cterm_4/CA_proB_rmsf.txt"
f4=np.loadtxt(mySingleA4, usecols=(1,2),skiprows=2)
g4=np.loadtxt(mySingleB4, usecols=(1,2),skiprows=2)

dataSingle = np.zeros([np.shape(f3)[0],8])
dataSingle[:,0]=f1[:,1];dataSingle[:,1] = g1[:,1];\
dataSingle[:,2]=f2[:,1];dataSingle[:,3] = g2[:,1];\
dataSingle[:,4]=f3[:,1];dataSingle[:,5] = g3[:,1];\
dataSingle[:,6]=f4[:,1];dataSingle[:,7] = g4[:,1]

RMSFaveSingle=np.mean(dataSingle,axis=1)
RMSFstdSingle=np.std(dataSingle,axis=1)

print RMSFaveApo

##plt.plot(a1[:,0],RMSFave,'k',linewidth=3.0)
plt.errorbar(x=a1[:,0],y=RMSFaveApo,yerr=RMSFstdApo,color='b',label='Average Apo')
plt.errorbar(x=d1[:,0],y=RMSFaveHolo,yerr=RMSFstdHolo,color='r',label='Average Holo')
plt.errorbar(x=f1[:,0],y=RMSFaveSingle,yerr=RMSFstdSingle,color='g',label='Average Half-Sat.')
plt.xticks(np.arange(0, 100+1, 10))
plt.xlabel('Number of Residues', weight="bold" ,fontsize=16)
plt.ylabel('Average backbone RMSF \n for a single chain \n of S100A1 ($\AA$)', weight="bold",fontsize=16)
#plt.ylabel('Average backbone RMSF for a single chain of S100A1')
plt.legend(loc='upper left')
#plt.ylim([0,4])
##plt.show()
plt.tight_layout()
#plt.gcf().savefig("/net/share/cesc235/pkh-lab-papers/141006-S100A1/figs/aveRMSF-tleap_corr.png")
# Out:
# [ 2.72589475  1.64251587  1.35995488  1.0782795   1.06209087  1.002438
#   0.819785    0.73637375  0.74524525  0.71329038  0.62671362  0.63525387
#   0.71490338  0.68586013  0.616328    0.71599675  0.8144515   0.740009
#   0.7539765   1.437833    2.04515212  2.2664635   2.01890512  1.61275562
#   1.264845    0.94855675  0.783044    0.70754162  0.727205    0.68815575
#   0.80778412  0.71395962  0.61414288  0.74002025  0.82627475  0.77179962
#   0.86067462  1.05022737  1.08486512  0.9730575   0.95658862  1.04743213
#   1.13701775  1.01289838  1.06394425  1.21597425  1.24070975  1.290409
#   1.77439275  1.80267525  2.05314562  2.18294363  2.15227088  1.86655538
#   1.74569237  1.79661938  1.55092975  1.35029362  1.50514925  1.46880637
#   1.11561375  1.44651938  1.651827    1.44861012  1.29801388  1.3510535
#   1.08005938  0.85073162  0.751599    0.83595925  0.6921635   0.83782713
#   0.86095975  0.68378688  0.67223213  0.79853087  0.79408638  0.74913412
# ...

# %% [markdown]
# ## Figure S2

# %%
####Tleap MMPBSA Results
##Averages are computed in a workbook: /home/AD/cesc235/Documents/mmpbsa_averages.ods

font = {'weight' : 'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

holo_pEF_ave=-168.0016425
holo_cEF_ave=-577.1113075
single_cEF_ave=-583.9547825

holo_pEF_std=12.9651889408
holo_cEF_std=25.2901928656
single_cEF_std=21.2779571245

names=['Apo pEF','Half-Sat. pEF','Holo pEF','Apo cEF','Half-Sat. cEF','Holo cEF']

stds=np.array([0, 0,  holo_pEF_std, 0, single_cEF_std, holo_cEF_std])

mean=np.array([0, 0, holo_pEF_ave, 0, single_cEF_ave, holo_cEF_ave])

N = 2.

ind = np.arange(N)  # the x locations for the groups
width = 0.15  
width = 0.3

class empty:pass
apo=empty()
apo.names = names[::3]
apo.stds = stds[::3]
apo.mean = mean[::3]
print apo.mean

single = empty()
single.names = names[1::3]
single.stds = stds[1::3]
single.mean = mean[1::3]
print single.mean

holo = empty()
holo.names = names[2::3]
holo.stds = stds[2::3]
holo.mean = mean[2::3]
print holo.mean

#fig, ax = plt.subplots(dpi=300,figsize=(15,6))
fig, ax = plt.subplots(dpi=600)
rects1 = ax.bar(ind, apo.mean, width, color='b',yerr=apo.stds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects2 = ax.bar(ind+width, single.mean, width, color='g',yerr=single.stds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
rects3 = ax.bar(ind+2*width, holo.mean, width, color='r',yerr=holo.stds,error_kw=dict(elinewidth=2,capsize=3,markeredgewidth=2,ecolor='black'))
plt.plot((0.95, 0.95), (0, -620), 'k--')
         
ax.set_ylabel(' MM Electrostatic Energy \n (kcal/mol)',fontsize=20,weight="bold")
#ax.set_title('S100A1 Average Electrostatic Score of Ca2+-binding EF hands in the Holo States')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('pEF hand', 'cEF hand'), weight="bold" ,fontsize=20)
ax.legend( (rects2[0],rects3[0]), ('Half-sat.','Holo'), loc=(0), fontsize=14) 
#ax.legend( (rects1[0]), ('Chain A','Chain B'), loc=(2)) 
ax.set_ylim([-620,0])
ax.set_xlim([0,2])
plt.tight_layout()
#plt.gcf().savefig("/home/AD/cesc235/ipython/Eelec/tleap-mmpbsa.png")
# Out:
# [ 0.  0.]
# [   0.        -583.9547825]
# [-168.0016425 -577.1113075]
