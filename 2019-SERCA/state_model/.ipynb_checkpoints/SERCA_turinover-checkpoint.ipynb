# %%
# Function for integreating ODE and displaying results
# %matplotlib inline
import scipy.integrate
from scipy.integrate import odeint
import matplotlib
import matplotlib.pylab as plt
matplotlib.rcParams['figure.figsize'] = (3,2)
matplotlib.rcParams['savefig.dpi'] = 300
import numpy as np

# %%
def f(y,t,a):
  return np.dot(a,y)
#    return [a[0,0]*y[0] + a[0,1]*y[1],\
#            a[1,0]*y[0] + a[1,1]*y[1]]


t  = scipy.linspace(0.,10.,100)

# %%
# Initial conc. 
y0 = [2,3]

# Jacobian

kf3=0.8
kb3=0.2
kf1=1.9
kb1=0.2
kf2=0.9
kb2=0.8
kf4=1.6
kb4=0.9

K1=kf1/kb1
K3=kf3/kb3

af1=kf4*K3/(1+K3)
ab1=kb4/(1+K1)
af2=kf2*K1/(1+K1)
ab2=kb2/(1+K3)

J1 = np.array([
  [-(kf3+kb2),kb3,0,kf2],
  [kf3,-(kb3+kf4),kb4,0],
  [0,kf4,-(kb4+kf1),kb1],
  [kb2,0,kf1,-(kf2+kb1)]
 ]) 

J2 = np.array([
  [-(af1+ab2),ab1+af2],
  [af1+ab2,-(ab1+af2)],
 ]) 


y1 = 1
y2 = 0
y3 = 0
y4 = 0

ly1=1
ly2=0

ys = np.array([y1,y2,y3,y4],dtype=np.float)
daSum = np.sum(ys)
y = scipy.integrate.odeint(f,ys,t,args=(J1,))

lys = np.array([ly1,ly2],dtype=np.float)
ldaSum = np.sum(lys)
lumy = scipy.integrate.odeint(f,lys,t,args=(J2,))



#print y[:,1]
#print y[:,0]
#print y[:,0]+y[:,1]-lumy[:,0]
#print y[:,2]+y[:,3]-lumy[:,1]
#print lumy[:,0]
matplotlib.rcParams['figsize'] = (6,4)
matplotlib.rcParams['savefig.dpi'] = 300
plt.plot(t,y[:,0],"r.",label="y$_1$")
plt.plot(t,y[:,1],"r-.",label="y$_2$")
plt.plot(t,y[:,2],"b.",label="y$_3$")
plt.plot(t,y[:,3],"b-.",label="y$_4$")
plt.plot(t,lumy[:,0],"r-",label="E$_1$")
plt.plot(t,lumy[:,1],"b-",label="E$_2$")
plt.ylabel("$[y_i]$")
plt.xlabel("t")
plt.legend(loc=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in __setitem__(self, key, val)
#     815             try:
# --> 816                 cval = self.validate[key](val)
#     817             except ValueError as ve:
#
# KeyError: 'figsize'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-9cea207556d3> in <module>()
#      57 #print y[:,2]+y[:,3]-lumy[:,1]
#      58 #print lumy[:,0]
# ---> 59 matplotlib.rcParams['figsize'] = (6,4)
#      60 matplotlib.rcParams['savefig.dpi'] = 300
#      61 plt.plot(t,y[:,0],"r.",label="y$_1$")
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in __setitem__(self, key, val)
#     821             raise KeyError(
# ...

# %%
# two state model ( only Ca2+ ) turn over rate 
# in Tran's paper, for two-state model, the expression of turin over is:
#  V= (af1*af2-ab1*ab2)/(ab1+ab2+af1+af2)

# experimental data from Cantilina's paper (figure 3A, nomalized to ensure maxmium is 5/S-1)
c0=[7.76046e-08,9.94839e-08,1.92927e-07,2.97960e-07,4.79622e-07,7.72041e-07,9.30121e-07,1.88000e-06,4.67372e-06,9.64428e-06]
r0=[0.272727,0.285714,0.636364,0.870130,2.10390,2.74026,4,4.72727,4.84416,4.94805]
                   
def cRate(Ca,kf5,kb5,kf6,kb6):
    Kd=0.00224 # dissociation constance of Calcium in the SR side, taken from Tran's paper
    #Kdk=0.0253
    MgATP=0.0003
    Pi=0.000001
    #Ca=0.000005
    MgADP=0.000001

    Cai=0.000001
    kf1=100000000.0
    kb1=400.0
    kf2=30.0
    kb2=40.0
    kf3=400000000.0
    kb3=16.0
    kf4=20000000.0
    kb4=40.0
   
    
    K1=kf1/kb1
    K3=kf3/kb3
    K2=kf2/kb2
    #K3=kf3/kb3
    K4=kf4/kb4
     
    af1=kf5*K1*K2*K3*K4*Ca*Ca*MgATP/(1+K1*Ca+K1*K2*Ca+K1*K2*K3*Ca*Ca+K1*K2*K3*K4*Ca*Ca*MgATP)
    ab1=kb5*MgADP/(1+Kd/Cai+Kd*Kd/(Cai*Cai))
    af2=(kf6*Kd*Kd/(Cai*Cai))/(1+(Kd/Cai)+Kd*Kd/(Cai*Cai))
    ab2=kb6*Pi/(1+K1*Ca+K1*K2*Ca+K1*K2*K3*Ca*Ca+K1*K2*K3*K4*Ca*Ca*MgATP)
    
    return (af1*af2-ab1*ab2)/(ab1+ab2+af1+af2)
    
vcRate = np.vectorize(cRate)
# Both Mg and K are inhibtors of SERCA
def MgKin_Rate(Ca,Mg,Kdmg,K,Kdk):

    Kd=0.00224
    #Kdk=1.2
    #Kdmg=0.1
    MgATP=0.0003
    Pi=0.000001
    #Ca=0.000005
    MgADP=0.000001

    Cai=0.000001
    kf1=100000000.0
    kb1=400.0
    kf2=30.0
    kb2=40.0
    kf3=400000000.0
    kb3=16.0
    kf4=20000000.0
    kb4=40.0
    kf5=15
    kb5=75000
    kf6=7.5
    kb6=5000000000
    K1=kf1/kb1
    K3=kf3/kb3
    K2=kf2/kb2
    K4=kf4/kb4
    
    ad1=Kdmg/Mg
    ad2=Kdk/K
    
    af1=kf5*ad1*ad2*K1*K2*K3*K4*Ca*Ca*MgATP/(1+ad1+ad1*ad2+ad1*ad2*K1*Ca+ad1*ad2*K1*K2*Ca+ad1*ad2*K1*K2*K3*Ca*Ca+ad1*ad2*K1*K2*K3*K4*Ca*Ca*MgATP)
    ab1=kb5*MgADP/(1+Kd/Cai+Kd*Kd/(Cai*Cai))
    af2=(kf6*Kd*Kd/(Cai*Cai))/(1+(Kd/Cai)+Kd*Kd/(Cai*Cai))
    ab2=kb6*Pi/(1+ad1+ad1*ad2+ad1*ad2*K1*Ca+ad1*ad2*K1*K2*Ca+ad1*ad2*K1*K2*K3*Ca*Ca+ad1*ad2*K1*K2*K3*K4*Ca*Ca*MgATP)
    
    return (af1*af2-ab1*ab2)/(ab1+ab2+af1+af2)
    
vMgKin_Rate = np.vectorize(MgKin_Rate)

def MgIKT_Rate(Ca,Mg,Kdmg,K,Kdk):
    Kd=0.00224
   
    #Kdk=0.1
    #Kdmg=0.003
    
    MgATP=0.0003
    Pi=0.000001
    #Ca=0.000005
    MgADP=0.000001

    Cai=0.000001
    
    
    Cai=0.000001
    kf1=100000000.0
    kb1=400.0
    kf2=30.0
    kb2=40.0
    kf3=400000000.0
    kb3=16.0
    kf4=20000000.0
    kb4=40.0
    kf5=15
    kb5=7.5
    kf6=7.5
    kb6=7000000000
    K1=kf1/kb1
    K3=kf3/kb3
    K2=kf2/kb2
    K4=kf4/kb4
    ad1=Kdmg/Mg
    ad2=Kdk/K
    
    af1=kf5*ad1*ad2*K1*K2*K3*K4*Ca*Ca*MgATP/(1+ad2+ad1*ad2+ad1*ad2*K1*Ca+ad1*ad2*K1*K2*Ca+ad1*ad2*K1*K2*K3*Ca*Ca+ad1*ad2*K1*K2*K3*K4*Ca*Ca*MgATP)
    ab1=kb5*MgADP/(1+Kd/Cai+Kd*Kd/(Cai*Cai))
    af2=(kf6*Kd*Kd/(Cai*Cai))/(1+(Kd/Cai)+Kd*Kd/(Cai*Cai))
    ab2=kb6*Pi/(1+ad2+ad1*ad2+ad1*ad2*K1*Ca+ad1*ad2*K1*K2*Ca+ad1*ad2*K1*K2*K3*Ca*Ca+ad1*ad2*K1*K2*K3*K4*Ca*Ca*MgATP)
    
    return (af1*af2-ab1*ab2)/(ab1+ab2+af1+af2)
    
vMgIKT_Rate = np.vectorize(MgIKT_Rate)

cs = 10**np.linspace(-8,-4,100)
#print vcRate(cs,0.0000002)
#plt.plot(cs,vcRate(cs,15,75000,250,270000),"k-",label="Only Ca2+")
plt.plot(cs,vcRate(cs,15,75000,7.5,5000000000),"b-",label="Only Ca2+") # Now we know the value of K5 and K6
plt.plot(c0,r0,"k.",label="Experimental data")
plt.plot(cs,vMgKin_Rate(cs,0.002,0.003,0.15,0.1),"m.",label="Only Ca2+")
#plt.plot(cs,vMgIKT_Rate(cs,0.002,0.15),"r.",label="Only Ca2+")

plt.xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("Pump Rate(1/S)")
# Out:
# Text(0,0.5,'Pump Rate(1/S)')

# %%
# Turn over rate for Mg and K both are inhibitors
# Mg and K are both intermediates
def MgKTT_Rate(Ca,Mg,Kdmg,K,Kdk):
    Kd=0.00224
   
    #Kdk=0.1
    #Kdmg=0.003
    
    MgATP=0.0003
    Pi=0.000001
    #Ca=0.000005
    MgADP=0.000001

  
    
    Cai=0.000001
    kf1=100000000.0
    kb1=400.0
    kf2=30.0
    kb2=40.0
    kf3=400000000.0
    kb3=16.0
    kf4=20000000.0
    kb4=40.0
    kf5=15
    kb5=7.5
    kf6=7.5
    kb6=7000000000
    K1=kf1/kb1
    K3=kf3/kb3
    K2=kf2/kb2
    K4=kf4/kb4
  
   
    kf0=1/(1/Kdmg+1/Mg+K/(Mg*Kdk))
    
    
    ad1=kf0/Mg
    
    
    af1=kf5*ad1*K1*K2*K3*K4*Ca*Ca*MgATP/(1+ad1+ad1*K1*Ca+ad1*K1*K2*Ca+ad1*K1*K2*K3*Ca*Ca+ad1*K1*K2*K3*K4*Ca*Ca*MgATP)
    ab1=kb5*MgADP/(1+Kd/Cai+Kd*Kd/(Cai*Cai))
    af2=(kf6*Kd*Kd/(Cai*Cai))/(1+(Kd/Cai)+Kd*Kd/(Cai*Cai))
    ab2=kb6*Pi/(1+ad1+ad1*K1*Ca+ad1*K1*K2*Ca+ad1*K1*K2*K3*Ca*Ca+ad1*K1*K2*K3*K4*Ca*Ca*MgATP)
    
    return (af1*af2-ab1*ab2)/(ab1+ab2+af1+af2)
    
vMgKTT_Rate = np.vectorize(MgKTT_Rate)

plt.plot(cs,vcRate(cs,15,7.5,7.5,7000000000),"c-",label="Only Ca2+") # Now we know the value of K5 and K6
plt.plot(c0,r0,"k.",label="Experimental data")
plt.plot(cs,vMgKin_Rate(cs,0.002,0.0015,0.15,0.3),"r-",label="MgIKI")
plt.plot(cs,vMgIKT_Rate(cs,0.002,0.0015,0.15,0.3),"b-",label="MgIKT")
#plt.plot(cs,vMgKTT_Rate(cs,0.002,0.005,0.15,0.2),"b-",label="MgTKT")
plt.plot(cs,vMgKTT_Rate(cs,0.002,0.0015,0.15,0.3),"g-",label="MgTKT")
plt.xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("Pump Rate(1/S)")
# Out:
# Text(0,0.5,'Pump Rate(1/S)')

# %%
plt.plot(cs,vcRate(cs,15,7.5,7.5,7000000000),"b-",label="Only Ca2+") # Now we know the value of K5 and K6
plt.plot(c0,r0,"k.",label="Experimental data")
plt.xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("Pump Rate(1/S)")
# Out:
# Text(0,0.5,'Pump Rate(1/S)')

# %%
# Vmax50 --- Half Saturation 
plt.plot(cs,vMgKin_Rate(cs,0.002,0.0015,0.15,0.3),"r-",label="MgIKI")
plt.plot(cs,vMgIKT_Rate(cs,0.2,0.0015,0.15,0.3),"b-",label="MgIKT")
#plt.plot(cs,vMgKTT_Rate(cs,0.002,0.005,0.15,0.2),"b-",label="MgTKT")
plt.plot(cs,vMgKTT_Rate(cs,0.002,0.0015,0.15,0.3),"g-",label="MgTKT")
plt.xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("Pump Rate(1/S)")
# Out:
# Text(0,0.5,'Pump Rate(1/S)')

# %%
mc = 10**np.linspace(-5,-1,20)
kc = 10**np.linspace(-2,2,20)
print (kc)
# Out:
# [1.00000000e-02 1.62377674e-02 2.63665090e-02 4.28133240e-02
#  6.95192796e-02 1.12883789e-01 1.83298071e-01 2.97635144e-01
#  4.83293024e-01 7.84759970e-01 1.27427499e+00 2.06913808e+00
#  3.35981829e+00 5.45559478e+00 8.85866790e+00 1.43844989e+01
#  2.33572147e+01 3.79269019e+01 6.15848211e+01 1.00000000e+02]

# %%
for i,conc in enumerate(kc):
    print (conc)
    plt.plot(cs,vMgKTT_Rate(cs,0.002,0.0015,0.15*conc,0.3),"g-")
    #plt.plot(cs,vMgKin_Rate(cs,2*conc,0.0015,0.15,0.3),"b-")
    plt.xscale('log')
    plt.legend(loc=0)
    plt.xlabel("[Ca]")
    plt.ylabel("Pump Rate(1/S)")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.01
# ...

# %%
# MgKin--- Vmax50 dependence of Mg and Ca

#print cs
#print vcRate(cs,15,7.5,7.5,7000000000)
# Mg dependence
org=[6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,
     6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7,6.648961E-7]

II_MgCa=[5.299778E-8,6.424372E-8,8.004844E-8,9.97413E-8,1.2599907E-7,1.5699634E-7,1.9832699E-7,2.5053316E-7,3.164882E-7,4.109595E-7
,5.336304E-7,6.8344406E-7,8.5156194E-7,1.1210575E-6,1.3968508E-6,1.7890088E-6,2.2291263E-6,2.8159632E-6,3.6564493E-6,4.6191362E-6]

II_KCa=[4.97339E-8,6.112423E-8,7.721414E-8,9.620776E-8,1.215378E-7,1.5353052E-7,1.9663335E-7,2.483988E-7,3.0529475E-7,4.018955E-7,5.007871E-7
,6.4135395E-7, 8.3278013E-7,1.0665784E-6,1.3473646E-6,1.7020701E-6,2.1207995E-6,2.7162018E-6,3.5269845E-6,4.5170727E-6]

TT_MgCa=[7.967926E-7,8.154926E-7,8.419021E-7,8.53573E-7,8.6540564E-7,8.6540564E-7,9.143996E-7,9.2707546E-7,9.399271E-7,1.0208657E-6,1.1555275E-6
,1.3631045E-6,1.6079703E-6,1.9497775E-6,2.3970172E-6,3.0291123E-6,3.775553E-6,4.705933E-6,6.02933E-6,7.7248915E-6]

TT_KCa=[9.795608E-7,9.855608E-7,9.995608E-7,1.0069074E-6,1.0350175E-6,1.0639124E-6,1.0786608E-6,1.1087741E-6,1.1397279E-6,1.171546E-6,
        1.2209463E-6,1.2550317E-6,1.3079524E-6,1.440275E-6,1.7464351E-6,2.0042098E-6,2.4980916E-6,3.0291123E-6,3.775553E-6,4.771169E-6]

plt.plot(2*mc,org,"k-",label="Only Ca")
plt.plot(2*mc,II_MgCa,"r-",label="MgIKI")
plt.plot(2*mc,TT_MgCa,"b-",label="MgTKT")
#plt.plot(kc,KCa,"k-")
plt.yscale('log')
plt.xscale('log')
plt.legend(loc=0)
plt.xlabel("p[Mg]")
plt.ylabel("p[Ca] for Vmax$_{50}$")
# Out:
# Text(0,0.5,'p[Ca] for Vmax$_{50}$')

# %%
# MgKin--- Vmax50 dependence of K and Ca
plt.plot(0.15*kc,org,"k-",label="Only Ca")
plt.plot(0.15*kc,II_KCa,"r-",label="MgIKI")
plt.plot(0.15*kc,TT_KCa,"b-",label="MgTKT")
#plt.plot(kc,KCa,"k-")
plt.yscale('log')
plt.xscale('log')
plt.legend(loc=0)
plt.xlabel("p[K]")
plt.ylabel("p[Ca] for Vmax$_{50}$")
# Out:
# Text(0,0.5,'p[Ca] for Vmax$_{50}$')
