# %%
from IPython.display import Image

# %%
Image(filename="SERCA_pump_cycle_Ca_only_linear.png")

# %% [markdown]
# $$\phi_f = \frac{1}{\frac{1}{CaK_{12}K_{23}CaK_{34}}+\frac{1}{K_{23}CaK_{34}}+\frac{1}{CaK_{34}}+1}$$

# %%
def cycleCa(Ca,K12,K23,K34):
    denom = ((1/(Ca*K12*K23*Ca*K34))+(1/(K23*Ca*K34))+(1/(Ca*K34))+1)
    return  1/denom 

vCycleCa = np.vectorize(cycleCa)
cs = 10**np.linspace(-9,-1,100)

# %%
sk1 = 100000000.0/216000.  # Af: Cantilina/Trieber
sk3 = 400000000.0/2567000. #Cf: Cantilina/Trieber

K12 = (216000.0/400.0)# * sk1          # Trieber
K23 = (30.0/40.0)
K34 = (2567000.0/16.0)# * sk3

CK12 = (1.0e8/400.0)                   # Cantilina
CK23 = (30.0/40.0)
CK34 = (4.0e8/16.0)

#K12 = (400.0/216000.0)
#K23 = (40.0/30.0)
#K34 = (16.0/2567000.0)

linear_case = vCycleCa(cs,CK12,CK23,CK34)

print K12,K23,K34
# Out:
# 540.0 0.75 160437.5

# %%
print vCycleCa(cs,K12,K23,K34)
print vCycleCa(cs,CK12,CK23,CK34)
# Out:
# [  6.49771261e-11   9.42706663e-11   1.36770564e-10   1.98430614e-10
#    2.87888748e-10   4.17677111e-10   6.05977676e-10   8.79169333e-10
#    1.27552326e-09   1.85056427e-09   2.68484913e-09   3.89525154e-09
#    5.65133456e-09   8.19910402e-09   1.18954702e-08   1.72582453e-08
#    2.50386799e-08   3.63266991e-08   5.27035788e-08   7.64634463e-08
#    1.10934629e-07   1.60945859e-07   2.33502622e-07   3.38768363e-07
#    4.91487957e-07   7.13052730e-07   1.03449615e-06   1.50083949e-06
#    2.17739570e-06   3.15891350e-06   4.58284082e-06   6.64856243e-06
#    9.64530064e-06   1.39925772e-05   2.02988857e-05   2.94467582e-05
#    4.27160817e-05   6.19628222e-05   8.98779815e-05   1.30362668e-04
#    1.89071081e-04   2.74196083e-04   3.97604747e-04   5.76477863e-04
#    8.35673265e-04   1.21112493e-03   1.75471663e-03   2.54123945e-03
#    3.67826258e-03   5.32001343e-03   7.68664454e-03   1.10904704e-02
#    1.59706714e-02   2.29371365e-02   3.28217111e-02   4.67297590e-02
# ...

# %%
#K34=1e9;
plt.plot(cs,vCycleCa(cs,K12,K23,K34),label = "Trieber")
#K34=1e8;
plt.plot(cs,vCycleCa(cs,CK12,CK23,CK34),label = "Cantilina")
#K34=1e7;
#plt.plot(cs,vCycleCa(cs,K12,K23,K34),label="K$_{34}$ = %3.1e[1/M]"%(K34))
ylim([0,1])
xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("[CaCaM]")
#plt.title("Ca-bound CaM probability wrt\n CaM target peptide concentration and peptide affinity")
#plt.gcf().savefig("/home/AD/pmke226/grants/151101_EF_NSF/figs/cambind.png")

# %%
Image(filename="SERCA_pump_cycle_Mg_inhibited_linear.png")

# %% [markdown]
# $$\phi_f = \frac{1}{\frac{MgKMg}{CaK_{12}K_{23}CaK_{34}}+\frac{1}{CaK_{12}K_{23}CaK_{34}}+\frac{1}{K_{23}CaK_{34}}+\frac{1}{CaK_{34}}+1}$$

# %%
def cycleCa(Ca,Mg,K12,K23,K34,KMg):
    denom = ((Mg*KMg/(Ca*K12*K23*Ca*K34))+(1/(Ca*K12*K23*Ca*K34))+(1/(K23*Ca*K34))+(1/(Ca*K34))+1)
    return  1/denom 

vCycleCa = np.vectorize(cycleCa)
cs = 10**np.linspace(-9,-1,100)

# %%
sk1 = 100000000.0/216000.  # Af: Cantilina/Trieber
sk3 = 400000000.0/2567000. #Cf: Cantilina/Trieber

K12 = (216000.0/400.0)# * sk1         # Trieber
K23 = (30.0/40.0)
K34 = (2567000.0/16.0)# * sk3

CK12 = (1.0e8/400.0)                  # Cantilina
CK23 = (30.0/40.0)
CK34 = (4.0e8/16.0)

KMg = 49304.0

#K12 = (400.0/216000.0)
#K23 = (40.0/30.0)
#K34 = (16.0/2567000.0)

print K12,K23,K34
Mg_con = 4.0e-3

Mg_inhib = vCycleCa(cs,Mg_con,CK12,CK23,CK34,KMg)
# Out:
# 540.0 0.75 160437.5

# %%
#K34=1e9;
plt.plot(cs,vCycleCa(cs,Mg_con,K12,K23,K34,KMg),label = "Trieber")
#K34=1e8;
plt.plot(cs,vCycleCa(cs,Mg_con,CK12,CK23,CK34,KMg),label = "Cantilina")
#K34=1e7;
#plt.plot(cs,vCycleCa(cs,Mg_con,K12,K23,K34,KMg),label="K$_{34}$ = %3.1e[1/M]"%(K34))
ylim([0,1])
xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("[CaCaM]")
#plt.title("Ca-bound CaM probability wrt\n CaM target peptide concentration and peptide affinity")
#plt.gcf().savefig("/home/AD/pmke226/grants/151101_EF_NSF/figs/cambind.png")

# %%
Image(filename="SERCA_pump_cycle_Mg_intermediate_linear.png")

# %% [markdown]
# $$\phi_f = \frac{1}{\frac{1}{MgKMg_{1}CaKMg_{2}K_{23}CaK_{34}}+\frac{1}{CaKMg_{2}K_{23}CaK_{34}}+\frac{1}{K_{23}CaK_{34}}+\frac{1}{CaK_{34}}+1}$$

# %%
def cycleCa(Ca,Mg,K12,K23,K34,KMg1,KMg2):
    denom = ((1/(Mg*KMg1*Ca*KMg2*K23*Ca*K34))+(1/(Ca*KMg2*K23*Ca*K34))+(1/(K23*Ca*K34))+(1/(Ca*K34))+1)
    return 1/denom 

vCycleCa = np.vectorize(cycleCa)
cs = 10**np.linspace(-9,-1,100)

# %%
sk1 = 100000000.0/216000.  # Af: Cantilina/Trieber
sk3 = 400000000.0/2567000. #Cf: Cantilina/Trieber

K12 = (216000.0/400.0)# * sk1        # Trieber
K23 = (30.0/40.0)
K34 = (2567000.0/16.0)# * sk3

CK12 = (1.0e8/400.0)                 # Cantilina
CK23 = (30.0/40.0)
CK34 = (4.0e8/16.0)

KMg1 = 49304.0
#KMg2 = 49304.0

#K12 = (400.0/216000.0)
#K23 = (40.0/30.0)
#K34 = (16.0/2567000.0)

print K12,K23,K34

Mg_con = 4.0e-3
K_con = 150.0e-3

#Mg_inter = vCycleCa(cs,Mg_con,CK12,CK23,CK34,KMg1,KMg2)
# Out:
# 540.0 0.75 160437.5

# %%
KMg2=49304.0;
plt.plot(cs,vCycleCa(cs,Mg_con,CK12,CK23,CK34,KMg1,KMg2),label = "49304.0")
KMg2=493040.0;
plt.plot(cs,vCycleCa(cs,Mg_con,CK12,CK23,CK34,KMg1,KMg2),label = "493040.0")
KMg2=4930400.0;
plt.plot(cs,vCycleCa(cs,Mg_con,CK12,CK23,CK34,KMg1,KMg2),label="4930400.0")
ylim([0,1])
xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("[theta]")
#plt.title("Ca-bound CaM probability wrt\n CaM target peptide concentration and peptide affinity")
#plt.gcf().savefig("/home/AD/pmke226/grants/151101_EF_NSF/figs/cambind.png")

# %%
Image(filename="SERCA_pump_cycle_Mg_inhibited_K_inhibited_linear.png")

# %% [markdown]
# $$\phi_f = \frac{1}{\frac{MgKMg}{CaK_{12}K_{23}CaK_{34}}+\frac{KKK}{CaK_{12}K_{23}CaK_{34}}+\frac{1}{CaK_{12}K_{23}CaK_{34}}+\frac{1}{K_{23}CaK_{34}}+\frac{1}{CaK_{34}}+1}$$

# %%
def cycleCa(Ca,Mg,K,K12,K23,K34,KMg,KK):
    denom = ((Mg*KMg/(Ca*K12*K23*Ca*K34))+(K*KK/(Ca*K12*K23*Ca*K34))+(1/(Ca*K12*K23*Ca*K34))+(1/(K23*Ca*K34))+(1/(Ca*K34))+1)
    return 1/denom 

vCycleCa = np.vectorize(cycleCa)
cs = 10**np.linspace(-9,-1,100)

# %%
sk1 = 100000000.0/216000.  # Af: Cantilina/Trieber
sk3 = 400000000.0/2567000. #Cf: Cantilina/Trieber

K12 = (216000.0/400.0)# * sk1        # Trieber
K23 = (30.0/40.0)
K34 = (2567000.0/16.0)# * sk3

CK12 = (1.0e8/400.0)                 # Cantilina
CK23 = (30.0/40.0)
CK34 = (4.0e8/16.0)

KMg = 49304.0
KK  = 378.186

#K12 = (400.0/216000.0)
#K23 = (40.0/30.0)
#K34 = (16.0/2567000.0)

print K12,K23,K34

Mg_con = 4.0e-3
K_con = 150.0e-3

Mg_K_inhib = vCycleCa(cs,Mg_con,K_con,CK12,CK23,CK34,KMg,KK)
# Out:
# 540.0 0.75 160437.5

# %%
#K34=1e9;
plt.plot(cs,vCycleCa(cs,Mg_con,K_con,K12,K23,K34,KMg,KK),label = "Trieber")
#K34=1e8;
plt.plot(cs,vCycleCa(cs,Mg_con,K_con,CK12,CK23,CK34,KMg,KK),label = "Cantilina")
#K34=1e7;
#plt.plot(cs,vCycleCa(cs,Mg_con,K_con,K12,K23,K34,KMg,KK),label="K$_{34}$ = %3.1e[1/M]"%(K34))
ylim([0,1])
xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("[CaCaM]")
#plt.title("Ca-bound CaM probability wrt\n CaM target peptide concentration and peptide affinity")
#plt.gcf().savefig("/home/AD/pmke226/grants/151101_EF_NSF/figs/cambind.png")

# %%
Image(filename="SERCA_pump_cycle_Mg_inhibited_K_intermediate_linear.png")

# %% [markdown]
# $$\phi_f = \frac{1}{\frac{MgKMg}{KKk_{1}Kk_{2}CaK_{23}CaK_{34}}+\frac{1}{KKk_{1}Kk_{2}K_{23}CaK_{34}}+\frac{1}{Kk_{2}K_{23}CaK_{34}}+\frac{1}{K_{23}CaK_{34}}+\frac{1}{CaK_{34}}+1}$$

# %%
def cycleCa(Ca,Mg,K,K23,K34,KMg,Kk1,Kk2):
    denom = ((Mg*KMg/(K*Kk1*Kk2*Ca*K23*Ca*K34))+(1/(K*Kk1*Kk2*K23*Ca*K34))+(1/(Kk2*K23*Ca*K34))+(1/(K23*Ca*K34))+(1/(Ca*K34))+1)
    return 1/denom 

vCycleCa = np.vectorize(cycleCa)
cs = 10**np.linspace(-9,-1,100)

# %%
sk3 = 400000000.0/2567000. #Cf: Cantilina/Trieber

KMg = 49304.0
Kk1 = 378.186
Kk2 = 378.186

K23 = (30.0/40.0)              # Trieber
K34 = (2567000.0/16.0)# * sk3

CK23 = (30.0/40.0)             # Cantilina
CK34 = (4.0e8/16.0)

#K12 = (400.0/216000.0)
#K23 = (40.0/30.0)
#K34 = (16.0/2567000.0)

print K12,K23,K34

Mg_con = 4.0e-3
K_con = 150.0e-3

Mg_inhib_K_inter = vCycleCa(cs,Mg_con,K_con,CK23,CK34,KMg,Kk1,Kk2)
# Out:
# 540.0 0.75 160437.5

# %%
#K34=1e9;
plt.plot(cs,vCycleCa(cs,Mg_con,K_con,K23,K34,KMg,Kk1,Kk2),label = "Trieber")
#K34=1e8;
plt.plot(cs,vCycleCa(cs,Mg_con,K_con,CK23,CK34,KMg,Kk1,Kk2),label = "Cantilina")
#K34=1e7;
#plt.plot(cs,vCycleCa(cs,Mg_con,K_con,K23,K34,KMg,Kk1,Kk2),label="K$_{34}$ = %3.1e[1/M]"%(K34))
ylim([0,1])
xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("[CaCaM]")
#plt.title("Ca-bound CaM probability wrt\n CaM target peptide concentration and peptide affinity")
#plt.gcf().savefig("/home/AD/pmke226/grants/151101_EF_NSF/figs/cambind.png")

# %%
cs = 10**np.linspace(-9,-1,100)

plt.plot(cs,linear_case,label = "No inhib")
plt.plot(cs,Mg_inhib,label = "Mg inhib")
plt.plot(cs,Mg_inter,label = "Mg inter")
plt.plot(cs,Mg_K_inhib,label = "Mg and K inhib")
plt.plot(cs,Mg_inhib_K_inter,label = "Mg inhib K inter")

ylim([0,1])
xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("[theta]")

# %%
Image(filename="SERCA_pump_cycle_Ca_only.png")

# %% [markdown]
# $$\phi_f = \frac{1}{\frac{1}{CaK_{34}K_{45}K_{56}K_{61}}+\frac{1}{K_{45}K_{56}K_{61}}+\frac{1}{K_{56}K_{61}}+\frac{1}{K_{61}}+CaK_{12}+1}$$

# %%
def cycleCa(Ca,K12,K23,K34,K45,K56,K61):
    denom = ((1/(Ca*K34*K45*K56*K61))+(1/(K45*K56*K61))+(1/(K56*K61))+(1/(K61))+Ca*K12+1)
    return  1/denom 

vCycleCa = np.vectorize(cycleCa)
cs = 10**np.linspace(-9,-5,100)

# %%
CK12 = (1.0e8/400.0)                 # Cantilina
CK23 = (30.0/40.0)
CK34 = (4.0e8/16.0)

Mg_con = 4.0e-3
K_con = 150.0e-3

# %%
K45=1e1;
plt.plot(cs,vCycleCa(cs,K12,K23,K34,K45,K56,K61),label="K$_{45}$ = %3.1f[1/M]"%(K45))
K45=1e1;
plt.plot(cs,vCycleCa(cs,K12,K23,K34,K45,K56,K61),label="K$_{45}$ = %3.1f[1/M]"%(K45))
K45=2e1;
plt.plot(cs,vCycleCa(cs,K12,K23,K34,K45,K56,K61),label="K$_{45}$ = %3.1f[1/M]"%(K45))
ylim([0,1])
xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("[CaCaM]")
#plt.title("Ca-bound CaM probability wrt\n CaM target peptide concentration and peptide affinity")
#plt.gcf().savefig("/home/AD/pmke226/grants/151101_EF_NSF/figs/cambind.png")

# %%
Image(filename="SERCA_pump_cycle_Mg_inhibited.png")

# %% [markdown]
# $$\phi_f = \frac{1}{\frac{1}{CaK_{34}K_{45}K_{56}K_{61}}+\frac{1}{K_{45}K_{56}K_{61}}+\frac{1}{K_{56}K_{61}}+\frac{1}{K_{61}}+CaK_{12}+K_{Mg}+1}$$

# %%
def cycleCa_MgI(Ca,K12,K23,K34,K45,K56,K61,KMg):
    denom = ((1/(Ca*K34*K45*K56*K61))+(1/(K45*K56*K61))+(1/(K56*K61))+(1/(K61))+Ca*K12+KMg+1)
    return 1 - 1/denom 

vCycleCa_MgI = np.vectorize(cycleCa_MgI)
cs = 10**np.linspace(-9,-5,100)

# %%
K12 = 1e1
K23 = 1e1
K34 = 1e3
K45 = 1e1
K56 = 1e2
K61 = 1e1
KMg = 1e1

# %%
K45=1e1;
plt.plot(cs,vCycleCa_MgI(cs,K12,K23,K34,K45,K56,K61,KMg),label="K$_{45}$ = %3.1f[1/M]"%(K45))
K45=1e1;
plt.plot(cs,vCycleCa_MgI(cs,K12,K23,K34,K45,K56,K61,KMg),label="K$_{45}$ = %3.1f[1/M]"%(K45))
K45=2e1;
plt.plot(cs,vCycleCa_MgI(cs,K12,K23,K34,K45,K56,K61,KMg),label="K$_{45}$ = %3.1f[1/M]"%(K45))
ylim([0,1])
xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("[CaCaM]")
#plt.title("Ca-bound CaM probability wrt\n CaM target peptide concentration and peptide affinity")
#plt.gcf().savefig("/home/AD/pmke226/grants/151101_EF_NSF/figs/cambind.png")

# %%
Image(filename="SERCA_pump_cycle_Mg_inhibited_K_inhibited.png")

# %% [markdown]
# $$\phi_f = \frac{1}{\frac{1}{CaK_{34}K_{45}K_{56}K_{61}}+\frac{1}{K_{45}K_{56}K_{61}}+\frac{1}{K_{56}K_{61}}+\frac{1}{K_{61}}+CaK_{12}+K_{Mg}+K_{K}+1}$$

# %%
def cycleCa_MgI_KI(Ca,K12,K23,K34,K45,K56,K61,KMg,KK):
    denom = ((1/(Ca*K34*K45*K56*K61))+(1/(K45*K56*K61))+(1/(K56*K61))+(1/(K61))+Ca*K12+KMg+KK+1)
    return 1 - 1/denom 

vCycleCa_MgI_KI = np.vectorize(cycleCa_MgI_KI)
cs = 10**np.linspace(-9,-5,100)

# %%
K12 = 1e1
K23 = 1e1
K34 = 1e3
K45 = 1e1
K56 = 1e2
K61 = 1e1
KMg = 1e1
KK  = 1e1

# %%
K45=1e1;
plt.plot(cs,vCycleCa_MgI_KI(cs,K12,K23,K34,K45,K56,K61,KMg,KK),label="K$_{45}$ = %3.1f[1/M]"%(K45))
K45=1e1;
plt.plot(cs,vCycleCa_MgI_KI(cs,K12,K23,K34,K45,K56,K61,KMg,KK),label="K$_{45}$ = %3.1f[1/M]"%(K45))
K45=2e1;
plt.plot(cs,vCycleCa_MgI_KI(cs,K12,K23,K34,K45,K56,K61,KMg,KK),label="K$_{45}$ = %3.1f[1/M]"%(K45))
ylim([0,1])
xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("[CaCaM]")
#plt.title("Ca-bound CaM probability wrt\n CaM target peptide concentration and peptide affinity")
#plt.gcf().savefig("/home/AD/pmke226/grants/151101_EF_NSF/figs/cambind.png")

# %%
Image(filename="SERCA_pump_cycle_Mg_inhibited_K_intermediate.png")

# %% [markdown]
# # Code from Pete taken from cambind notebook

# %% [markdown]
# $$\phi_f = \frac{1}{1 + c^3 K_{12}(1+c K_{24}(1+p K_{45}(1+c K_{35}^{-1})))}$$
# $$\phi_f = \frac{1}{1 + c^3 K_{12}(1+c K_{24}))}$$
#
#
# $$\phi_{bound} \equiv 1-\phi_f$$

# %%
K12=1.e18; K45=1e1; K35=1e0;

# %%
def func(c,p,K45=1e7):
    denom = 1 + c**3*K12*1+c*K24*(1+p*K45*(1+c*K35**(-1)))
    return 1 - 1/denom 

vfunc = np.vectorize(func)
cs = 10**np.linspace(-9,-5,100)

# %%
p=0.; K45=1e1;
plt.plot(cs,vfunc(cs,p,K45),label="p = %3.1f [M], K$_{45}$ = %3.1f[1/M]"%(p,K45))
p=0.1; K45=1e1;
plt.plot(cs,vfunc(cs,p,K45),label="p = %3.1f [M], K$_{45}$ = %3.1f[1/M]"%(p,K45))
p=0.1; K45=2e1;
plt.plot(cs,vfunc(cs,p,K45),label="p = %3.1f [M], K$_{45}$ = %3.1f[1/M]"%(p,K45))
ylim([0,1])
xscale('log')
plt.legend(loc=0)
plt.xlabel("[Ca]")
plt.ylabel("[CaCaM]")
plt.title("Ca-bound CaM probability wrt\n CaM target peptide concentration and peptide affinity")
plt.gcf().savefig("/home/AD/pmke226/grants/151101_EF_NSF/figs/cambind.png")
