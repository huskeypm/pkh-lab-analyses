# %%
import loos
import sys
import math
import PyTraj
import carbonylDensityAnalysis as cda
import binfuncs as bf

class empty:pass

# autoreload modules 
# %load_ext autoreload
# %autoreload 2

# %%
prefix = "/home/AD/bdst227/namd-mg-lipid/analysis/"
cols = ["-","-.","--"]

cases = []
caseNames = ["mg50nsRun"]

# timing 
NS_PER_FRAME = 0.002 # [ns/fr] Verified 
PTRAJ_DOWNSAMPLE = 1 # Verified 
FRAME_TO_TIME = NS_PER_FRAME * PTRAJ_DOWNSAMPLE

runs = ["1", "2", "3"]

for i, caseName in enumerate(caseNames):
    
    for j, run in enumerate(runs):
        
        holo = empty()
        holo.dcdFile = prefix+caseName+run#+ run + ".dcd"
        holo.pdbFile = prefix+"step5_assemblyJustProtein"#+ run + ".pdb"
        #holo.col='r'
        holo.name = caseName#+run
        holo.frame_to_time = FRAME_TO_TIME
        cases.append(holo)
        print holo.dcdFile

# hack
#apos = cases[0::2]
holos = cases[:]

import parvfuncs as pf
pf.FRAME_TO_TIME = FRAME_TO_TIME
#pf.cols = cols
# Out:
# /home/AD/bdst227/namd-mg-lipid/analysis/mg50nsRun1
# /home/AD/bdst227/namd-mg-lipid/analysis/mg50nsRun2
# /home/AD/bdst227/namd-mg-lipid/analysis/mg50nsRun3

# %%
for i, case in enumerate(cases):
    case.trajs = []
    #for j, run in enumerate(runs):
    pdbFile = case.pdbFile+".pdb"
    dcdFile = case.dcdFile+".dcd"
    print "Loading " + dcdFile
    case.system=loos.createSystem(pdbFile) # only loading once, since should be same across runs
    traj=loos.createTrajectory(dcdFile,case.system)
    case.trajs.append(traj)
    print "Frames for %s: %d" %(case.name,traj.nframes())
# Out:
# Loading /home/AD/bdst227/namd-mg-lipid/analysis/mg50nsRun1.dcd
# Frames for mg50nsRun: 25000
# Loading /home/AD/bdst227/namd-mg-lipid/analysis/mg50nsRun2.dcd
# Frames for mg50nsRun: 25000
# Loading /home/AD/bdst227/namd-mg-lipid/analysis/mg50nsRun3.dcd
# Frames for mg50nsRun: 25000

# %%
alldists = []
alltimes = []
for i,case in enumerate(holos):
  sel1 = loos.selectAtoms(case.system,'name == "MG" && resid == 1002')
  sel2 = loos.selectAtoms(case.system,'name == "OE1" && resid == 771')
  #for j, run in enumerate(runs):
  run = 1
  idx = np.int(run)-1 # since not zero-indexes    
  dists = pf.dodist(case,idx,sel1,sel2)
  alldists.append(dists[:,1])
  alltimes.append(dists[:,0])
  plot(dists[:,0],dists[:,1],label = "SERCA_lipid_MG_run%s" %(i+1))
 # plot(dists[:,1],case.col,label="%s"%(case.name) )
        
plt.xlabel("time [ns]")
plt.ylabel("Dist [Ang]") 
plt.title("MGdist_OE1_771")
plt.legend(loc=2)
plt.gcf().savefig("_MGDist.png")
# Out:
# 25000
# 25000
# 25000

# %%
alldists = []
alltimes = []
for i,case in enumerate(holos):
  sel1 = loos.selectAtoms(case.system,'name == "MG" && resid == 1002')
  sel2 = loos.selectAtoms(case.system,'name == "OE2" && resid == 771')
  #for j, run in enumerate(runs):
  run = 1
  idx = np.int(run)-1 # since not zero-indexes    
  dists = pf.dodist(case,idx,sel1,sel2)
  alldists.append(dists[:,1])
  alltimes.append(dists[:,0])
  plot(dists[:,0],dists[:,1],label = "SERCA_lipid_MG_run%s" %(i+1))
 # plot(dists[:,1],case.col,label="%s"%(case.name) )
        
plt.xlabel("time [ns]")
plt.ylabel("Dist [Ang]") 
plt.title("MGdist_OE2_771")
plt.legend(loc=2)
plt.gcf().savefig("_MGDist.png")
# Out:
# 25000
# 25000
# 25000

# %%
alldists = []
alltimes = []
for i,case in enumerate(holos):
  sel1 = loos.selectAtoms(case.system,'name == "MG" && resid == 1002')
  sel2 = loos.selectAtoms(case.system,'name == "OD2" && resid == 800')
  #for j, run in enumerate(runs):
  run = 1
  idx = np.int(run)-1 # since not zero-indexes    
  dists = pf.dodist(case,idx,sel1,sel2)
  alldists.append(dists[:,1])
  alltimes.append(dists[:,0])
  plot(dists[:,0],dists[:,1],label = "SERCA_lipid_MG_run%s" %(i+1))
 # plot(dists[:,1],case.col,label="%s"%(case.name) )
        
plt.xlabel("time [ns]")
plt.ylabel("Dist [Ang]") 
plt.title("MGdist_OD2_800")
plt.legend(loc=2)
plt.gcf().savefig("_MGDist.png")
# Out:
# 25000
# 25000
# 25000

# %%
alldists = []
alltimes = []
for i,case in enumerate(holos):
  sel1 = loos.selectAtoms(case.system,'name == "MG" && resid == 1002')
  sel2 = loos.selectAtoms(case.system,'name == "OD1" && resid == 796')
  #for j, run in enumerate(runs):
  run = 1
  idx = np.int(run)-1 # since not zero-indexes    
  dists = pf.dodist(case,idx,sel1,sel2)
  alldists.append(dists[:,1])
  alltimes.append(dists[:,0])
  plot(dists[:,0],dists[:,1],label = "SERCA_lipid_MG_run%s" %(i+1))
 # plot(dists[:,1],case.col,label="%s"%(case.name) )
        
plt.xlabel("time [ns]")
plt.ylabel("Dist [Ang]") 
plt.title("MGdist_OD1_796")
plt.legend(loc=2)
plt.gcf().savefig("_MGDist.png")
# Out:
# 25000
# 25000
# 25000

# %%
alldists = []
alltimes = []
for i,case in enumerate(holos):
  sel1 = loos.selectAtoms(case.system,'name == "MG" && resid == 1002')
  sel2 = loos.selectAtoms(case.system,'name == "OD1" && resid == 768')
  #for j, run in enumerate(runs):
  run = 1
  idx = np.int(run)-1 # since not zero-indexes    
  dists = pf.dodist(case,idx,sel1,sel2)
  alldists.append(dists[:,1])
  alltimes.append(dists[:,0])
  plot(dists[:,0],dists[:,1],label = "SERCA_lipid_MG_run%s" %(i+1))
 # plot(dists[:,1],case.col,label="%s"%(case.name) )
        
plt.xlabel("time [ns]")
plt.ylabel("Dist [Ang]") 
plt.title("MGdist_OD1_768")
plt.legend(loc=2)
plt.gcf().savefig("_MGDist.png")
# Out:
# 25000
# 25000
# 25000

# %%
alldists = []
alltimes = []
for i,case in enumerate(holos):
  sel1 = loos.selectAtoms(case.system,'name == "MG" && resid == 1002')
  sel2 = loos.selectAtoms(case.system,'name == "O" && resid == 305')
  #for j, run in enumerate(runs):
  run = 1
  idx = np.int(run)-1 # since not zero-indexes    
  dists = pf.dodist(case,idx,sel1,sel2)
  alldists.append(dists[:,1])
  alltimes.append(dists[:,0])
  plot(dists[:,0],dists[:,1],label = "SERCA_lipid_MG_run%s" %(i+1))
 # plot(dists[:,1],case.col,label="%s"%(case.name) )
        
plt.xlabel("time [ns]")
plt.ylabel("Dist [Ang]") 
plt.title("MGdist_O_305")
plt.legend(loc=2)
plt.gcf().savefig("_MGDist.png")
# Out:
# 25000
# 25000
# 25000

# %%
alldists = []
alltimes = []
for i,case in enumerate(holos):
  sel1 = loos.selectAtoms(case.system,'name == "MG" && resid == 1002')
  sel2 = loos.selectAtoms(case.system,'name == "OD1" && resid == 800')
  #for j, run in enumerate(runs):
  run = 1
  idx = np.int(run)-1 # since not zero-indexes    
  dists = pf.dodist(case,idx,sel1,sel2)
  alldists.append(dists[:,1])
  alltimes.append(dists[:,0])
  plot(dists[:,0],dists[:,1],label = "SERCA_lipid_MG_run%s" %(i+1))
 # plot(dists[:,1],case.col,label="%s"%(case.name) )
        
plt.xlabel("time [ns]")
plt.ylabel("Dist [Ang]") 
plt.title("MGdist_OD1_800")
plt.legend(loc=2)
plt.gcf().savefig("_MGDist.png")
# Out:
# 25000
# 25000
# 25000

# %%
prefix1 = "/net/share/bdst227/Gordon/mg_SERCA_dcd/run2/"
prefix2 = "/home/AD/bdst227/namd-mg-lipid/analysis/"

cols = ["-","-.","--"]

cases = []
caseNames = ["mg100nsRun2_10"]

# timing 
NS_PER_FRAME = 0.002 # [ns/fr] Verified 
PTRAJ_DOWNSAMPLE = 1 # Verified 
FRAME_TO_TIME = NS_PER_FRAME * PTRAJ_DOWNSAMPLE

#runs = ["1", "2", "3"]
runs = ["3"]

for i, caseName in enumerate(caseNames):
    
   for j, run in enumerate(runs):
        holo = empty()
        holo.dcdFile = prefix2+caseName#+ run + ".dcd"
        holo.pdbFile = prefix2+"step5_assemblyJustProtein_10"#+ run + ".pdb"
        holo.col='r'
        holo.name = caseName#+run
        holo.frame_to_time = FRAME_TO_TIME
        cases.append(holo)
        print holo.dcdFile

# hack
#apos = cases[0::2]
holos = cases[:]

import parvfuncs as pf
pf.FRAME_TO_TIME = FRAME_TO_TIME
pf.cols = cols
# Out:
# /home/AD/bdst227/namd-mg-lipid/analysis/mg100nsRun2_10

# %%
for i, case in enumerate(cases):
    case.trajs = []
    #for j, run in enumerate(runs):
    pdbFile = case.pdbFile+".pdb"
    dcdFile = case.dcdFile+".dcd"
    print "Loading " + dcdFile
    case.system=loos.createSystem(pdbFile) # only loading once, since should be same across runs
    traj=loos.createTrajectory(dcdFile,case.system)
    case.trajs.append(traj)
    print "Frames for %s: %d" %(case.name,traj.nframes())
# Out:
# Loading /home/AD/bdst227/namd-mg-lipid/analysis/mg100nsRun2_10.dcd
# Frames for mg100nsRun2_10: 47513

# %%
for i, case in enumerate(cases):
    case.trajs = []
    for j, run in enumerate(runs):
        print case.traj[j].nframes())
# Out:
#   File "<ipython-input-122-f5fd8c82eb2b>", line 4
#     print case.traj[j].nframes())
#                                 ^
# SyntaxError: invalid syntax

# %%
def CarbonylDensityAnalysis_BS(case,idx=0,\
                            loopType = "cEF", 
                            calIdx = 109,
                            binMin=-1,
                            binMax=-1,
                            res = 0.5, # Angstroms
                            timeStepMax = None
                            ):

    ## Make selection
    selAllOs = loos.selectAtoms(case.system,'name=~"O"') # &&segid=="PROA"')
    selCa = loos.selectAtoms(case.system,'name=="MG"&& resid==%d'%(calIdx))
    print selAllOs
    print selCa

    ## compute all distancers
    nOs = selAllOs.size()
    #print nOs
    if timeStepMax==None:
    #  print "Trajs Idx ", case.trajs[idx].nframes()
      nTs = case.trajs[idx].nframes()
    else:
      nTs = timeStepMax
      # use value passed in
        
    #print "nFrame " , nTs
    allDists = np.zeros((nOs,nTs))
    ts = np.zeros(nTs)
    coordinating=[]
    for i in range(nOs):
        selO = selAllOs.subset(i,1)
        dists = pf.dodist(case,idx,selO,selCa)
       # print np.shape(dists)
        allDists[i,:] = dists[0:nTs,1] 
        ts  = dists[0:nTs,0]
        print  allDists[i,:]
     #   singleDist = allDists[i,-1]
     #   if singleDist < 3.0:
     #     coordinating.append(i)  
     #     print "im coordinating at %f/%s Ang"%(singleDist,"cat")
     #     print selO
       # print allDists[i,:]
    
    #myFile = "case0idx%d_dists.txt"%idx
    #np.savetxt(myFile,allDists)
    #myFile = "case0idx%d_ts.txt"%idx
    #np.savetxt(myFile,ts)

    ## get bounds for binning 
    if binMin<0:
        binMin=np.floor(np.min(allDists))
    if binMax<0:
        binMax=np.ceil(np.max(allDists))

    ## do binning for each O-Ca dist
    zs=[]
    zCs=[]
    for i in range(nOs):
      grid_t,grid_r,z = BinTimeSeries_BS(allDists[i,:],binMin,binMax,res=res,plot=False)#plot=True)
      zs.append(z)
        
      # debug 
   #   if i in coordinating:  
   #     grid_t,grid_r,z = BinTimeSeries_BS(allDists[i,:],binMin,binMax,res=res,plot=True)
   #     zCs.append(z)

           
    ## display density 
    dummy=plotOxyDensity_BS(grid_t,grid_r,zs,title=loopType)

    return grid_t,grid_r,zCs

# %%
def BinTimeSeries_BS(data,binMin,binMax,res=1.,plot=True):
    
    # define bins 
    nBins = np.int((1/res)*(binMax-binMin)+1)
    bins = (np.linspace(binMin, binMax, nBins)) - 0.25
    #print "bins: " , bins

    
    #digitize into bins 
    digitized = np.digitize(data, bins)

    # create 2D matrix of bin versus time
    nTs = np.shape(data)[0]
    z=np.zeros((nBins,nTs))
    for i in range(nBins):
      z[i,np.where(digitized==i)]=1

    # create 2D coordinates and plot
    grid_t,grid_r = np.mgrid[0:(nTs-1):(nTs*1j),binMin:binMax:(nBins*1j)]
    #np.shape(grid_x)
    #pcolormesh(z)
    if plot:
      plt.figure()
      plt.pcolormesh(grid_t,grid_r,z.transpose())
    return grid_t,grid_r,z

# %%
ts,rs,zs=CarbonylDensityAnalysis_BS(case, idx=idx, loopType="Mg to Oxy distance in run %d"%idx, calIdx = 1002, binMax=15,\
                                   timeStepMax=3)
# Out:
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 25000
# 6.0

# %%
zs=z
print np.shape(z)

# z[oxyNum,rBin,time]
for i in range(7):
#print (z[0])[:,0]
  print (z[i])[:,-1]

print rs    

#print np.sum(zs,axis=0)[:,-1]
newzs = []
#newzs.append()
print zs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-8c35b330979f> in <module>()
# ----> 1 zs=z
#       2 print np.shape(z)
#       3
#       4 # z[oxyNum,rBin,time]
#       5 for i in range(7):
#
# NameError: name 'z' is not defined

# %%
ar = np.sum(zs,axis=0)
histo = np.sum(ar,axis=1)
print ar.T
print histo

np.shape(zs)
v = np.zeros((7,29,3))
v[0,2,:] = 6
#print v


l=plotOxyDensity_BS(ts,rs,v,nCalCoord=1.,ylimMax=7.)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-778a8e526fa5> in <module>()
#       1 ar = np.sum(zs,axis=0)
# ----> 2 histo = np.sum(ar,axis=1)
#       3 print ar.T
#       4 print histo
#       5
#
# /usr/lib/python2.7/dist-packages/numpy/core/fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1709                                 out=out, keepdims=keepdims)
#    1710         # NOTE: Dropping the keepdims parameters here...
# -> 1711         return sum(axis=axis, dtype=dtype, out=out)
#    1712     else:
#    1713         return _methods._sum(a, axis=axis, dtype=dtype,
#
# /usr/lib/python2.7/dist-packages/numpy/core/_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      23 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#      24     return um.add.reduce(a, axis=axis, dtype=dtype,
# ---> 25                             out=out, keepdims=keepdims)
#      26
#      27 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: 'axis' entry is out of bounds

# %%
def plotOxyDensity_BS(grid_t, grid_r, zs, title = "NONE",nCalCoord = 6.,ylimMax=1.):
      xlimLim = [0,12]
      frames_to_time = 0.002
      print nCalCoord
      scaleByCoordinationNumber = 1 / nCalCoord
      ylimLim = [0,ylimMax]
  
      ar = np.sum(zs,axis=0)

      
        
      # density plot 
      plt.subplot(211)
      plt.tight_layout()
      plt.title(title)
      plt.xlabel("Time (ns)",fontsize=14, weight="bold")
      plt.ylabel("Mg/O \n distance [A]",fontsize=14, weight="bold")
      plt.pcolormesh(grid_t * frames_to_time,grid_r,ar.transpose())
      plt.colorbar()
      plt.clim([0,nCalCoord])
      plt.ylim([0,12])

      # histogram plot
      plt.subplot(212)
      plt.tight_layout()
      plt.xlabel("Mg/O distance [A]",fontsize=14, weight="bold")
      plt.ylabel("Radial \n Distribution",fontsize=14, weight="bold") 
      histo=np.sum(ar,axis=1)
      nTs  = np.shape(ar)[1]
      plt.plot(grid_r[0,:],histo/nTs,'-o')
      plt.tight_layout()
      plt.xlim([0,12])
      plt.ylim([0,7])
     
     # output=np.column_stack((grid_r[0,:],ar))  
      ar_title="ar_"+title+".txt"
      np.savetxt(ar_title,ar)
          
      plt.gcf().savefig(title+".png")
        
      # save data 
      l = np.mean(ar,axis=1) #Same as summing up and averaging over nTs.  See above.
      s = np.std(ar,axis=1)
      j = np.zeros([np.shape(l)[0],3])
      j[:,0] = grid_r[0,:]
      j[:,1] = l
      j[:,2] = s

      np.savetxt(title + ".txt",j)
      return ar

# %%
#for i, case in enumerate(cases):
#   for j, run in enumerate(runs):
run = 2 #mg50nsRun2_10
idx = np.int(run)-1
plt.figure()
CarbonylDensityAnalysis_BS(case, idx=idx, loopType="Mg to Oxy distance in run 1", calIdx = 1002, binMax=15, timeStepMax = 25000)
# Out:
# <GROUP PERIODIC='(0,0,0)'>
#    <ATOM INDEX='18' ID='19' NAME='O' RESID='61' RESNAME='LEU' COORDS='(6.764,11.625,-38.548)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='37' ID='38' NAME='O' RESID='97' RESNAME='ILE' COORDS='(-4.714,10.018,-34.253)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='46' ID='47' NAME='OD1' RESID='101' RESNAME='ASN' COORDS='(-0.448,7.946,-32.05)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='51' ID='52' NAME='O' RESID='101' RESNAME='ASN' COORDS='(-3.595,9.494,-28.146)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='70' ID='71' NAME='O' RESID='264' RESNAME='ILE' COORDS='(12.015,-0.05,-37.491)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='86' ID='87' NAME='O' RESID='300' RESNAME='VAL' COORDS='(6.395,6.047,-39.423)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='96' ID='97' NAME='O' RESID='301' RESNAME='ALA' COORDS='(3.718,4.048,-38.933)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='115' ID='116' NAME='O' RESID='302' RESNAME='LEU' COORDS='(5.657,2.303,-37.204)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='125' ID='126' NAME='O' RESID='303' RESNAME='ALA' COORDS='(7.055,4.085,-35.11)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='141' ID='142' NAME='O' RESID='304' RESNAME='VAL' COORDS='(3.772,5.29,-34.086)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='151' ID='152' NAME='O' RESID='305' RESNAME='ALA' COORDS='(3.728,2.186,-33.26)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='161' ID='162' NAME='O' RESID='306' RESNAME='ALA' COORDS='(6.156,-0.648,-32.72)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='180' ID='181' NAME='O' RESID='307' RESNAME='ILE' COORDS='(5.158,2.473,-30.851)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='194' ID='195' NAME='O' RESID='308' RESNAME='PRO' COORDS='(6.761,3.676,-27.386)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='206' ID='207' NAME='OE1' RESID='309' RESNAME='GLU' COORDS='(2.546,3.136,-30.071)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='207' ID='208' NAME='OE2' RESID='309' RESNAME='GLU' COORDS='(1.747,4.581,-31.538)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='209' ID='210' NAME='O' RESID='309' RESNAME='GLU' COORDS='(4.343,6.505,-26.1)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='216' ID='217' NAME='O' RESID='310' RESNAME='GLY' COORDS='(3.975,3.567,-22.04)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='235' ID='236' NAME='O' RESID='311' RESNAME='LEU' COORDS='(5.455,2.009,-19.742)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='249' ID='250' NAME='OH' RESID='763' RESNAME='TYR' COORDS='(-5.321,-5.598,-28.942)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='256' ID='257' NAME='O' RESID='763' RESNAME='TYR' COORDS='(0.114,-6.279,-27.71)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='275' ID='276' NAME='O' RESID='764' RESNAME='LEU' COORDS='(2.322,-5.076,-28.638)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='294' ID='295' NAME='O' RESID='765' RESNAME='ILE' COORDS='(5.01,-6.452,-29.928)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='302' ID='303' NAME='OG' RESID='766' RESNAME='SER' COORDS='(1.38,-9.51,-28.579)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='305' ID='306' NAME='O' RESID='766' RESNAME='SER' COORDS='(3.187,-8.117,-31.769)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='313' ID='314' NAME='OG' RESID='767' RESNAME='SER' COORDS='(0.486,-4.979,-29.877)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='316' ID='317' NAME='O' RESID='767' RESNAME='SER' COORDS='(1.524,-6.072,-33.591)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='325' ID='326' NAME='OD1' RESID='768' RESNAME='ASN' COORDS='(2.549,-1.663,-31.98)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='330' ID='331' NAME='O' RESID='768' RESNAME='ASN' COORDS='(4.779,-4.746,-34.499)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='346' ID='347' NAME='O' RESID='769' RESNAME='VAL' COORDS='(5.797,-7.194,-35.947)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='353' ID='354' NAME='O' RESID='770' RESNAME='GLY' COORDS='(3.152,-7.32,-38.103)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='365' ID='366' NAME='OE1' RESID='771' RESNAME='GLU' COORDS='(1.086,-1.617,-34.417)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='366' ID='367' NAME='OE2' RESID='771' RESNAME='GLU' COORDS='(-0.459,-2.897,-33.558)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='368' ID='369' NAME='O' RESID='771' RESNAME='GLU' COORDS='(3.369,-3.849,-38.982)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='384' ID='385' NAME='O' RESID='772' RESNAME='VAL' COORDS='(6.355,-5.499,-40.656)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='400' ID='401' NAME='O' RESID='773' RESNAME='VAL' COORDS='(6.064,-8.436,-42.243)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='419' ID='420' NAME='O' RESID='775' RESNAME='ILE' COORDS='(6.575,-4.326,-45.185)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='438' ID='439' NAME='O' RESID='792' RESNAME='LEU' COORDS='(-2.56,1.207,-38.141)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='457' ID='458' NAME='O' RESID='793' RESNAME='LEU' COORDS='(-4.148,4.511,-36.681)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='481' ID='482' NAME='O' RESID='794' RESNAME='TRP' COORDS='(-6.786,2.349,-35.843)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='497' ID='498' NAME='O' RESID='795' RESNAME='VAL' COORDS='(-5.677,-0.177,-34.334)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='506' ID='507' NAME='OD1' RESID='796' RESNAME='ASN' COORDS='(-0.68,0.391,-33.348)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='511' ID='512' NAME='O' RESID='796' RESNAME='ASN' COORDS='(-4.101,1.601,-32.345)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='530' ID='531' NAME='O' RESID='797' RESNAME='LEU' COORDS='(-7.358,3.963,-32.066)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='546' ID='547' NAME='O' RESID='798' RESNAME='VAL' COORDS='(-7.462,0.232,-29.991)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='553' ID='554' NAME='OG1' RESID='799' RESNAME='THR' COORDS='(-3.565,-1.507,-32.318)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='560' ID='561' NAME='O' RESID='799' RESNAME='THR' COORDS='(-5.098,-1.719,-28.595)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='569' ID='570' NAME='OD1' RESID='800' RESNAME='ASP' COORDS='(-1.324,-0.866,-29.324)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='570' ID='571' NAME='OD2' RESID='800' RESNAME='ASP' COORDS='(-0.998,0.773,-30.828)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='572' ID='573' NAME='O' RESID='800' RESNAME='ASP' COORDS='(-3.907,2.565,-27.22)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='579' ID='580' NAME='O' RESID='801' RESNAME='GLY' COORDS='(-7.857,2.971,-25.855)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='589' ID='590' NAME='O' RESID='804' RESNAME='ALA' COORDS='(-5.313,-2.425,-22.425)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='605' ID='606' NAME='O' RESID='844' RESNAME='VAL' COORDS='(-0.618,-11.046,-39.116)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='624' ID='625' NAME='O' RESID='904' RESNAME='LEU' COORDS='(-6.366,-7.882,-35.953)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='636' ID='637' NAME='OE1' RESID='908' RESNAME='GLU' COORDS='(-2.877,-7.122,-32.026)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='637' ID='638' NAME='OE2' RESID='908' RESNAME='GLU' COORDS='(-2.668,-5.178,-33.034)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='640' ID='641' NAME='O' RESID='908' RESNAME='GLU' COORDS='(-6.518,-8.698,-29.939)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
# </GROUP>
# <GROUP PERIODIC='(0,0,0)'>
#    <ATOM INDEX='641' ID='642' NAME='MG' RESID='1002' RESNAME='MG' COORDS='(1.918,0.289,-33.033)' ALTLOC='' CHAINID='X' ICODE='' SEGID='HETB' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
# </GROUP>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-1cebeb5a0b98> in <module>()
#       4 idx = np.int(run)-1
#       5 plt.figure()
# ----> 6 CarbonylDensityAnalysis_BS(case, idx=idx, loopType="Mg to Oxy distance in run 1", calIdx = 1002, binMax=15, timeStepMax = 25000)
#
# <ipython-input-11-e9533ea857bc> in CarbonylDensityAnalysis_BS(case, idx, loopType, calIdx, binMin, binMax, res, timeStepMax)
#      29     for i in range(nOs):
#      30         selO = selAllOs.subset(i,1)
# ---> 31         dists = pf.dodist(case,idx,selO,selCa)
#      32        # print np.shape(dists)
#      33         allDists[i,:] = dists[0:nTs,1]
#
# /home/AD/bdst227/ipython/parvfuncs.pyc in dodist(case, run, sel1, sel2)
#      20
#      21 def dodist(case,run,sel1,sel2):
# ---> 22     dists = np.zeros((case.trajs[run].nframes(),2))
#      23     dists[:,0] = np.arange(case.trajs[run].nframes())*case.frame_to_time
#      24
#
# IndexError: list index out of range

# %%
#for i, case in enumerate(cases):
#   for j, run in enumerate(runs):
run=1
idx = 0#np.int(run)-1
plt.figure()
CarbonylDensityAnalysis_BS(case, idx=idx, loopType="Mg_to_Oxy_distance_in_run_1", calIdx = 1002, binMax=15)
# Out:
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 6.0
# (array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  1.00000000e+00,   1.00000000e+00,   1.00000000e+00, ...,
#            1.00000000e+00,   1.00000000e+00,   1.00000000e+00],
#         [  2.00000000e+00,   2.00000000e+00,   2.00000000e+00, ...,
#            2.00000000e+00,   2.00000000e+00,   2.00000000e+00],
#         ...,
#         [  4.99970000e+04,   4.99970000e+04,   4.99970000e+04, ...,
#            4.99970000e+04,   4.99970000e+04,   4.99970000e+04],
#         [  4.99980000e+04,   4.99980000e+04,   4.99980000e+04, ...,
#            4.99980000e+04,   4.99980000e+04,   4.99980000e+04],
#         [  4.99990000e+04,   4.99990000e+04,   4.99990000e+04, ...,
#            4.99990000e+04,   4.99990000e+04,   4.99990000e+04]]),
#  array([[  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         ...,
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ]]),
#  [])

# %%
run=2
idx = 0#np.int(run)-1
plt.figure()
CarbonylDensityAnalysis_BS(case, idx=idx, loopType="Mg_to_Oxy_distance_in_run_2", calIdx = 1002, binMax=15)
# Out:
# <GROUP PERIODIC='(0,0,0)'>
#    <ATOM INDEX='18' ID='19' NAME='O' RESID='61' RESNAME='LEU' COORDS='(6.764,11.625,-38.548)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='37' ID='38' NAME='O' RESID='97' RESNAME='ILE' COORDS='(-4.714,10.018,-34.253)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='46' ID='47' NAME='OD1' RESID='101' RESNAME='ASN' COORDS='(-0.448,7.946,-32.05)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='51' ID='52' NAME='O' RESID='101' RESNAME='ASN' COORDS='(-3.595,9.494,-28.146)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='70' ID='71' NAME='O' RESID='264' RESNAME='ILE' COORDS='(12.015,-0.05,-37.491)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='86' ID='87' NAME='O' RESID='300' RESNAME='VAL' COORDS='(6.395,6.047,-39.423)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='96' ID='97' NAME='O' RESID='301' RESNAME='ALA' COORDS='(3.718,4.048,-38.933)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='115' ID='116' NAME='O' RESID='302' RESNAME='LEU' COORDS='(5.657,2.303,-37.204)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='125' ID='126' NAME='O' RESID='303' RESNAME='ALA' COORDS='(7.055,4.085,-35.11)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='141' ID='142' NAME='O' RESID='304' RESNAME='VAL' COORDS='(3.772,5.29,-34.086)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='151' ID='152' NAME='O' RESID='305' RESNAME='ALA' COORDS='(3.728,2.186,-33.26)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='161' ID='162' NAME='O' RESID='306' RESNAME='ALA' COORDS='(6.156,-0.648,-32.72)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='180' ID='181' NAME='O' RESID='307' RESNAME='ILE' COORDS='(5.158,2.473,-30.851)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='194' ID='195' NAME='O' RESID='308' RESNAME='PRO' COORDS='(6.761,3.676,-27.386)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='206' ID='207' NAME='OE1' RESID='309' RESNAME='GLU' COORDS='(2.546,3.136,-30.071)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='207' ID='208' NAME='OE2' RESID='309' RESNAME='GLU' COORDS='(1.747,4.581,-31.538)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='209' ID='210' NAME='O' RESID='309' RESNAME='GLU' COORDS='(4.343,6.505,-26.1)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='216' ID='217' NAME='O' RESID='310' RESNAME='GLY' COORDS='(3.975,3.567,-22.04)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='235' ID='236' NAME='O' RESID='311' RESNAME='LEU' COORDS='(5.455,2.009,-19.742)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='249' ID='250' NAME='OH' RESID='763' RESNAME='TYR' COORDS='(-5.321,-5.598,-28.942)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='256' ID='257' NAME='O' RESID='763' RESNAME='TYR' COORDS='(0.114,-6.279,-27.71)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='275' ID='276' NAME='O' RESID='764' RESNAME='LEU' COORDS='(2.322,-5.076,-28.638)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='294' ID='295' NAME='O' RESID='765' RESNAME='ILE' COORDS='(5.01,-6.452,-29.928)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='302' ID='303' NAME='OG' RESID='766' RESNAME='SER' COORDS='(1.38,-9.51,-28.579)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='305' ID='306' NAME='O' RESID='766' RESNAME='SER' COORDS='(3.187,-8.117,-31.769)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='313' ID='314' NAME='OG' RESID='767' RESNAME='SER' COORDS='(0.486,-4.979,-29.877)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='316' ID='317' NAME='O' RESID='767' RESNAME='SER' COORDS='(1.524,-6.072,-33.591)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='325' ID='326' NAME='OD1' RESID='768' RESNAME='ASN' COORDS='(2.549,-1.663,-31.98)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='330' ID='331' NAME='O' RESID='768' RESNAME='ASN' COORDS='(4.779,-4.746,-34.499)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='346' ID='347' NAME='O' RESID='769' RESNAME='VAL' COORDS='(5.797,-7.194,-35.947)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='353' ID='354' NAME='O' RESID='770' RESNAME='GLY' COORDS='(3.152,-7.32,-38.103)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='365' ID='366' NAME='OE1' RESID='771' RESNAME='GLU' COORDS='(1.086,-1.617,-34.417)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='366' ID='367' NAME='OE2' RESID='771' RESNAME='GLU' COORDS='(-0.459,-2.897,-33.558)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='368' ID='369' NAME='O' RESID='771' RESNAME='GLU' COORDS='(3.369,-3.849,-38.982)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='384' ID='385' NAME='O' RESID='772' RESNAME='VAL' COORDS='(6.355,-5.499,-40.656)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='400' ID='401' NAME='O' RESID='773' RESNAME='VAL' COORDS='(6.064,-8.436,-42.243)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='419' ID='420' NAME='O' RESID='775' RESNAME='ILE' COORDS='(6.575,-4.326,-45.185)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='438' ID='439' NAME='O' RESID='792' RESNAME='LEU' COORDS='(-2.56,1.207,-38.141)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='457' ID='458' NAME='O' RESID='793' RESNAME='LEU' COORDS='(-4.148,4.511,-36.681)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='481' ID='482' NAME='O' RESID='794' RESNAME='TRP' COORDS='(-6.786,2.349,-35.843)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='497' ID='498' NAME='O' RESID='795' RESNAME='VAL' COORDS='(-5.677,-0.177,-34.334)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='506' ID='507' NAME='OD1' RESID='796' RESNAME='ASN' COORDS='(-0.68,0.391,-33.348)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='511' ID='512' NAME='O' RESID='796' RESNAME='ASN' COORDS='(-4.101,1.601,-32.345)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='530' ID='531' NAME='O' RESID='797' RESNAME='LEU' COORDS='(-7.358,3.963,-32.066)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='546' ID='547' NAME='O' RESID='798' RESNAME='VAL' COORDS='(-7.462,0.232,-29.991)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='553' ID='554' NAME='OG1' RESID='799' RESNAME='THR' COORDS='(-3.565,-1.507,-32.318)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='560' ID='561' NAME='O' RESID='799' RESNAME='THR' COORDS='(-5.098,-1.719,-28.595)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='569' ID='570' NAME='OD1' RESID='800' RESNAME='ASP' COORDS='(-1.324,-0.866,-29.324)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='570' ID='571' NAME='OD2' RESID='800' RESNAME='ASP' COORDS='(-0.998,0.773,-30.828)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='572' ID='573' NAME='O' RESID='800' RESNAME='ASP' COORDS='(-3.907,2.565,-27.22)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='579' ID='580' NAME='O' RESID='801' RESNAME='GLY' COORDS='(-7.857,2.971,-25.855)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='589' ID='590' NAME='O' RESID='804' RESNAME='ALA' COORDS='(-5.313,-2.425,-22.425)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='605' ID='606' NAME='O' RESID='844' RESNAME='VAL' COORDS='(-0.618,-11.046,-39.116)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='624' ID='625' NAME='O' RESID='904' RESNAME='LEU' COORDS='(-6.366,-7.882,-35.953)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='636' ID='637' NAME='OE1' RESID='908' RESNAME='GLU' COORDS='(-2.877,-7.122,-32.026)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='637' ID='638' NAME='OE2' RESID='908' RESNAME='GLU' COORDS='(-2.668,-5.178,-33.034)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
#    <ATOM INDEX='640' ID='641' NAME='O' RESID='908' RESNAME='GLU' COORDS='(-6.518,-8.698,-29.939)' ALTLOC='' CHAINID='X' ICODE='' SEGID='PROA' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
# </GROUP>
# <GROUP PERIODIC='(0,0,0)'>
#    <ATOM INDEX='641' ID='642' NAME='MG' RESID='1002' RESNAME='MG' COORDS='(1.918,0.289,-33.033)' ALTLOC='' CHAINID='X' ICODE='' SEGID='HETB' B='0' Q='1' CHARGE='0' MASS='1' ATOMICNUMBER='-1' MASK='201'/>
# </GROUP>
# 47513
# [ 17.2759669   16.88560084  18.43256431 ...,  19.73501787  19.60730969
#   19.57560242]
# 47513
# [ 13.67294198  13.46038599  15.03923035 ...,  16.04599662  16.77784816
#   16.82639374]
# 47513
# [ 15.91105541  14.71118347  15.70443329 ...,  16.97339917  16.09759334
#   16.95575535]
# 47513
# [ 14.65588756  13.03464269  13.82747983 ...,  14.35218816  14.13144268
#   14.13139378]
# 47513
# [ 16.1987569   15.87894942  16.57374359 ...,  24.84909251  24.39672547
#   24.28068389]
# 47513
# [ 23.60747978  22.91468229  23.59696282 ...,  22.47289132  22.49698244
#   21.96950961]
# 47513
# [ 25.54725397  25.01304665  25.66900252 ...,  23.42922452  22.84750452
#   23.32024086]
# 47513
# [ 30.1339864   29.26524966  30.61415121 ...,  26.84283821  26.51066053
#   26.48194219]
# 47513
# [ 27.2708891   25.9165627   27.19698146 ...,  25.93573138  25.35198179
#   25.61848587]
# 47513
# [ 29.00454333  27.76974031  28.83407045 ...,  27.60769716  27.02699622
#   27.19830771]
# 47513
# [ 31.18081244  30.33188592  31.42322547 ...,  31.05007593  30.18322389
#   30.19840279]
# 47513
# [ 30.38706745  29.87052095  30.59406562 ...,  30.0324891   28.03634452
#   28.8039969 ]
# 47513
# [ 34.35579249  33.42703606  33.8413275  ...,  34.2300399   34.00340888
#   34.4576058 ]
# 47513
# [ 30.71911073  30.51345875  31.48284328 ...,  30.65074026  30.24061526
#   30.62054473]
# 47513
# [ 26.28554207  25.29826669  26.42580086 ...,  25.88110864  25.10717118
#   25.42083058]
# 47513
# [ 24.05696393  23.64195579  24.19714721 ...,  24.96462959  24.22889621
#   24.48400972]
# 47513
# [ 24.87900732  24.45921528  24.99986751 ...,  25.98112843  25.21398092
#   25.48897028]
# 47513
# [ 25.81767577  25.16974898  25.90105241 ...,  27.22438703  26.38341649
#   26.69998874]
# 47513
# [ 28.40375326  27.97781644  28.17788951 ...,  28.34681742  27.92618045
#   28.13294151]
# 47513
# [ 20.1924474   19.38818925  20.18393349 ...,  23.46886077  23.31011282
#   23.50918059]
# 47513
# [ 22.89573854  21.46737043  22.21495086 ...,  19.88592022  19.52250136
#   19.66643382]
# 47513
# [ 17.39875243  16.64977561  17.25346497 ...,  18.36539513  17.98632784
#   18.23822667]
# 47513
# [ 23.27823345  23.48066171  23.45832378 ...,  23.62655963  23.27390955
#   22.89392839]
# 47513
# [ 25.31436441  25.20320444  25.19077526 ...,  26.85233259  26.93473533
#   27.05857615]
# 47513
# [ 27.04449593  26.98571918  27.05495646 ...,  27.7855801   27.97620111
#   28.13264631]
# 47513
# [ 27.35967168  27.24101215  27.4259211  ...,  28.24807992  28.2894352
#   28.37077678]
# 47513
# [ 26.98230764  26.60095161  27.0880509  ...,  27.48382162  27.0056885
#   27.18687681]
# 47513
# [ 31.51507998  30.8047809   31.70179069 ...,  31.67259876  31.18997371
#   31.45799491]
# 47513
# [ 29.13807463  28.76242255  28.86044857 ...,  28.91127726  28.74533004
#   28.94242215]
# 47513
# [ 27.03775971  26.69454028  26.94417977 ...,  28.92004693  28.70473163
#   29.25672384]
# 47513
# [ 25.44210979  24.80080044  25.2149642  ...,  29.8429622   29.48806364
#   30.17634655]
# 47513
# [ 20.82554797  20.05946835  20.30459942 ...,  22.3333357   22.87414239
#   22.97156112]
# 47513
# [ 21.30792447  20.40467941  20.76400494 ...,  23.0195244   23.43847
#   23.51431611]
# 47513
# [ 18.88538756  18.39748611  18.47909645 ...,  20.76374024  21.40341687
#   21.5367707 ]
# 47513
# [ 21.77751739  20.84976316  21.14277949 ...,  24.39820108  25.1267423
#   24.89661261]
# 47513
# [ 19.4393328   19.14835559  19.26179496 ...,  22.48490862  23.07594733
#   22.72392338]
# 47513
# [ 22.67808628  21.92682999  21.48292829 ...,  26.69257807  27.20319097
#   27.37037068]
# 47513
# [ 16.5757667   15.55081642  15.98713408 ...,  20.09813476  20.61307543
#   20.60773941]
# 47513
# [ 14.93460586  14.14106902  14.62087975 ...,  19.01515177  19.05996065
#   19.2491813 ]
# 47513
# [ 17.38435743  16.70994271  17.01126916 ...,  21.68539578  21.77339729
#   21.60193163]
# 47513
# [ 20.18941166  18.79040396  19.56853292 ...,  21.81893918  22.30157477
#   21.80808656]
# 47513
# [ 13.58400222  13.09276838  13.58169269 ...,  16.56450649  16.5190141
#   16.42234089]
# 47513
# [ 17.45249737  16.93426892  17.41139134 ...,  19.76182152  20.15218755
#   19.86451098]
# 47513
# [  8.38890073   6.95139832   7.36288486 ...,  14.37144448  14.69566723
#   14.74791509]
# 47513
# [ 13.31662615  12.52142087  12.58176783 ...,  19.18242477  19.39489481
#   18.73951901]
# 47513
# [ 12.8570013   11.43956554  12.75973216 ...,  17.94745562  17.76554753
#   17.74895223]
# 47513
# [ 16.32999705  15.01343956  16.01369946 ...,  19.96921089  19.27491398
#   19.88192794]
# 47513
# [ 16.89137968  16.0098307   17.73136385 ...,  23.98848591  23.05276808
#   23.64301663]
# 47513
# [ 16.13685154  16.02509237  17.50494206 ...,  22.7694992   21.84504606
#   22.54745773]
# 47513
# [ 11.70017524  10.75065434  11.84183931 ...,  16.48340919  15.99915608
#   16.17790431]
# 47513
# [ 10.41181041  10.04677456  10.72170063 ...,  13.10987505  12.55620982
#   13.21689115]
# 47513
# [ 13.13706634  12.47932116  13.05134914 ...,  15.91539273  15.39021699
#   16.36481897]
# 47513
# [  6.21392986   5.82554444   6.24863794 ...,   9.84368835  10.03859553
#    9.82449448]
# 47513
# [ 7.48923371  7.23982121  7.63047344 ...,  7.03542309  7.03332572
#   5.99795966]
# 47513
# [ 3.77984877  3.73711427  3.8256309  ...,  2.65344884  2.56400628
#   2.43960842]
# 47513
# [ 2.14895773  2.10299812  2.19806668 ...,  2.16604266  2.25405736
#   2.11024007]
# 47513
# [ 1.11100055  1.11099992  1.1109992  ...,  1.11100001  1.11100022
#   1.1110002 ]
# 6.0
# (array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  1.00000000e+00,   1.00000000e+00,   1.00000000e+00, ...,
#            1.00000000e+00,   1.00000000e+00,   1.00000000e+00],
#         [  2.00000000e+00,   2.00000000e+00,   2.00000000e+00, ...,
#            2.00000000e+00,   2.00000000e+00,   2.00000000e+00],
#         ...,
#         [  4.75100000e+04,   4.75100000e+04,   4.75100000e+04, ...,
#            4.75100000e+04,   4.75100000e+04,   4.75100000e+04],
#         [  4.75110000e+04,   4.75110000e+04,   4.75110000e+04, ...,
#            4.75110000e+04,   4.75110000e+04,   4.75110000e+04],
#         [  4.75120000e+04,   4.75120000e+04,   4.75120000e+04, ...,
#            4.75120000e+04,   4.75120000e+04,   4.75120000e+04]]),
#  array([[  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         ...,
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ]]),
#  [])

# %%
run=3
idx = 0#np.int(run)-1
plt.figure()
CarbonylDensityAnalysis_BS(case, idx=idx, loopType="Mg_to_Oxy_distance_in_run_3", calIdx = 1002, binMax=15)
# Out:
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 6.0
# (array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  1.00000000e+00,   1.00000000e+00,   1.00000000e+00, ...,
#            1.00000000e+00,   1.00000000e+00,   1.00000000e+00],
#         [  2.00000000e+00,   2.00000000e+00,   2.00000000e+00, ...,
#            2.00000000e+00,   2.00000000e+00,   2.00000000e+00],
#         ...,
#         [  4.99970000e+04,   4.99970000e+04,   4.99970000e+04, ...,
#            4.99970000e+04,   4.99970000e+04,   4.99970000e+04],
#         [  4.99980000e+04,   4.99980000e+04,   4.99980000e+04, ...,
#            4.99980000e+04,   4.99980000e+04,   4.99980000e+04],
#         [  4.99990000e+04,   4.99990000e+04,   4.99990000e+04, ...,
#            4.99990000e+04,   4.99990000e+04,   4.99990000e+04]]),
#  array([[  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         ...,
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ],
#         [  1. ,   1.5,   2. , ...,  14. ,  14.5,  15. ]]),
#  [])
