# %%
import matplotlib.pylab as pltx = np.arange(256)/256.y = np.arange(256)/256.p = np.outer(x,y) + 0.0*np.reshape(np.random.randn(256*256),[256,256])pcolormesh(p)colorbar()levels = np.array([0.3,0.4,0.5])imshow(p)contour(p,levels,hold='on',colors='k')
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x8769908>

# %%
import cPickle as pickle

# %%
pickle.dump( p, open( "save.p", "wb"))

# %%
pp = pickle.load( open( "save.p", "rb" ))

# %%
pcolormesh(pp)
