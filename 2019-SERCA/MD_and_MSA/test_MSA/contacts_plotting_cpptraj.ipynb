# %%
import cpptraj_contact_analysis as CCA
import matplotlib.pyplot as plt
#h1 = "/net/share/anku223/mdjobsbpv/CAWT_holo_amber_1/map_holo_1.txt"
#h2 = "/net/share/anku223/mdjobsbpv/CAWT_holo_amber_2/map_holo_2.txt"
#h3 = "/net/share/anku223/mdjobsbpv/CAWT_holo_amber_3/map_holo_3.txt"
a1 = "/net/share/anku223/mdjobsbpv/MGWT_holo_amber_1/map_mg_1.txt"
a2 = "/net/share/anku223/mdjobsbpv/MGWT_holo_amber_2/map_mg_1.txt"
a3 = "/net/share/anku223/mdjobsbpv/MGWT_holo_amber_3/map_mg_1.txt"
h1 = "/net/share/anku223/mdjobsbpv/CAWT_holo_amber_1/map_ca_1.txt"
h2 = "/net/share/anku223/mdjobsbpv/CAWT_holo_amber_2/map_ca_1.txt"
h3 = "/net/share/anku223/mdjobsbpv/CAWT_holo_amber_3/map_ca_1.txt"
figname = "contact_ca_mg_new.png"
xlim = 113
ylim = 113
color_title = "Fraction of Time Contact is Maintained"
title = "Contacts Formed/Broken in PV \n Upon Calcium vs. Magnesium Binding"
x_axis = "PV Residue Number"
y_axis = "PV Residue Number"
CCA.cpptraj_analysis(h1,h2,h3,a1,a2,a3,figname,xlim,ylim,color_title,title,x_axis,y_axis)

# %%
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f723982ab00>

# %%
# Out:
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,  -8.28333333e-02
#    -1.33333333e-04   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#    -1.37766667e-01  -3.35666667e-02]
#  ...,
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]
