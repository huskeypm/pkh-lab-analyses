# %%
import numpy as np
CD_WTAPO1 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/WTAPO/rmsd_CD_WTAPO1.txt")
CD_WTAPO2 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/WTAPO/rmsd_CD_WTAPO2.txt")
CD_WTAPO3 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/WTAPO/rmsd_CD_WTAPO3.txt")
font = {'weight':'bold','size': 12}
matplotlib.rc('font', **font)
plt.plot(CD_WTAPO1[0:49999,0]/500,CD_WTAPO1[0:49999,1], label= "Run 1")
plt.plot(CD_WTAPO2[0:49999,0]/500,CD_WTAPO2[0:49999,1], label= "Run 2")
plt.plot(CD_WTAPO3[0:49999,0]/500,CD_WTAPO3[0:49999,1], label= "Run 3")
plt.ylabel("RMSD ($\AA$)", **font)
plt.xlabel("Time (ns)", **font)
plt.legend(loc="upper right")
plt.title("RMSD of Apo PV CD Loop", **font)
#plt.ylim(0,7)
plt.tight_layout()
plt.gcf().savefig("/net/share/shared/papers/150611_MSA_AS/RMSD/WTAPO_CD_RMSD.png", dpi=300)

# %%
import numpy as np
EF_WTAPO1 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/WTAPO/rmsd_EF_WTAPO1.txt")
EF_WTAPO2 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/WTAPO/rmsd_EF_WTAPO2.txt")
EF_WTAPO3 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/WTAPO/rmsd_EF_WTAPO3.txt")
font = {'weight':'bold','size': 12}
matplotlib.rc('font', **font)
plt.plot(EF_WTAPO1[0:49999,0]/500,EF_WTAPO1[0:49999,1], label= "Run 1")
plt.plot(EF_WTAPO2[0:49999,0]/500,EF_WTAPO2[0:49999,1], label= "Run 2")
plt.plot(EF_WTAPO3[0:49999,0]/500,EF_WTAPO3[0:49999,1], label= "Run 3")
plt.ylabel("RMSD ($\AA$)", **font)
plt.xlabel("Time (ns)", **font)
plt.legend(loc="upper right")
plt.title("RMSD of Apo PV EF Loop", **font)
plt.ylim(0,8)
plt.tight_layout()
plt.gcf().savefig("/net/share/shared/papers/150611_MSA_AS/RMSD/WTAPO_EF_RMSD.png", dpi=300)

# %%
import numpy as np
EF_CAWT1 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/CAWT/rmsd_EF_CAWT1.txt")
EF_CAWT2 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/CAWT/rmsd_EF_CAWT2.txt")
EF_CAWT3 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/CAWT/rmsd_EF_CAWT3.txt")
font = {'weight':'bold','size': 12}
matplotlib.rc('font', **font)
plt.plot(EF_CAWT1[0:49999,0]/500,EF_CAWT1[0:49999,1], label= "Run 1")
plt.plot(EF_CAWT2[0:49999,0]/500,EF_CAWT2[0:49999,1], label= "Run 2")
plt.plot(EF_CAWT3[0:49999,0]/500,EF_CAWT3[0:49999,1], label= "Run 3")
plt.ylabel("RMSD ($\AA$)", **font)
plt.xlabel("Time (ns)", **font)
plt.legend(loc="upper right")
plt.title("RMSD of Ca-bound PV EF Loop", **font)
#plt.ylim(0,8)
plt.tight_layout()
plt.gcf().savefig("/net/share/shared/papers/150611_MSA_AS/RMSD/CAWT_EF_RMSD.png", dpi=300)

# %%
import numpy as np
CD_CAWT1 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/CAWT/rmsd_CD_CAWT1.txt")
CD_CAWT2 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/CAWT/rmsd_CD_CAWT2.txt")
CD_CAWT3 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/CAWT/rmsd_CD_CAWT3.txt")
font = {'weight':'bold','size': 12}
matplotlib.rc('font', **font)
plt.plot(CD_CAWT1[0:49999,0]/500,CD_CAWT1[0:49999,1], label= "Run 1")
plt.plot(CD_CAWT2[0:49999,0]/500,CD_CAWT2[0:49999,1], label= "Run 2")
plt.plot(CD_CAWT3[0:49999,0]/500,CD_CAWT3[0:49999,1], label= "Run 3")
plt.ylabel("RMSD ($\AA$)", **font)
plt.xlabel("Time (ns)", **font)
plt.legend(loc="upper right")
plt.title("RMSD of Ca-bound PV CD Loop", **font)
#plt.ylim(0,8)
plt.tight_layout()
plt.gcf().savefig("/net/share/shared/papers/150611_MSA_AS/RMSD/CAWT_CD_RMSD.png", dpi=300)

# %%
import numpy as np
CD_MGWT1 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/MGWT/rmsd_CD_MGWT1.txt")
CD_MGWT2 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/MGWT/rmsd_CD_MGWT2.txt")
CD_MGWT3 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/MGWT/rmsd_CD_MGWT3.txt")
font = {'weight':'bold','size': 12}
matplotlib.rc('font', **font)
plt.plot(CD_MGWT1[0:49999,0]/500,CD_MGWT1[0:49999,1], label= "Run 1")
plt.plot(CD_MGWT2[0:49999,0]/500,CD_MGWT2[0:49999,1], label= "Run 2")
plt.plot(CD_MGWT3[0:49999,0]/500,CD_MGWT3[0:49999,1], label= "Run 3")
plt.ylabel("RMSD ($\AA$)", **font)
plt.xlabel("Time (ns)", **font)
plt.legend(loc="upper right")
plt.title("RMSD of Mg-bound PV CD Loop", **font)
#plt.ylim(0,8)
plt.tight_layout()
plt.gcf().savefig("/net/share/shared/papers/150611_MSA_AS/RMSD/MGWT_CD_RMSD.png", dpi=300)

# %%
import numpy as np
EF_MGWT1 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/MGWT/rmsd_EF_MGWT1.txt")
EF_MGWT2 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/MGWT/rmsd_EF_MGWT2.txt")
EF_MGWT3 = np.loadtxt("/net/share/anku223/mdjobsbpv/ANALYSIS_LEGIT/MGWT/rmsd_EF_MGWT3.txt")
font = {'weight':'bold','size': 12}
matplotlib.rc('font', **font)
plt.plot(EF_MGWT1[0:49999,0]/500,EF_MGWT1[0:49999,1], label= "Run 1")
plt.plot(EF_MGWT2[0:49999,0]/500,EF_MGWT2[0:49999,1], label= "Run 2")
plt.plot(EF_MGWT3[0:49999,0]/500,EF_MGWT3[0:49999,1], label= "Run 3")
plt.ylabel("RMSD ($\AA$)", **font)
plt.xlabel("Time (ns)", **font)
plt.legend(loc="upper right")
plt.title("RMSD of Mg-bound PV EF Loop", **font)
#plt.ylim(0,8)
plt.tight_layout()
plt.gcf().savefig("/net/share/shared/papers/150611_MSA_AS/RMSD/MGWT_EF_RMSD.png", dpi=300)

# %%
font = {'weight':'bold','size': 12}
dataL85FAPO = np.zeros([np.shape(L85FAPO1_rmsfdata[0:108,1])[0],3])
dataL85FAPO[:,0]= L85FAPO1_rmsfdata[0:108,1]; dataL85FAPO[:,1] = L85FAPO2_rmsfdata[0:108,1]; dataL85FAPO[:,2] = L85FAPO3_rmsfdata[0:108,1]
dataWTAPO = np.zeros([np.shape(WTAPO1_rmsfdata[0:108,1])[0],3])
dataWTAPO[:,0]= WTAPO1_rmsfdata[0:108,1]; dataWTAPO[:,1] = WTAPO2_rmsfdata[0:108,1]; dataWTAPO[:,2] = WTAPO3_rmsfdata[0:108,1]
averageL85FAPO = np.mean(dataL85FAPO, axis = 1)
stdL85FAPO = np.std(dataL85FAPO, axis=1)
averageWTAPO = np.mean(dataWTAPO, axis = 1)
stdWTAPO = np.std(dataWTAPO, axis=1)
plt.errorbar(x=L85FAPO1_rmsfdata[0:108,0],y=averageL85FAPO,yerr=stdL85FAPO, label="L85F PV")
plt.errorbar(x=WTAPO1_rmsfdata[0:108,0],y=averageWTAPO,yerr=stdWTAPO, label="WT PV")
matplotlib.rc('font', **font)
plt.legend(loc="best")
plt.ylabel("RMSF ($\AA$)", **font)
plt.xlabel("Residue number", **font)
plt.title("Average RMSF for apo WT and L85F PV", font)
matplotlib.rc('font', **font)
plt.ylim(0,7)
plt.tight_layout()
plt.gcf().savefig("RMSFAVG_APOS.png",dpi = 300)

# %%
plt.errorbar(x=MGWT1_rmsfdata[0:108,0],y=averageMGWT,yerr=stdMGWT, label="Mg bound PV")
plt.errorbar(x=CAWT1_rmsfdata[0:108,0],y=averageCAWT,yerr=stdCAWT, label="Ca bound PV")
plt.errorbar(x=WTAPO1_rmsfdata[0:108,0],y=averageWTAPO,yerr=stdWTAPO, label="Apo PV")
matplotlib.rc('font', **font)
plt.legend(loc=2)
plt.ylabel("RMSF ($\AA$)", **font)
plt.xlabel("Residue number", **font)
plt.title("Average RMSF for all WT PV runs", font)
matplotlib.rc('font', **font)
plt.ylim(0,8)
plt.tight_layout()
plt.gcf().savefig("RMSFAVG_WT.png",dpi = 300)

# %%
plt.errorbar(x=L85FMG1_rmsfdata[0:108,0],y=averageL85FMG,yerr=stdL85FMG, label="Mg bound PV")
plt.errorbar(x=L85FCA1_rmsfdata[0:108,0],y=averageL85FCA,yerr=stdL85FCA, label="Ca bound PV")
plt.errorbar(x=L85FAPO1_rmsfdata[0:108,0],y=averageL85FAPO,yerr=stdL85FAPO, label="Apo PV")
matplotlib.rc('font', **font)
plt.legend(loc=2)
plt.ylabel("RMSF ($\AA$)", **font)
plt.xlabel("Residue number", **font)
plt.title("Average RMSF for all L85F PV runs", font)
matplotlib.rc('font', **font)
plt.ylim(0,8)
plt.tight_layout()
plt.gcf().savefig("RMSFAVG_L85F.png",dpi = 300)
