# %%
# %matplotlib inline
import matplotlib
import matplotlib.pylab as plt
matplotlib.rcParams['figure.figsize'] = (3,2.75)
matplotlib.rcParams['savefig.dpi'] = 300
import numpy as np

# %%
case=["pCaN/","lpCaN/","lpcCaN/"]
ionicstrength=["0.15M/","1.5M/"]
print x1[:,0][17]
path="/net/share/bsu233/CaM/Con_bding_kinetes/microsecondMD/"

file1 = path + ionicstrength[0] + case[0] + "newtraj/rmsd/rmsddis"
file2 = path + ionicstrength[1] + case[0] + "newtraj/rmsd/rmsddis"
#print file1

x1=np.loadtxt(file1)

x2=np.loadtxt(file2)
print x2[:,0][15]

plt.plot(x1[:,0],x1[:,1],"k--",label="0.15M")
plt.plot(x2[:,0],x2[:,1],"k-",label="1.5M")
plt.legend(fontsize=6,handlelength=4)
plt.xlabel("RMSD ($\AA$)",weight="bold")
plt.ylabel("Probability",weight="bold")
plt.fill_between(x1[:,0][1:17], 0,x1[:,1][1:17],color='violet', alpha='0.3')
plt.fill_between(x2[:,0][1:15], 0,x2[:,1][1:15],color='violet', alpha='0.8')
#print x1
# Out:
# 6.82972
# 6.8985

# %%
file1 = path + ionicstrength[0] + case[1] + "newtraj/rmsd/rmsddis"
file2 = path + ionicstrength[1] + case[1] + "newtraj/rmsd/rmsddis"
#print file1

x1=np.loadtxt(file1)

x2=np.loadtxt(file2)
print x2[:,0][10]
print x1[:,0][11]

plt.plot(x1[:,0],x1[:,1],"r--",label="0.15M")
plt.plot(x2[:,0],x2[:,1],"r-",label="1.5M")
plt.legend(fontsize=6,handlelength=4)
plt.xlabel("RMSD ($\AA$)",weight="bold")
plt.ylabel("Probability",weight="bold")
plt.fill_between(x1[:,0][1:11], 0,x1[:,1][1:11],color='violet', alpha='0.3')
plt.fill_between(x2[:,0][1:10], 0,x2[:,1][1:10],color='violet', alpha='0.8')
# Out:
# 4.90672
# 4.80885

# %%
file1 = path + ionicstrength[0] + case[2] + "newtraj/rmsd/rmsddis"
file2 = path + ionicstrength[1] + case[2] + "newtraj/rmsd/rmsddis"
#print file1

x1=np.loadtxt(file1)

x2=np.loadtxt(file2)
print x2[:,0][14]
print x1[:,0][13]

plt.plot(x1[:,0],x1[:,1],"g--",label="0.15M")
plt.plot(x2[:,0],x2[:,1],"g-",label="1.5M")
plt.legend(fontsize=6,handlelength=4)
plt.xlabel("RMSD ($\AA$)",weight="bold")
plt.ylabel("Probability",weight="bold")
plt.fill_between(x1[:,0][1:13], 0,x1[:,1][1:13],color='violet', alpha='0.3')
plt.fill_between(x2[:,0][1:14], 0,x2[:,1][1:14],color='violet', alpha='0.8')
# Out:
# 5.03259
# 5.08616

# %%
ind=[0,0.4,0.8]
std=[0,0,0]
name=["KctoO","BD","KOtoC"]
data=[5.949e8,8.303e8,8.6835e9]
colors = ['orangered','k','b']
barlist = plt.bar(ind,data,0.4,align="center")
plt.plot

ind2=[2,2.4,2.8]
name2=["","",""]
data2=[9.775e7,1.59e7,1.09e10]
barlist2 = plt.bar(ind2,data2,0.39,align="center")
plt.plot

ind3=[4,4.4,4.8]
name3=["KctoO","BD","KOtoC"]
data3=[5.811e9,8.69e7,6.53e9]

barlist3 = plt.bar(ind3,data3,0.39,align="center")
plt.plot

#plt.plot([-1,6],[10,20],"r--") 

for i in range(3):
    barlist[i].set_color(colors[i])
for i in range(3):
    barlist2[i].set_color(colors[i])
for i in range(3):
    barlist3[i].set_color(colors[i])
pos=[0.4,2.4,4.4]
labb = ["pCaN","lpCaN","lpcCaN"]

#plt.xticks(,name,weight='bold',fontsize=10)
plt.xticks(pos,labb,weight='bold',fontsize=10,rotation=45)
plt.yscale('log')
plt.xlim([-0.3,5])
plt.ylabel("Rate Constants $(M^{-1}S^{-1})$",weight="bold",fontsize=12)
