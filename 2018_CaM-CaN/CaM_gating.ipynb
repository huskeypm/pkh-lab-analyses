# %%
# %matplotlib inline
import matplotlib
import matplotlib.pylab as plt
matplotlib.rcParams['figure.figsize'] = (3,2.75)
matplotlib.rcParams['savefig.dpi'] = 300
import numpy as np

# %%
ind=[0,1]
std=[0,0]
name=["Open","Closed"]
data=[0.136821,0.206486]
colors = ['red','blue']
barlist = plt.bar(ind,data,0.37,align="center")
plt.plot

ind2=[0.4,1.4]
name2=["lpCaN","lpCaN"]
data2=[0.150665,0.187013]
std2=[0,0]

colors2 =['salmon','royalblue']
barlist2 = plt.bar(ind2,data2,0.37,align="center")
plt.plot

#ind3=[0.8,2.8]
#name3=["lpcCaN","lpcCaN"]
#data3=[0.172,0.153]
#std3=[0,0]

#colors3 =['salmon','mediumpurple']
#barlist3 = plt.bar(ind3,data3,0.39,align="center")
#plt.plot

#plt.plot([-1,6],[10,20],"r--") 

for i in range(len(colors)):
    barlist[i].set_color(colors[i])
for i in range(len(colors)):
    
    barlist2[i].set_color(colors2[i])

#for i in range(len(colors)):
    
#    barlist3[i].set_color(colors3[i])

    
pos=[0.2,1.2]
#labb = name + name2 + name3
#plt.xticks(,name,weight='bold',fontsize=10)
plt.xticks(pos,["open","closed"],weight='bold',fontsize=10)
plt.ylabel("Average life time (ns)",weight="bold",fontsize=10)

# %%
ind=[0,1]

name=["wt-F57",""]
data=[0.6840,0.000]
colors = ['k','b']
barlist = plt.bar(ind,data,0.34,align="center")
plt.plot

ind2=[0.35,1.35]
name2=["mut-F57","mut-E98"]
data2=[1.1507,0.8446]
colors2 = ['grey','royalblue']
barlist2 = plt.bar(ind2,data2,0.34,align="center")
plt.plot

for i in range(len(colors)):
    barlist[i].set_color(colors[i])
for i in range(len(colors)):
    barlist2[i].set_color(colors2[i])
    
pos=ind + ind2 
labb = name + name2 
#plt.xticks(,name,weight='bold',fontsize=10)
plt.xticks(pos,labb,weight='bold',fontsize=10)
plt.ylabel("Side-chain RMSF ($\AA$)",weight="bold",fontsize=12)

# %%
ind=[0,0.4,0.8]
std=[0,0,0]
name=["KctoO","BD","KOtoC"]
data=[5.949e8,8.303e8,8.6835e9]
colors = ['orangered','k','b']
barlist = plt.bar(ind,data,0.4,align="center")
plt.plot

ind2=[2,2.4,2.8]
name2=["","",""]
data2=[9.775e7,1.59e7,1.09e10]
barlist2 = plt.bar(ind2,data2,0.39,align="center")
plt.plot

ind3=[4,4.4,4.8]
name3=["KctoO","BD","KOtoC"]
data3=[5.811e9,8.69e7,6.53e9]

barlist3 = plt.bar(ind3,data3,0.39,align="center")
plt.plot

#plt.plot([-1,6],[10,20],"r--") 

for i in range(3):
    barlist[i].set_color(colors[i])
for i in range(3):
    barlist2[i].set_color(colors[i])
for i in range(3):
    barlist3[i].set_color(colors[i])
pos=[0.4,2.4,4.4]
labb = ["pCaN","lpCaN","lpcCaN"]

#plt.xticks(,name,weight='bold',fontsize=10)
plt.xticks(pos,labb,weight='bold',fontsize=10,rotation=45)
plt.yscale('log')
plt.xlim([-0.3,5])
plt.ylabel("Rate Constants $(M^{-1}S^{-1})$",weight="bold",fontsize=12)
